# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Obtaining dependency information for optuna from https://files.pythonhosted.org/packages/d9/dd/0b593d1a5ee431b33a1fdf4ddb5911c312ed3bb598ef9e17457af2ee7b34/optuna-4.3.0-py3-none-any.whl.metadata
#   Downloading optuna-4.3.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Obtaining dependency information for alembic>=1.5.0 from https://files.pythonhosted.org/packages/31/59/565286efff3692c5716c212202af61466480f6357c4ae3089d4453bff1f3/alembic-1.16.1-py3-none-any.whl.metadata
#   Downloading alembic-1.16.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Obtaining dependency information for colorlog from https://files.pythonhosted.org/packages/e3/51/9b208e85196941db2f0654ad0357ca6388ab3ed67efdbfc799f35d1f83aa/colorlog-6.9.0-py3-none-any.whl.metadata
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in c:\users\kaitlyn\anaconda3\lib\site-packages (from optuna) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\kaitlyn\anaconda3\lib\site-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\kaitlyn\anaconda3\lib\site-packages (from optuna) (1.4.39)
# Requirement already satisfied: tqdm in c:\users\kaitlyn\anaconda3\lib\site-packages (from optuna) (4.65.0)
# Requirement already satisfied: PyYAML in c:\users\kaitlyn\anaconda3\lib\site-packages (from optuna) (6.0)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Obtaining dependency information for Mako from https://files.pythonhosted.org/packages/87/fb/99f81ac72ae23375f22b7afdb7642aba97c00a713c217124420147681a2f/mako-1.3.10-py3-none-any.whl.metadata
#   Downloading mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.12 in c:\users\kaitlyn\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\kaitlyn\anaconda3\lib\site-packages (from sqlalchemy>=1.4.2->optuna) (2.0.1)
# Requirement already satisfied: colorama in c:\users\kaitlyn\anaconda3\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\kaitlyn\anaconda3\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.1)
# Downloading optuna-4.3.0-py3-none-any.whl (386 kB)
#    ---------------------------------------- 0.0/386.6 kB ? eta -:--:--
#    --------- ------------------------------ 92.2/386.6 kB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 368.6/386.6 kB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 386.6/386.6 kB 4.0 MB/s eta 0:00:00
# Downloading alembic-1.16.1-py3-none-any.whl (242 kB)
#    ---------------------------------------- 0.0/242.5 kB ? eta -:--:--
#    --------------------------------------- 242.5/242.5 kB 14.5 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading mako-1.3.10-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.5 kB ? eta -:--:--
#    ---------------------------------------- 78.5/78.5 kB ? eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.10 alembic-1.16.1 colorlog-6.9.0 optuna-4.3.0

# %%
### CITATION ###
# Hyperparameter tuning implemented with help from tutorials provided with Optuna package
# https://optuna.org/
# https://optuna.readthedocs.io/en/stable/index.html

# %%
import networkx as nx
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch_geometric.nn import GCNConv, global_mean_pool
from torch_geometric.data import Data, DataLoader
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, classification_report, f1_score
import numpy as np
import time
import random
import optuna
from optuna.samplers import TPESampler
from gwgraphs import *
from visualizations import GCNResultsVisualizer, get_model_probabilities

# %%
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

# %%
def read_graph_data():
    # Read the adjacency matrix (edges)
    with open("BZR_A.txt", "r") as f:
        edges = [tuple(map(int, line.split(','))) for line in f]

    # Read graph indicators
    with open("BZR_graph_indicator.txt", "r") as f:
        graph_indicators = [int(line.strip()) for line in f if line.strip()]

    # Read graph labels
    with open("BZR_graph_labels.txt", "r") as f:
        graph_labels = [int(line.strip()) for line in f]

    # Read node labels
    with open("BZR_node_labels.txt", "r") as f:
        node_labels = [int(line.strip()) for line in f]

    # Read node attributes
    with open("BZR_node_attributes.txt", "r") as f:
        node_attributes = [
            list(map(float,
                     line.strip().split(','))) for line in f if line.strip()
        ]

    return edges, graph_indicators, graph_labels, node_labels, node_attributes


def construct_networkx_graph(edges, graph_indicators, graph_labels,
                             node_labels, node_attributes):
    graphs = {}
    for node_id, graph_id in enumerate(graph_indicators, start=1):
        if graph_id not in graphs:
            graphs[graph_id] = nx.Graph(label=graph_labels[graph_id - 1])

    for edge in edges:
        node1, node2 = edge
        graph_id = graph_indicators[
            node1 - 1]  # Determine which graph the edge belongs to
        graphs[graph_id].add_edge(node1, node2)

    for node_id, (graph_id, node_label,
                  node_attr) in enumerate(zip(graph_indicators, node_labels,
                                              node_attributes),
                                          start=1):
        graphs[graph_id].nodes[node_id]['label'] = node_label
        graphs[graph_id].nodes[node_id]['attributes'] = node_attr

    return graphs


def compute_bzr_distance_matrix(graph):
    num_nodes = len(graph.nodes)
    distance_matrix = np.full((num_nodes, num_nodes), 10000.0)

    # Get the correct node indices to be used for indexing the matrix
    node_list = list(graph.nodes())
    node_index = {node: i for i, node in enumerate(node_list)}

    for node in graph.nodes:
        lengths = nx.shortest_path_length(graph, source=node, weight="weight")

        for target, length in lengths.items():
            if target in node_index:
                distance_matrix[node_index[node], node_index[target]] = length

    return distance_matrix

# %%
class GraphNeuralNetwork(nn.Module):

    def __init__(self, input_dim, hidden_dim, output_dim, num_layers=3):
        super(GraphNeuralNetwork, self).__init__()

        self.num_layers = num_layers
        self.convs = nn.ModuleList()

        # First layer
        self.convs.append(GCNConv(input_dim, hidden_dim))

        # Hidden layers
        for _ in range(num_layers - 2):
            self.convs.append(GCNConv(hidden_dim, hidden_dim))

        # Last layer
        self.convs.append(GCNConv(hidden_dim, hidden_dim))

        # Classifier
        self.classifier = nn.Linear(hidden_dim, output_dim)
        self.dropout = nn.Dropout(0.5)

    def forward(self, x, edge_index, batch):
        # Apply GCN layers
        for i, conv in enumerate(self.convs):
            x = conv(x, edge_index)
            if i < len(self.convs) - 1:
                x = F.relu(x)
                x = self.dropout(x)

        # Global pooling to get graph-level representation
        x = global_mean_pool(x, batch)

        # Final classification
        x = self.classifier(x)

        return x


def train_model(model, train_loader, optimizer, criterion, device):
    """Function to train the model for one epoch."""
    model.train()
    total_loss = 0

    for batch in train_loader:
        batch = batch.to(device)
        optimizer.zero_grad()

        # Forward pass
        out = model(batch.x, batch.edge_index, batch.batch)

        # Convert labels from {-1, 1} to {0,1} for cross-entropy loss
        labels = (batch.y + 1) // 2

        loss = criterion(out, labels.view(-1))
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    return total_loss / len(train_loader)


def evaluate_model(model, test_loader, device):
    """Function to evaluate the model."""
    model.eval()
    predictions = []
    true_labels = []

    with torch.no_grad():
        for batch in test_loader:
            batch = batch.to(device)
            out = model(batch.x, batch.edge_index, batch.batch)

            # Get predictions
            pred = torch.argmax(out, dim=1)
            # Convert back to {-1,1} labels
            pred = pred * 2 - 1

            predictions.extend(pred.cpu().numpy())
            true_labels.extend(batch.y.cpu().numpy())

        return np.array(predictions), np.array(true_labels)


def calculate_metrics(y_true, y_pred):
    """Calculate classification metrics"""
    # Overall accuracy
    overall_acc = accuracy_score(y_true, y_pred)

    # By-class accuracy
    class_1_mask = y_true == 1
    class_neg1_mask = y_true == -1

    class_1_acc = accuracy_score(
        y_true[class_1_mask],
        y_pred[class_1_mask]) if np.sum(class_1_mask) > 0 else 0
    class_neg1_acc = accuracy_score(
        y_true[class_neg1_mask],
        y_pred[class_neg1_mask]) if np.sum(class_neg1_mask) > 0 else 0

    # F1 score
    f1 = f1_score(y_true, y_pred, average='weighted')

    return overall_acc, class_1_acc, class_neg1_acc, f1


def objective(trial, full_graph_data, labels, device, input_dim, hidden_dim, output_dim):
    """Objective function for Bayesian optimization"""
    # Suggest hyperparameters
    num_epochs = trial.suggest_int('num_epochs', 20, 100, step=10)
    learning_rate = trial.suggest_float('learning_rate', 1e-4, 1e-1, log=True)
    batch_size = trial.suggest_categorical('batch_size', [16, 32, 64])
    
    # 5-fold cross validation for this trial
    kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    fold_scores = []
    
    for fold, (train_idx, test_idx) in enumerate(kfold.split(full_graph_data, labels)):
        # Split data
        train_graphs = [full_graph_data[i] for i in train_idx]
        test_graphs = [full_graph_data[i] for i in test_idx]
        
        # Create data loaders
        train_loader = DataLoader(train_graphs, batch_size=batch_size, shuffle=True)
        test_loader = DataLoader(test_graphs, batch_size=batch_size, shuffle=False)
        
        # Initialize model
        model = GraphNeuralNetwork(input_dim, hidden_dim, output_dim).to(device)
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)
        criterion = nn.CrossEntropyLoss()
        
        # Training loop
        for epoch in range(num_epochs):
            train_loss = train_model(model, train_loader, optimizer, criterion, device)
        
        # Evaluation
        y_pred, y_true = evaluate_model(model, test_loader, device)
        overall_acc, _, _, _ = calculate_metrics(y_true, y_pred)
        fold_scores.append(overall_acc)
        
        # Report intermediate objective value for pruning
        trial.report(np.mean(fold_scores[:fold+1]), fold)
        
        # Handle pruning based on the intermediate value
        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()
    
    return np.mean(fold_scores)


def networkx_to_pyg(nx_graph, label, num_features):
    """Convert NetworkX graph to PyTorch Geometric Data object"""
    num_nodes = len(nx_graph.nodes)

    # Extract node features from the graph's node attributes
    node_features = []
    node_list = sorted(nx_graph.nodes())  # Ensure consistent ordering
    
    for node in node_list:
        if 'attributes' in nx_graph.nodes[node]:
            # Use the actual node attributes from the BZR dataset
            node_features.append(nx_graph.nodes[node]['attributes'])
        else:
            # Fallback to zero features if attributes are missing
            node_features.append([0.0] * num_features)
    
    # Convert to tensor
    x = torch.tensor(node_features, dtype=torch.float32)

    # Convert edges to tensor format - need to map node IDs to indices
    node_to_idx = {node: idx for idx, node in enumerate(node_list)}
    edge_list = list(nx_graph.edges())
    
    if len(edge_list) == 0:
        # Handle graphs with no edges
        edge_index = torch.empty((2, 0), dtype=torch.long)
    else:
        # Map node IDs to indices for edge_index
        mapped_edges = [(node_to_idx[u], node_to_idx[v]) for u, v in edge_list]
        edge_index = torch.tensor(mapped_edges, dtype=torch.long).t().contiguous()

    # Convert label to tensor
    y = torch.tensor([label], dtype=torch.long)

    return Data(x=x, edge_index=edge_index, y=y)

# %%
edges, graph_indicators, graph_labels, node_labels, node_attributes = read_graph_data()
graphs = construct_networkx_graph(edges, graph_indicators, graph_labels,
                                node_labels, node_attributes)
for graph_id, graph in graphs.items():
    print(
        f"Graph ID: {graph_id}, number of nodes: {graph.number_of_nodes()}, label: {graph.graph['label']}"
        )
total_avg, class_averages = compute_averages(graphs)
print(f"Average number of nodes in entire dataset: {total_avg}")
print("Average number of nodes for each class:")
for class_label, avg_nodes in class_averages.items():
        print(f"  Class {class_label}: {avg_nodes}")
# Out:
# Graph ID: 1, number of nodes: 30, label: -1
# Graph ID: 2, number of nodes: 33, label: -1
# Graph ID: 3, number of nodes: 30, label: -1
# Graph ID: 4, number of nodes: 33, label: -1
# Graph ID: 5, number of nodes: 30, label: -1
# Graph ID: 6, number of nodes: 33, label: -1
# Graph ID: 7, number of nodes: 30, label: -1
# Graph ID: 8, number of nodes: 30, label: -1
# Graph ID: 9, number of nodes: 33, label: -1
# Graph ID: 10, number of nodes: 30, label: -1
# Graph ID: 11, number of nodes: 30, label: -1
# Graph ID: 12, number of nodes: 30, label: -1
# Graph ID: 13, number of nodes: 33, label: -1
# Graph ID: 14, number of nodes: 33, label: -1
# Graph ID: 15, number of nodes: 33, label: -1
# Graph ID: 16, number of nodes: 33, label: -1
# Graph ID: 17, number of nodes: 32, label: -1
# Graph ID: 18, number of nodes: 32, label: -1
# Graph ID: 19, number of nodes: 32, label: -1
# Graph ID: 20, number of nodes: 35, label: -1
# Graph ID: 21, number of nodes: 32, label: -1
# Graph ID: 22, number of nodes: 35, label: -1
# Graph ID: 23, number of nodes: 35, label: -1
# Graph ID: 24, number of nodes: 36, label: -1
# Graph ID: 25, number of nodes: 32, label: -1
# Graph ID: 26, number of nodes: 35, label: -1
# Graph ID: 27, number of nodes: 35, label: -1
# Graph ID: 28, number of nodes: 32, label: -1
# Graph ID: 29, number of nodes: 37, label: 1
# Graph ID: 30, number of nodes: 42, label: -1
# Graph ID: 31, number of nodes: 38, label: 1
# Graph ID: 32, number of nodes: 34, label: -1
# Graph ID: 33, number of nodes: 34, label: -1
# Graph ID: 34, number of nodes: 36, label: -1
# Graph ID: 35, number of nodes: 34, label: -1
# Graph ID: 36, number of nodes: 32, label: -1
# Graph ID: 37, number of nodes: 35, label: -1
# Graph ID: 38, number of nodes: 41, label: 1
# Graph ID: 39, number of nodes: 30, label: -1
# Graph ID: 40, number of nodes: 30, label: -1
# Graph ID: 41, number of nodes: 30, label: -1
# Graph ID: 42, number of nodes: 33, label: -1
# Graph ID: 43, number of nodes: 33, label: -1
# Graph ID: 44, number of nodes: 30, label: -1
# Graph ID: 45, number of nodes: 33, label: -1
# Graph ID: 46, number of nodes: 30, label: -1
# Graph ID: 47, number of nodes: 33, label: -1
# Graph ID: 48, number of nodes: 33, label: -1
# Graph ID: 49, number of nodes: 33, label: -1
# Graph ID: 50, number of nodes: 33, label: -1
# Graph ID: 51, number of nodes: 30, label: -1
# Graph ID: 52, number of nodes: 33, label: -1
# Graph ID: 53, number of nodes: 30, label: -1
# Graph ID: 54, number of nodes: 33, label: -1
# Graph ID: 55, number of nodes: 35, label: 1
# Graph ID: 56, number of nodes: 38, label: -1
# Graph ID: 57, number of nodes: 42, label: -1
# Graph ID: 58, number of nodes: 36, label: -1
# Graph ID: 59, number of nodes: 35, label: -1
# Graph ID: 60, number of nodes: 40, label: -1
# Graph ID: 61, number of nodes: 39, label: -1
# Graph ID: 62, number of nodes: 42, label: -1
# Graph ID: 63, number of nodes: 43, label: 1
# Graph ID: 64, number of nodes: 38, label: -1
# Graph ID: 65, number of nodes: 50, label: -1
# Graph ID: 66, number of nodes: 37, label: -1
# Graph ID: 67, number of nodes: 38, label: -1
# Graph ID: 68, number of nodes: 44, label: -1
# Graph ID: 69, number of nodes: 41, label: -1
# Graph ID: 70, number of nodes: 42, label: -1
# Graph ID: 71, number of nodes: 44, label: -1
# Graph ID: 72, number of nodes: 36, label: 1
# Graph ID: 73, number of nodes: 23, label: 1
# Graph ID: 74, number of nodes: 34, label: -1
# Graph ID: 75, number of nodes: 37, label: -1
# Graph ID: 76, number of nodes: 36, label: -1
# Graph ID: 77, number of nodes: 29, label: -1
# Graph ID: 78, number of nodes: 36, label: -1
# Graph ID: 79, number of nodes: 33, label: 1
# Graph ID: 80, number of nodes: 33, label: -1
# Graph ID: 81, number of nodes: 35, label: -1
# Graph ID: 82, number of nodes: 38, label: -1
# Graph ID: 83, number of nodes: 39, label: 1
# Graph ID: 84, number of nodes: 33, label: -1
# Graph ID: 85, number of nodes: 31, label: -1
# Graph ID: 86, number of nodes: 34, label: -1
# Graph ID: 87, number of nodes: 31, label: -1
# Graph ID: 88, number of nodes: 42, label: -1
# Graph ID: 89, number of nodes: 44, label: -1
# Graph ID: 90, number of nodes: 33, label: -1
# Graph ID: 91, number of nodes: 33, label: -1
# Graph ID: 92, number of nodes: 27, label: -1
# Graph ID: 93, number of nodes: 27, label: -1
# Graph ID: 94, number of nodes: 27, label: -1
# Graph ID: 95, number of nodes: 27, label: -1
# Graph ID: 96, number of nodes: 34, label: -1
# Graph ID: 97, number of nodes: 32, label: 1
# Graph ID: 98, number of nodes: 32, label: 1
# Graph ID: 99, number of nodes: 35, label: 1
# Graph ID: 100, number of nodes: 38, label: 1
# Graph ID: 101, number of nodes: 37, label: -1
# Graph ID: 102, number of nodes: 35, label: -1
# Graph ID: 103, number of nodes: 31, label: -1
# Graph ID: 104, number of nodes: 34, label: -1
# Graph ID: 105, number of nodes: 40, label: 1
# Graph ID: 106, number of nodes: 37, label: 1
# Graph ID: 107, number of nodes: 43, label: 1
# Graph ID: 108, number of nodes: 33, label: 1
# Graph ID: 109, number of nodes: 38, label: -1
# Graph ID: 110, number of nodes: 57, label: -1
# Graph ID: 111, number of nodes: 46, label: 1
# Graph ID: 112, number of nodes: 34, label: -1
# Graph ID: 113, number of nodes: 31, label: -1
# Graph ID: 114, number of nodes: 35, label: -1
# Graph ID: 115, number of nodes: 32, label: -1
# Graph ID: 116, number of nodes: 35, label: -1
# Graph ID: 117, number of nodes: 35, label: -1
# Graph ID: 118, number of nodes: 36, label: -1
# Graph ID: 119, number of nodes: 43, label: -1
# Graph ID: 120, number of nodes: 46, label: -1
# Graph ID: 121, number of nodes: 38, label: -1
# Graph ID: 122, number of nodes: 40, label: -1
# Graph ID: 123, number of nodes: 40, label: -1
# Graph ID: 124, number of nodes: 32, label: -1
# Graph ID: 125, number of nodes: 38, label: -1
# Graph ID: 126, number of nodes: 32, label: -1
# Graph ID: 127, number of nodes: 32, label: -1
# Graph ID: 128, number of nodes: 32, label: -1
# Graph ID: 129, number of nodes: 34, label: -1
# Graph ID: 130, number of nodes: 36, label: -1
# Graph ID: 131, number of nodes: 37, label: -1
# Graph ID: 132, number of nodes: 42, label: -1
# Graph ID: 133, number of nodes: 48, label: -1
# Graph ID: 134, number of nodes: 39, label: -1
# Graph ID: 135, number of nodes: 46, label: -1
# Graph ID: 136, number of nodes: 36, label: -1
# Graph ID: 137, number of nodes: 37, label: -1
# Graph ID: 138, number of nodes: 37, label: -1
# Graph ID: 139, number of nodes: 48, label: -1
# Graph ID: 140, number of nodes: 54, label: -1
# Graph ID: 141, number of nodes: 31, label: -1
# Graph ID: 142, number of nodes: 33, label: -1
# Graph ID: 143, number of nodes: 36, label: -1
# Graph ID: 144, number of nodes: 36, label: -1
# Graph ID: 145, number of nodes: 33, label: -1
# Graph ID: 146, number of nodes: 36, label: -1
# Graph ID: 147, number of nodes: 38, label: -1
# Graph ID: 148, number of nodes: 38, label: -1
# Graph ID: 149, number of nodes: 38, label: -1
# Graph ID: 150, number of nodes: 40, label: -1
# Graph ID: 151, number of nodes: 43, label: -1
# Graph ID: 152, number of nodes: 43, label: -1
# Graph ID: 153, number of nodes: 43, label: -1
# Graph ID: 154, number of nodes: 38, label: -1
# Graph ID: 155, number of nodes: 34, label: -1
# Graph ID: 156, number of nodes: 30, label: -1
# Graph ID: 157, number of nodes: 37, label: -1
# Graph ID: 158, number of nodes: 37, label: -1
# Graph ID: 159, number of nodes: 36, label: -1
# Graph ID: 160, number of nodes: 34, label: -1
# Graph ID: 161, number of nodes: 32, label: -1
# Graph ID: 162, number of nodes: 32, label: -1
# Graph ID: 163, number of nodes: 32, label: -1
# Graph ID: 164, number of nodes: 32, label: -1
# Graph ID: 165, number of nodes: 32, label: -1
# Graph ID: 166, number of nodes: 35, label: 1
# Graph ID: 167, number of nodes: 35, label: -1
# Graph ID: 168, number of nodes: 40, label: -1
# Graph ID: 169, number of nodes: 40, label: -1
# Graph ID: 170, number of nodes: 40, label: -1
# Graph ID: 171, number of nodes: 50, label: -1
# Graph ID: 172, number of nodes: 52, label: -1
# Graph ID: 173, number of nodes: 49, label: -1
# Graph ID: 174, number of nodes: 46, label: -1
# Graph ID: 175, number of nodes: 50, label: -1
# Graph ID: 176, number of nodes: 46, label: -1
# Graph ID: 177, number of nodes: 46, label: -1
# Graph ID: 178, number of nodes: 46, label: -1
# Graph ID: 179, number of nodes: 46, label: -1
# Graph ID: 180, number of nodes: 46, label: -1
# Graph ID: 181, number of nodes: 46, label: -1
# Graph ID: 182, number of nodes: 46, label: -1
# Graph ID: 183, number of nodes: 49, label: -1
# Graph ID: 184, number of nodes: 48, label: -1
# Graph ID: 185, number of nodes: 43, label: -1
# Graph ID: 186, number of nodes: 43, label: -1
# Graph ID: 187, number of nodes: 41, label: -1
# Graph ID: 188, number of nodes: 46, label: -1
# Graph ID: 189, number of nodes: 46, label: -1
# Graph ID: 190, number of nodes: 46, label: -1
# Graph ID: 191, number of nodes: 44, label: -1
# Graph ID: 192, number of nodes: 52, label: -1
# Graph ID: 193, number of nodes: 50, label: -1
# Graph ID: 194, number of nodes: 53, label: -1
# Graph ID: 195, number of nodes: 56, label: -1
# Graph ID: 196, number of nodes: 47, label: -1
# Graph ID: 197, number of nodes: 44, label: -1
# Graph ID: 198, number of nodes: 31, label: 1
# Graph ID: 199, number of nodes: 36, label: -1
# Graph ID: 200, number of nodes: 36, label: -1
# Graph ID: 201, number of nodes: 36, label: -1
# Graph ID: 202, number of nodes: 36, label: 1
# Graph ID: 203, number of nodes: 36, label: 1
# Graph ID: 204, number of nodes: 36, label: -1
# Graph ID: 205, number of nodes: 36, label: -1
# Graph ID: 206, number of nodes: 36, label: 1
# Graph ID: 207, number of nodes: 34, label: -1
# Graph ID: 208, number of nodes: 37, label: -1
# Graph ID: 209, number of nodes: 43, label: -1
# Graph ID: 210, number of nodes: 41, label: -1
# Graph ID: 211, number of nodes: 47, label: -1
# Graph ID: 212, number of nodes: 44, label: -1
# Graph ID: 213, number of nodes: 43, label: -1
# Graph ID: 214, number of nodes: 43, label: -1
# Graph ID: 215, number of nodes: 43, label: -1
# Graph ID: 216, number of nodes: 43, label: -1
# Graph ID: 217, number of nodes: 43, label: -1
# Graph ID: 218, number of nodes: 44, label: -1
# Graph ID: 219, number of nodes: 51, label: -1
# Graph ID: 220, number of nodes: 29, label: -1
# Graph ID: 221, number of nodes: 31, label: -1
# Graph ID: 222, number of nodes: 35, label: -1
# Graph ID: 223, number of nodes: 31, label: -1
# Graph ID: 224, number of nodes: 44, label: 1
# Graph ID: 225, number of nodes: 48, label: 1
# Graph ID: 226, number of nodes: 44, label: 1
# Graph ID: 227, number of nodes: 44, label: 1
# Graph ID: 228, number of nodes: 31, label: 1
# Graph ID: 229, number of nodes: 35, label: 1
# Graph ID: 230, number of nodes: 31, label: 1
# Graph ID: 231, number of nodes: 31, label: 1
# Graph ID: 232, number of nodes: 31, label: 1
# Graph ID: 233, number of nodes: 30, label: 1
# Graph ID: 234, number of nodes: 48, label: -1
# Graph ID: 235, number of nodes: 48, label: -1
# Graph ID: 236, number of nodes: 23, label: 1
# Graph ID: 237, number of nodes: 20, label: 1
# Graph ID: 238, number of nodes: 19, label: 1
# Graph ID: 239, number of nodes: 23, label: 1
# Graph ID: 240, number of nodes: 17, label: 1
# Graph ID: 241, number of nodes: 31, label: 1
# Graph ID: 242, number of nodes: 23, label: 1
# Graph ID: 243, number of nodes: 29, label: 1
# Graph ID: 244, number of nodes: 24, label: 1
# Graph ID: 245, number of nodes: 27, label: 1
# Graph ID: 246, number of nodes: 35, label: 1
# Graph ID: 247, number of nodes: 26, label: 1
# Graph ID: 248, number of nodes: 31, label: 1
# Graph ID: 249, number of nodes: 30, label: 1
# Graph ID: 250, number of nodes: 36, label: 1
# Graph ID: 251, number of nodes: 42, label: -1
# Graph ID: 252, number of nodes: 42, label: -1
# Graph ID: 253, number of nodes: 43, label: -1
# Graph ID: 254, number of nodes: 43, label: -1
# Graph ID: 255, number of nodes: 45, label: -1
# Graph ID: 256, number of nodes: 46, label: -1
# Graph ID: 257, number of nodes: 46, label: -1
# Graph ID: 258, number of nodes: 44, label: -1
# Graph ID: 259, number of nodes: 44, label: -1
# Graph ID: 260, number of nodes: 46, label: -1
# Graph ID: 261, number of nodes: 44, label: -1
# Graph ID: 262, number of nodes: 47, label: -1
# Graph ID: 263, number of nodes: 46, label: -1
# Graph ID: 264, number of nodes: 31, label: -1
# Graph ID: 265, number of nodes: 46, label: -1
# Graph ID: 266, number of nodes: 46, label: -1
# Graph ID: 267, number of nodes: 43, label: -1
# Graph ID: 268, number of nodes: 47, label: -1
# Graph ID: 269, number of nodes: 49, label: -1
# Graph ID: 270, number of nodes: 49, label: 1
# Graph ID: 271, number of nodes: 49, label: -1
# Graph ID: 272, number of nodes: 50, label: -1
# Graph ID: 273, number of nodes: 47, label: -1
# Graph ID: 274, number of nodes: 49, label: -1
# Graph ID: 275, number of nodes: 49, label: -1
# Graph ID: 276, number of nodes: 34, label: -1
# Graph ID: 277, number of nodes: 44, label: -1
# Graph ID: 278, number of nodes: 41, label: -1
# Graph ID: 279, number of nodes: 13, label: 1
# Graph ID: 280, number of nodes: 13, label: 1
# Graph ID: 281, number of nodes: 16, label: 1
# Graph ID: 282, number of nodes: 21, label: 1
# Graph ID: 283, number of nodes: 31, label: 1
# Graph ID: 284, number of nodes: 34, label: 1
# Graph ID: 285, number of nodes: 20, label: 1
# Graph ID: 286, number of nodes: 30, label: 1
# Graph ID: 287, number of nodes: 44, label: 1
# Graph ID: 288, number of nodes: 50, label: 1
# Graph ID: 289, number of nodes: 25, label: 1
# Graph ID: 290, number of nodes: 31, label: -1
# Graph ID: 291, number of nodes: 34, label: -1
# Graph ID: 292, number of nodes: 28, label: -1
# Graph ID: 293, number of nodes: 41, label: -1
# Graph ID: 294, number of nodes: 27, label: -1
# Graph ID: 295, number of nodes: 34, label: -1
# Graph ID: 296, number of nodes: 34, label: -1
# Graph ID: 297, number of nodes: 37, label: -1
# Graph ID: 298, number of nodes: 37, label: -1
# Graph ID: 299, number of nodes: 35, label: 1
# Graph ID: 300, number of nodes: 35, label: -1
# Graph ID: 301, number of nodes: 30, label: -1
# Graph ID: 302, number of nodes: 39, label: -1
# Graph ID: 303, number of nodes: 36, label: -1
# Graph ID: 304, number of nodes: 34, label: -1
# Graph ID: 305, number of nodes: 33, label: -1
# Graph ID: 306, number of nodes: 37, label: -1
# Graph ID: 307, number of nodes: 23, label: 1
# Graph ID: 308, number of nodes: 24, label: 1
# Graph ID: 309, number of nodes: 24, label: 1
# Graph ID: 310, number of nodes: 26, label: -1
# Graph ID: 311, number of nodes: 23, label: -1
# Graph ID: 312, number of nodes: 28, label: -1
# Graph ID: 313, number of nodes: 33, label: -1
# Graph ID: 314, number of nodes: 30, label: 1
# Graph ID: 315, number of nodes: 25, label: -1
# Graph ID: 316, number of nodes: 28, label: -1
# Graph ID: 317, number of nodes: 31, label: -1
# Graph ID: 318, number of nodes: 34, label: -1
# Graph ID: 319, number of nodes: 32, label: -1
# Graph ID: 320, number of nodes: 33, label: -1
# Graph ID: 321, number of nodes: 25, label: -1
# Graph ID: 322, number of nodes: 30, label: -1
# Graph ID: 323, number of nodes: 21, label: -1
# Graph ID: 324, number of nodes: 23, label: -1
# Graph ID: 325, number of nodes: 23, label: -1
# Graph ID: 326, number of nodes: 21, label: -1
# Graph ID: 327, number of nodes: 25, label: -1
# Graph ID: 328, number of nodes: 28, label: -1
# Graph ID: 329, number of nodes: 31, label: -1
# Graph ID: 330, number of nodes: 23, label: 1
# Graph ID: 331, number of nodes: 22, label: -1
# Graph ID: 332, number of nodes: 36, label: -1
# Graph ID: 333, number of nodes: 36, label: 1
# Graph ID: 334, number of nodes: 42, label: -1
# Graph ID: 335, number of nodes: 40, label: -1
# Graph ID: 336, number of nodes: 23, label: -1
# Graph ID: 337, number of nodes: 37, label: 1
# Graph ID: 338, number of nodes: 27, label: -1
# Graph ID: 339, number of nodes: 29, label: -1
# Graph ID: 340, number of nodes: 30, label: 1
# Graph ID: 341, number of nodes: 32, label: -1
# Graph ID: 342, number of nodes: 29, label: -1
# Graph ID: 343, number of nodes: 31, label: -1
# Graph ID: 344, number of nodes: 41, label: 1
# Graph ID: 345, number of nodes: 34, label: -1
# Graph ID: 346, number of nodes: 44, label: 1
# Graph ID: 347, number of nodes: 39, label: -1
# Graph ID: 348, number of nodes: 34, label: 1
# Graph ID: 349, number of nodes: 35, label: -1
# Graph ID: 350, number of nodes: 37, label: 1
# Graph ID: 351, number of nodes: 38, label: 1
# Graph ID: 352, number of nodes: 32, label: -1
# Graph ID: 353, number of nodes: 29, label: 1
# Graph ID: 354, number of nodes: 25, label: 1
# Graph ID: 355, number of nodes: 28, label: 1
# Graph ID: 356, number of nodes: 26, label: 1
# Graph ID: 357, number of nodes: 40, label: -1
# Graph ID: 358, number of nodes: 40, label: 1
# Graph ID: 359, number of nodes: 31, label: -1
# Graph ID: 360, number of nodes: 31, label: -1
# Graph ID: 361, number of nodes: 31, label: -1
# Graph ID: 362, number of nodes: 35, label: -1
# Graph ID: 363, number of nodes: 31, label: -1
# Graph ID: 364, number of nodes: 35, label: -1
# Graph ID: 365, number of nodes: 34, label: -1
# Graph ID: 366, number of nodes: 34, label: -1
# Graph ID: 367, number of nodes: 34, label: -1
# Graph ID: 368, number of nodes: 34, label: -1
# Graph ID: 369, number of nodes: 34, label: -1
# Graph ID: 370, number of nodes: 34, label: -1
# Graph ID: 371, number of nodes: 37, label: -1
# Graph ID: 372, number of nodes: 35, label: -1
# Graph ID: 373, number of nodes: 31, label: -1
# Graph ID: 374, number of nodes: 37, label: -1
# Graph ID: 375, number of nodes: 31, label: -1
# Graph ID: 376, number of nodes: 31, label: -1
# Graph ID: 377, number of nodes: 45, label: -1
# Graph ID: 378, number of nodes: 32, label: -1
# Graph ID: 379, number of nodes: 31, label: -1
# Graph ID: 380, number of nodes: 31, label: -1
# Graph ID: 381, number of nodes: 31, label: -1
# Graph ID: 382, number of nodes: 31, label: -1
# Graph ID: 383, number of nodes: 45, label: 1
# Graph ID: 384, number of nodes: 32, label: -1
# Graph ID: 385, number of nodes: 45, label: 1
# Graph ID: 386, number of nodes: 32, label: -1
# Graph ID: 387, number of nodes: 33, label: -1
# Graph ID: 388, number of nodes: 33, label: -1
# Graph ID: 389, number of nodes: 33, label: -1
# Graph ID: 390, number of nodes: 33, label: -1
# Graph ID: 391, number of nodes: 33, label: 1
# Graph ID: 392, number of nodes: 33, label: -1
# Graph ID: 393, number of nodes: 31, label: -1
# Graph ID: 394, number of nodes: 31, label: 1
# Graph ID: 395, number of nodes: 31, label: -1
# Graph ID: 396, number of nodes: 37, label: -1
# Graph ID: 397, number of nodes: 37, label: 1
# Graph ID: 398, number of nodes: 37, label: 1
# Graph ID: 399, number of nodes: 35, label: -1
# Graph ID: 400, number of nodes: 32, label: -1
# Graph ID: 401, number of nodes: 30, label: -1
# Graph ID: 402, number of nodes: 30, label: -1
# Graph ID: 403, number of nodes: 30, label: -1
# Graph ID: 404, number of nodes: 36, label: 1
# Graph ID: 405, number of nodes: 31, label: -1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 8
#       4 for graph_id, graph in graphs.items():
#       5     print(
#       6         f"Graph ID: {graph_id}, number of nodes: {graph.number_of_nodes()}, label: {graph.graph['label']}"
#       7         )
# ----> 8 total_avg, class_averages = compute_averages(graphs)
#       9 print(f"Average number of nodes in entire dataset: {total_avg}")
#      10 print("Average number of nodes for each class:")
#
# NameError: name 'compute_averages' is not defined

# %%
graphs_list = []
labels_list = []
for graph_id, graph in graphs.items():
    # Add the graph object to the list
    graphs_list.append(graph)

    # Extract the label and add to the label list
    label = graph.graph['label']
    labels_list.append(label)

# Convert graphs into pairwise distance matrices
distance_matrices = [compute_bzr_distance_matrix(graph) for graph in graphs_list]

# %%
# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Model parameters
input_dim = 3  # Number of node features; BZR dataset has 3D node attributes
hidden_dim = 64  # defines the number of neurons in the GCN layers
output_dim = 2  # Binary classification, so set to 2

# Convert NetworkX graphs to PyTorch Geometric Data objects
full_graph_data = []
for graph_id, nx_graph in graphs.items():
    label = nx_graph.graph['label']
    pyg_data = networkx_to_pyg(nx_graph, label, input_dim)
    full_graph_data.append(pyg_data)

# Extract labels for reference
labels = [data.y.item() for data in full_graph_data]
labels = np.array(labels)
print("BZR dataset processed successfully.")
# Out:
# Using device: cpu
# BZR dataset processed successfully.

# %%
print("\nStarting Bayesian Optimization for Hyperparameter Tuning...")
start_time = time.time()

# Create Optuna study
study = optuna.create_study(
    direction='maximize',
    sampler=TPESampler(seed=42),
    pruner=optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=2)
)

# Optimize hyperparameters
study.optimize(
    lambda trial: objective(trial, full_graph_data, labels, device, input_dim, hidden_dim, output_dim),
    n_trials=50 
)

optimization_time = time.time() - start_time

# Print best hyperparameters
print("\n" + "=" * 60)
print("BAYESIAN OPTIMIZATION RESULTS")
print("=" * 60)
print(f"Best trial: {study.best_trial.number}")
print(f"Best accuracy: {study.best_trial.value:.4f}")
print("Best hyperparameters:")
for key, value in study.best_trial.params.items():
    print(f"  {key}: {value}")

print(f"\nOptimization time: {optimization_time:.2f} seconds")

# Train final model with best hyperparameters
print("\n" + "=" * 60)
print("TRAINING FINAL MODEL WITH BEST HYPERPARAMETERS")
print("=" * 60)

best_params = study.best_trial.params
final_num_epochs = best_params['num_epochs']
final_learning_rate = best_params['learning_rate']
final_batch_size = best_params['batch_size']

# 5-fold cross validation with best parameters
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
all_results = []

for fold, (train_idx, test_idx) in enumerate(kfold.split(full_graph_data, labels)):
    print(f"\n--- Final Training Fold {fold + 1}/5 ---")
    
    # Split data
    train_graphs = [full_graph_data[i] for i in train_idx]
    test_graphs = [full_graph_data[i] for i in test_idx]
    
    # Create data loaders
    train_loader = DataLoader(train_graphs, batch_size=final_batch_size, shuffle=True)
    test_loader = DataLoader(test_graphs, batch_size=final_batch_size, shuffle=False)
    
    # Initialize model
    model = GraphNeuralNetwork(input_dim, hidden_dim, output_dim).to(device)
    optimizer = optim.Adam(model.parameters(), lr=final_learning_rate)
    criterion = nn.CrossEntropyLoss()
    
    # Training loop
    for epoch in range(final_num_epochs):
        train_loss = train_model(model, train_loader, optimizer, criterion, device)
        
        if (epoch + 1) % 10 == 0:
            print(f"Epoch {epoch + 1}/{final_num_epochs}, Loss: {train_loss:.4f}")
    
    # Final evaluation
    y_pred, y_true = evaluate_model(model, test_loader, device)
    overall_acc, class_1_acc, class_neg1_acc, f1 = calculate_metrics(y_true, y_pred)
    
    results = {
        'fold': fold + 1,
        'overall_accuracy': overall_acc,
        'class_1_accuracy': class_1_acc,
        'class_-1_accuracy': class_neg1_acc,
        'f1_score': f1
    }
    
    all_results.append(results)
    
    print(f"Results for Fold {fold + 1}:")
    print(f"  Overall Accuracy: {overall_acc:.4f}")
    print(f"  Class +1 Accuracy: {class_1_acc:.4f}")
    print(f"  Class -1 Accuracy: {class_neg1_acc:.4f}")
    print(f"  F1 Score: {f1:.4f}")

# Calculate final average metrics
avg_overall_acc = np.mean([r['overall_accuracy'] for r in all_results])
avg_class_1_acc = np.mean([r['class_1_accuracy'] for r in all_results])
avg_class_neg1_acc = np.mean([r['class_-1_accuracy'] for r in all_results])
avg_f1 = np.mean([r['f1_score'] for r in all_results])

std_overall_acc = np.std([r['overall_accuracy'] for r in all_results])
std_class_1_acc = np.std([r['class_1_accuracy'] for r in all_results])
std_class_neg1_acc = np.std([r['class_-1_accuracy'] for r in all_results])
std_f1 = np.std([r['f1_score'] for r in all_results])

total_time = time.time() - start_time

print("\n" + "=" * 60)
print("FINAL RESULTS WITH OPTIMIZED HYPERPARAMETERS")
print("=" * 60)
print(f"Best hyperparameters used:")
print(f"  Epochs: {final_num_epochs}")
print(f"  Learning Rate: {final_learning_rate:.6f}")
print(f"  Batch Size: {final_batch_size}")
print(f"\nFinal Cross-Validation Results:")
print(f"Average Overall Accuracy: {avg_overall_acc:.4f} ± {std_overall_acc:.4f}")
print(f"Average Class +1 Accuracy: {avg_class_1_acc:.4f} ± {std_class_1_acc:.4f}")
print(f"Average Class -1 Accuracy: {avg_class_neg1_acc:.4f} ± {std_class_neg1_acc:.4f}")
print(f"Average F1 Score: {avg_f1:.4f} ± {std_f1:.4f}")
print(f"\nTotal Time (Optimization + Final Training): {total_time:.2f} seconds")
# Out:
# [I 2025-07-28 17:50:23,040] A new study created in memory with name: no-name-35bad70b-ab13-423d-9d29-b098fecbb502
# Starting Bayesian Optimization for Hyperparameter Tuning...
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-07-28 17:50:50,042] Trial 0 finished with value: 0.7877439024390245 and parameters: {'num_epochs': 50, 'learning_rate': 0.0711447600934342, 'batch_size': 16}. Best is trial 0 with value: 0.7877439024390245.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-07-28 17:51:06,374] Trial 1 finished with value: 0.7877439024390245 and parameters: {'num_epochs': 30, 'learning_rate': 0.00014936568554617635, 'batch_size': 16}. Best is trial 0 with value: 0.7877439024390245.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-07-28 17:51:17,178] Trial 2 finished with value: 0.7877439024390245 and parameters: {'num_epochs': 20, 'learning_rate': 0.0812324508558869, 'batch_size': 16}. Best is trial 0 with value: 0.7877439024390245.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-07-28 17:51:33,360] Trial 3 finished with value: 0.8248780487804878 and parameters: {'num_epochs': 30, 'learning_rate': 0.0008179499475211679, 'batch_size': 16}. Best is trial 3 with value: 0.8248780487804878.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-07-28 17:51:53,720] Trial 4 finished with value: 0.8150609756097561 and parameters: {'num_epochs': 70, 'learning_rate': 0.00026210878782654407, 'batch_size': 64}. Best is trial 3 with value: 0.8248780487804878.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-07-28 17:52:26,906] Trial 5 finished with value: 0.8201219512195121 and parameters: {'num_epochs': 90, 'learning_rate': 0.0003972110727381916, 'batch_size': 32}. Best is trial 3 with value: 0.8248780487804878.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-07-28 17:52:47,347] Trial 6 finished with value: 0.8199390243902439 and parameters: {'num_epochs': 70, 'learning_rate': 0.00032476735706274504, 'batch_size': 64}. Best is trial 3 with value: 0.8248780487804878.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-07-28 17:53:20,555] Trial 7 finished with value: 0.8275 and parameters: {'num_epochs': 90, 'learning_rate': 0.0008200518402245837, 'batch_size': 32}. Best is trial 7 with value: 0.8275.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-07-28 17:53:31,689] Trial 8 finished with value: 0.8175609756097562 and parameters: {'num_epochs': 30, 'learning_rate': 0.0030586566669785274, 'batch_size': 32}. Best is trial 7 with value: 0.8275.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-07-28 17:53:57,584] Trial 9 finished with value: 0.8200609756097561 and parameters: {'num_epochs': 70, 'learning_rate': 0.0008612579192594886, 'batch_size': 32}. Best is trial 7 with value: 0.8275.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-07-28 17:54:34,488] Trial 10 finished with value: 0.8248170731707317 and parameters: {'num_epochs': 100, 'learning_rate': 0.012578389235983674, 'batch_size': 32}. Best is trial 7 with value: 0.8275.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-07-28 17:55:02,544] Trial 11 finished with value: 0.8225 and parameters: {'num_epochs': 50, 'learning_rate': 0.0017541719409627549, 'batch_size': 16}. Best is trial 7 with value: 0.8275.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-07-28 17:55:35,765] Trial 12 finished with value: 0.8421951219512195 and parameters: {'num_epochs': 90, 'learning_rate': 0.008622027702016937, 'batch_size': 32}. Best is trial 12 with value: 0.8421951219512195.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-07-28 17:56:12,636] Trial 13 finished with value: 0.8296951219512196 and parameters: {'num_epochs': 100, 'learning_rate': 0.010703919912979186, 'batch_size': 32}. Best is trial 12 with value: 0.8421951219512195.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-07-28 17:56:49,533] Trial 14 finished with value: 0.8225609756097562 and parameters: {'num_epochs': 100, 'learning_rate': 0.013196020607150267, 'batch_size': 32}. Best is trial 12 with value: 0.8421951219512195.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-07-28 17:57:22,756] Trial 15 finished with value: 0.8173780487804878 and parameters: {'num_epochs': 90, 'learning_rate': 0.01174008577767313, 'batch_size': 32}. Best is trial 12 with value: 0.8421951219512195.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-07-28 17:57:52,294] Trial 16 finished with value: 0.8199390243902439 and parameters: {'num_epochs': 80, 'learning_rate': 0.030180762645401437, 'batch_size': 32}. Best is trial 12 with value: 0.8421951219512195.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-07-28 17:58:21,505] Trial 17 finished with value: 0.8397560975609757 and parameters: {'num_epochs': 100, 'learning_rate': 0.00627888848820695, 'batch_size': 64}. Best is trial 12 with value: 0.8421951219512195.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-07-28 17:58:44,804] Trial 18 finished with value: 0.8225609756097562 and parameters: {'num_epochs': 80, 'learning_rate': 0.004851641292364678, 'batch_size': 64}. Best is trial 12 with value: 0.8421951219512195.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-07-28 17:59:02,284] Trial 19 finished with value: 0.8200609756097561 and parameters: {'num_epochs': 60, 'learning_rate': 0.004541910565568149, 'batch_size': 64}. Best is trial 12 with value: 0.8421951219512195.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# ...
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-07-28 18:12:07,683] Trial 45 finished with value: 0.8298780487804878 and parameters: {'num_epochs': 70, 'learning_rate': 0.0032183693882877934, 'batch_size': 16}. Best is trial 38 with value: 0.8495731707317074.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-07-28 18:12:17,788] Trial 46 pruned.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-07-28 18:12:43,763] Trial 47 finished with value: 0.8198170731707318 and parameters: {'num_epochs': 70, 'learning_rate': 0.0025689233587428252, 'batch_size': 32}. Best is trial 38 with value: 0.8495731707317074.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-07-28 18:13:28,581] Trial 48 finished with value: 0.8345731707317073 and parameters: {'num_epochs': 80, 'learning_rate': 0.014704480695575377, 'batch_size': 16}. Best is trial 38 with value: 0.8495731707317074.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-07-28 18:13:54,525] Trial 49 finished with value: 0.8445731707317072 and parameters: {'num_epochs': 70, 'learning_rate': 0.009678392810518683, 'batch_size': 32}. Best is trial 38 with value: 0.8495731707317074.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# ============================================================
# BAYESIAN OPTIMIZATION RESULTS
# ============================================================
# Best trial: 38
# Best accuracy: 0.8496
# Best hyperparameters:
#   num_epochs: 70
#   learning_rate: 0.007898469069882834
#   batch_size: 16
#
# Optimization time: 1411.49 seconds
#
# ============================================================
# TRAINING FINAL MODEL WITH BEST HYPERPARAMETERS
# ============================================================
#
# --- Final Training Fold 1/5 ---
# Epoch 10/70, Loss: 0.5063
# Epoch 20/70, Loss: 0.4788
# Epoch 30/70, Loss: 0.4488
# Epoch 40/70, Loss: 0.4010
# Epoch 50/70, Loss: 0.3938
# Epoch 60/70, Loss: 0.4199
# Epoch 70/70, Loss: 0.3901
# Results for Fold 1:
#   Overall Accuracy: 0.8537
#   Class +1 Accuracy: 0.4444
#   Class -1 Accuracy: 0.9688
#   F1 Score: 0.8371
#
# --- Final Training Fold 2/5 ---
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Epoch 10/70, Loss: 0.4468
# Epoch 20/70, Loss: 0.3981
# Epoch 30/70, Loss: 0.3843
# Epoch 40/70, Loss: 0.4454
# Epoch 50/70, Loss: 0.3752
# Epoch 60/70, Loss: 0.4173
# Epoch 70/70, Loss: 0.3549
# Results for Fold 2:
#   Overall Accuracy: 0.7805
#   Class +1 Accuracy: 0.5556
#   Class -1 Accuracy: 0.8438
#   F1 Score: 0.7845
#
# --- Final Training Fold 3/5 ---
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Epoch 10/70, Loss: 0.4240
# Epoch 20/70, Loss: 0.4048
# Epoch 30/70, Loss: 0.3979
# Epoch 40/70, Loss: 0.3829
# Epoch 50/70, Loss: 0.3735
# Epoch 60/70, Loss: 0.3898
# Epoch 70/70, Loss: 0.3656
# Results for Fold 3:
#   Overall Accuracy: 0.7805
#   Class +1 Accuracy: 0.1111
#   Class -1 Accuracy: 0.9688
#   F1 Score: 0.7215
#
# --- Final Training Fold 4/5 ---
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Epoch 10/70, Loss: 0.4560
# Epoch 20/70, Loss: 0.4220
# Epoch 30/70, Loss: 0.4286
# Epoch 40/70, Loss: 0.3899
# Epoch 50/70, Loss: 0.3865
# Epoch 60/70, Loss: 0.3943
# Epoch 70/70, Loss: 0.3741
# Results for Fold 4:
#   Overall Accuracy: 0.8293
#   Class +1 Accuracy: 0.3333
#   Class -1 Accuracy: 0.9688
#   F1 Score: 0.8026
#
# --- Final Training Fold 5/5 ---
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Epoch 10/70, Loss: 0.4366
# Epoch 20/70, Loss: 0.4293
# Epoch 30/70, Loss: 0.3925
# Epoch 40/70, Loss: 0.4325
# Epoch 50/70, Loss: 0.3759
# Epoch 60/70, Loss: 0.3594
# Epoch 70/70, Loss: 0.3568
# Results for Fold 5:
#   Overall Accuracy: 0.8049
#   Class +1 Accuracy: 0.2222
#   Class -1 Accuracy: 0.9688
#   F1 Score: 0.7645
#
# --- Final Training Fold 6/5 ---
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Epoch 10/70, Loss: 0.4649
# Epoch 20/70, Loss: 0.4545
# Epoch 30/70, Loss: 0.4394
# Epoch 40/70, Loss: 0.3957
# Epoch 50/70, Loss: 0.4014
# Epoch 60/70, Loss: 0.3812
# Epoch 70/70, Loss: 0.3838
# Results for Fold 6:
#   Overall Accuracy: 0.9000
#   Class +1 Accuracy: 0.5000
#   Class -1 Accuracy: 1.0000
#   F1 Score: 0.8863
#
# --- Final Training Fold 7/5 ---
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Epoch 10/70, Loss: 0.4449
# Epoch 20/70, Loss: 0.4077
# Epoch 30/70, Loss: 0.4170
# Epoch 40/70, Loss: 0.3883
# Epoch 50/70, Loss: 0.4017
# Epoch 60/70, Loss: 0.4042
# Epoch 70/70, Loss: 0.3985
# Results for Fold 7:
#   Overall Accuracy: 0.9000
#   Class +1 Accuracy: 0.6250
#   Class -1 Accuracy: 0.9688
#   F1 Score: 0.8944
#
# --- Final Training Fold 8/5 ---
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Epoch 10/70, Loss: 0.4653
# Epoch 20/70, Loss: 0.4177
# Epoch 30/70, Loss: 0.3972
# Epoch 40/70, Loss: 0.3874
# Epoch 50/70, Loss: 0.3572
# Epoch 60/70, Loss: 0.3708
# Epoch 70/70, Loss: 0.3645
# Results for Fold 8:
#   Overall Accuracy: 0.7750
#   Class +1 Accuracy: 0.1250
#   Class -1 Accuracy: 0.9375
#   F1 Score: 0.7320
#
# --- Final Training Fold 9/5 ---
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Epoch 10/70, Loss: 0.4769
# Epoch 20/70, Loss: 0.4242
# Epoch 30/70, Loss: 0.4076
# Epoch 40/70, Loss: 0.3915
# Epoch 50/70, Loss: 0.4215
# Epoch 60/70, Loss: 0.3828
# Epoch 70/70, Loss: 0.3984
# Results for Fold 9:
#   Overall Accuracy: 0.8250
#   Class +1 Accuracy: 0.1250
#   Class -1 Accuracy: 1.0000
#   F1 Score: 0.7656
#
# --- Final Training Fold 10/5 ---
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Epoch 10/70, Loss: 0.4751
# Epoch 20/70, Loss: 0.3920
# Epoch 30/70, Loss: 0.4308
# Epoch 40/70, Loss: 0.3972
# Epoch 50/70, Loss: 0.4106
# Epoch 60/70, Loss: 0.3867
# Epoch 70/70, Loss: 0.3391
# Results for Fold 10:
#   Overall Accuracy: 0.8000
#   Class +1 Accuracy: 0.1111
#   Class -1 Accuracy: 1.0000
#   F1 Score: 0.7314
#
# ============================================================
# FINAL RESULTS WITH OPTIMIZED HYPERPARAMETERS
# ============================================================
# Best hyperparameters used:
#   Epochs: 70
#   Learning Rate: 0.007898
#   Batch Size: 16
#
# Final Cross-Validation Results:
# Average Overall Accuracy: 0.8249 ± 0.0443
# Average Class +1 Accuracy: 0.3153 ± 0.1922
# Average Class -1 Accuracy: 0.9625 ± 0.0437
# Average F1 Score: 0.7920 ± 0.0594
#
# Total Time (Optimization + Final Training): 1450.82 seconds

# %%
# Create visualizer with optimization results
visualizer = GCNResultsVisualizer(
    study=study, 
    all_results=all_results, 
    best_params=study.best_trial.params
)

# Generate core optimization visualizations
visualizer.plot_optimization_history()
visualizer.plot_hyperparameter_relationships()
visualizer.plot_cross_validation_results()

# For the final model evaluation with the best parameters
print("\nTraining final model for detailed evaluation...")

# Use the entire dataset for final model evaluation
final_train_loader = DataLoader(full_graph_data, batch_size=final_batch_size, shuffle=True)
final_model = GraphNeuralNetwork(input_dim, hidden_dim, output_dim).to(device)
final_optimizer = optim.Adam(final_model.parameters(), lr=final_learning_rate)
final_criterion = nn.CrossEntropyLoss()

# Train the final model
for epoch in range(final_num_epochs):
    train_loss = train_model(final_model, final_train_loader, final_optimizer, final_criterion, device)

# Get predictions and probabilities for visualization
final_y_true, final_y_scores = get_model_probabilities(final_model, final_train_loader, device)
final_y_pred = np.argmax(final_y_scores, axis=1) * 2 - 1  # Convert back to {-1, 1}

# Generate performance visualizations
visualizer.plot_confusion_matrix(final_y_true, final_y_pred)
visualizer.plot_roc_curve(final_y_true, final_y_scores)

# Visualize sample graphs
visualizer.plot_sample_graphs(graphs_list, labels_list)

print("All visualizations have been generated and saved!")
# Out:
# Training final model for detailed evaluation...
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# All visualizations have been generated and saved!
