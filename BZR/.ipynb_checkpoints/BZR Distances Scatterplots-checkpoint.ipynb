# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import ot
import pandas as pd
import time
import random
from gwgraphs import *
from scipy.stats import ttest_ind

# %%
np.random.seed(42)
random.seed(42)

# %%
# Read and Process Graph Data #
def read_graph_data():
    # Read the adjacency matrix (edges)
    with open("BZR_A.txt", "r") as f:
        edges = [tuple(map(int, line.split(','))) for line in f]

    # Read graph indicators
    with open("BZR_graph_indicator.txt", "r") as f:
        graph_indicators = [int(line.strip()) for line in f if line.strip()]

    # Read graph labels
    with open("BZR_graph_labels.txt", "r") as f:
        graph_labels = [int(line.strip()) for line in f]

    # Read node labels
    with open("BZR_node_labels.txt", "r") as f:
        node_labels = [int(line.strip()) for line in f]

    # Read node attributes
    with open("BZR_node_attributes.txt", "r") as f:
        node_attributes = [
            list(map(float,
                     line.strip().split(','))) for line in f if line.strip()
        ]

    return edges, graph_indicators, graph_labels, node_labels, node_attributes


def normalize_features(features):
    features = np.array(features)
    # Normalize each feature dimension independently
    mean = np.mean(features, axis=0)
    std = np.std(features, axis=0)
    # Avoid division by zero
    std[std == 0] = 1
    normalized_features = (features - mean) / std
    return normalized_features.tolist()


def construct_networkx_graph(edges, graph_indicators, graph_labels,
                             node_labels, node_attributes):
    graphs = {}
    graphs_normalized = {}
    
    # Normalize all node attributes
    normalized_attributes = normalize_features(node_attributes)
    
    for node_id, graph_id in enumerate(graph_indicators, start=1):
        if graph_id not in graphs:
            graphs[graph_id] = nx.Graph(label=graph_labels[graph_id - 1])
            graphs_normalized[graph_id] = nx.Graph(label=graph_labels[graph_id - 1])

    for edge in edges:
        node1, node2 = edge
        graph_id = graph_indicators[
            node1 - 1]  # Determine which graph the edge belongs to
        graphs[graph_id].add_edge(node1, node2)
        graphs_normalized[graph_id].add_edge(node1, node2)

    for node_id, (graph_id, node_label,
                  node_attr, norm_attr) in enumerate(zip(graph_indicators, node_labels,
                                              node_attributes, normalized_attributes),
                                          start=1):
        # Original graphs with original features
        graphs[graph_id].nodes[node_id]['label'] = node_label
        graphs[graph_id].nodes[node_id]['attributes'] = node_attr
        
        # Normalized graphs with normalized features
        graphs_normalized[graph_id].nodes[node_id]['label'] = node_label
        graphs_normalized[graph_id].nodes[node_id]['attributes'] = norm_attr

    return graphs, graphs_normalized


def compute_bzr_distance_matrix(graph):
    num_nodes = len(graph.nodes)
    distance_matrix = np.full((num_nodes, num_nodes), 10000.0)

    # Get the correct node indices to be used for indexing the matrix
    node_list = list(graph.nodes())
    node_index = {node: i for i, node in enumerate(node_list)}

    for node in graph.nodes:
        lengths = nx.shortest_path_length(graph, source=node, weight="weight")

        for target, length in lengths.items():
            if target in node_index:
                distance_matrix[node_index[node], node_index[target]] = length

    return distance_matrix

# %%
edges, graph_indicators, graph_labels, node_labels, node_attributes = read_graph_data(
)
graphs, graphs_normalized = construct_networkx_graph(edges, graph_indicators, graph_labels,
                                                   node_labels, node_attributes)
for graph_id, graph in graphs.items():
    print(
        f"Graph ID: {graph_id}, number of nodes: {graph.number_of_nodes()}, label: {graph.graph['label']}"
    )
# Out:
# Graph ID: 1, number of nodes: 30, label: -1
# Graph ID: 2, number of nodes: 33, label: -1
# Graph ID: 3, number of nodes: 30, label: -1
# Graph ID: 4, number of nodes: 33, label: -1
# Graph ID: 5, number of nodes: 30, label: -1
# Graph ID: 6, number of nodes: 33, label: -1
# Graph ID: 7, number of nodes: 30, label: -1
# Graph ID: 8, number of nodes: 30, label: -1
# Graph ID: 9, number of nodes: 33, label: -1
# Graph ID: 10, number of nodes: 30, label: -1
# Graph ID: 11, number of nodes: 30, label: -1
# Graph ID: 12, number of nodes: 30, label: -1
# Graph ID: 13, number of nodes: 33, label: -1
# Graph ID: 14, number of nodes: 33, label: -1
# Graph ID: 15, number of nodes: 33, label: -1
# Graph ID: 16, number of nodes: 33, label: -1
# Graph ID: 17, number of nodes: 32, label: -1
# Graph ID: 18, number of nodes: 32, label: -1
# Graph ID: 19, number of nodes: 32, label: -1
# Graph ID: 20, number of nodes: 35, label: -1
# Graph ID: 21, number of nodes: 32, label: -1
# Graph ID: 22, number of nodes: 35, label: -1
# Graph ID: 23, number of nodes: 35, label: -1
# Graph ID: 24, number of nodes: 36, label: -1
# Graph ID: 25, number of nodes: 32, label: -1
# Graph ID: 26, number of nodes: 35, label: -1
# Graph ID: 27, number of nodes: 35, label: -1
# Graph ID: 28, number of nodes: 32, label: -1
# Graph ID: 29, number of nodes: 37, label: 1
# Graph ID: 30, number of nodes: 42, label: -1
# Graph ID: 31, number of nodes: 38, label: 1
# Graph ID: 32, number of nodes: 34, label: -1
# Graph ID: 33, number of nodes: 34, label: -1
# Graph ID: 34, number of nodes: 36, label: -1
# Graph ID: 35, number of nodes: 34, label: -1
# Graph ID: 36, number of nodes: 32, label: -1
# Graph ID: 37, number of nodes: 35, label: -1
# Graph ID: 38, number of nodes: 41, label: 1
# Graph ID: 39, number of nodes: 30, label: -1
# Graph ID: 40, number of nodes: 30, label: -1
# Graph ID: 41, number of nodes: 30, label: -1
# Graph ID: 42, number of nodes: 33, label: -1
# Graph ID: 43, number of nodes: 33, label: -1
# Graph ID: 44, number of nodes: 30, label: -1
# Graph ID: 45, number of nodes: 33, label: -1
# Graph ID: 46, number of nodes: 30, label: -1
# Graph ID: 47, number of nodes: 33, label: -1
# Graph ID: 48, number of nodes: 33, label: -1
# Graph ID: 49, number of nodes: 33, label: -1
# Graph ID: 50, number of nodes: 33, label: -1
# Graph ID: 51, number of nodes: 30, label: -1
# Graph ID: 52, number of nodes: 33, label: -1
# Graph ID: 53, number of nodes: 30, label: -1
# Graph ID: 54, number of nodes: 33, label: -1
# Graph ID: 55, number of nodes: 35, label: 1
# Graph ID: 56, number of nodes: 38, label: -1
# Graph ID: 57, number of nodes: 42, label: -1
# Graph ID: 58, number of nodes: 36, label: -1
# Graph ID: 59, number of nodes: 35, label: -1
# Graph ID: 60, number of nodes: 40, label: -1
# Graph ID: 61, number of nodes: 39, label: -1
# Graph ID: 62, number of nodes: 42, label: -1
# Graph ID: 63, number of nodes: 43, label: 1
# Graph ID: 64, number of nodes: 38, label: -1
# Graph ID: 65, number of nodes: 50, label: -1
# Graph ID: 66, number of nodes: 37, label: -1
# Graph ID: 67, number of nodes: 38, label: -1
# Graph ID: 68, number of nodes: 44, label: -1
# Graph ID: 69, number of nodes: 41, label: -1
# Graph ID: 70, number of nodes: 42, label: -1
# Graph ID: 71, number of nodes: 44, label: -1
# Graph ID: 72, number of nodes: 36, label: 1
# Graph ID: 73, number of nodes: 23, label: 1
# Graph ID: 74, number of nodes: 34, label: -1
# Graph ID: 75, number of nodes: 37, label: -1
# Graph ID: 76, number of nodes: 36, label: -1
# Graph ID: 77, number of nodes: 29, label: -1
# Graph ID: 78, number of nodes: 36, label: -1
# Graph ID: 79, number of nodes: 33, label: 1
# Graph ID: 80, number of nodes: 33, label: -1
# Graph ID: 81, number of nodes: 35, label: -1
# Graph ID: 82, number of nodes: 38, label: -1
# Graph ID: 83, number of nodes: 39, label: 1
# Graph ID: 84, number of nodes: 33, label: -1
# Graph ID: 85, number of nodes: 31, label: -1
# Graph ID: 86, number of nodes: 34, label: -1
# Graph ID: 87, number of nodes: 31, label: -1
# Graph ID: 88, number of nodes: 42, label: -1
# Graph ID: 89, number of nodes: 44, label: -1
# Graph ID: 90, number of nodes: 33, label: -1
# Graph ID: 91, number of nodes: 33, label: -1
# Graph ID: 92, number of nodes: 27, label: -1
# Graph ID: 93, number of nodes: 27, label: -1
# Graph ID: 94, number of nodes: 27, label: -1
# Graph ID: 95, number of nodes: 27, label: -1
# Graph ID: 96, number of nodes: 34, label: -1
# Graph ID: 97, number of nodes: 32, label: 1
# Graph ID: 98, number of nodes: 32, label: 1
# Graph ID: 99, number of nodes: 35, label: 1
# Graph ID: 100, number of nodes: 38, label: 1
# Graph ID: 101, number of nodes: 37, label: -1
# Graph ID: 102, number of nodes: 35, label: -1
# Graph ID: 103, number of nodes: 31, label: -1
# Graph ID: 104, number of nodes: 34, label: -1
# Graph ID: 105, number of nodes: 40, label: 1
# Graph ID: 106, number of nodes: 37, label: 1
# Graph ID: 107, number of nodes: 43, label: 1
# Graph ID: 108, number of nodes: 33, label: 1
# Graph ID: 109, number of nodes: 38, label: -1
# Graph ID: 110, number of nodes: 57, label: -1
# Graph ID: 111, number of nodes: 46, label: 1
# Graph ID: 112, number of nodes: 34, label: -1
# Graph ID: 113, number of nodes: 31, label: -1
# Graph ID: 114, number of nodes: 35, label: -1
# Graph ID: 115, number of nodes: 32, label: -1
# Graph ID: 116, number of nodes: 35, label: -1
# Graph ID: 117, number of nodes: 35, label: -1
# Graph ID: 118, number of nodes: 36, label: -1
# Graph ID: 119, number of nodes: 43, label: -1
# Graph ID: 120, number of nodes: 46, label: -1
# Graph ID: 121, number of nodes: 38, label: -1
# Graph ID: 122, number of nodes: 40, label: -1
# Graph ID: 123, number of nodes: 40, label: -1
# Graph ID: 124, number of nodes: 32, label: -1
# Graph ID: 125, number of nodes: 38, label: -1
# Graph ID: 126, number of nodes: 32, label: -1
# Graph ID: 127, number of nodes: 32, label: -1
# Graph ID: 128, number of nodes: 32, label: -1
# Graph ID: 129, number of nodes: 34, label: -1
# Graph ID: 130, number of nodes: 36, label: -1
# Graph ID: 131, number of nodes: 37, label: -1
# Graph ID: 132, number of nodes: 42, label: -1
# Graph ID: 133, number of nodes: 48, label: -1
# Graph ID: 134, number of nodes: 39, label: -1
# Graph ID: 135, number of nodes: 46, label: -1
# Graph ID: 136, number of nodes: 36, label: -1
# Graph ID: 137, number of nodes: 37, label: -1
# Graph ID: 138, number of nodes: 37, label: -1
# Graph ID: 139, number of nodes: 48, label: -1
# Graph ID: 140, number of nodes: 54, label: -1
# Graph ID: 141, number of nodes: 31, label: -1
# Graph ID: 142, number of nodes: 33, label: -1
# Graph ID: 143, number of nodes: 36, label: -1
# Graph ID: 144, number of nodes: 36, label: -1
# Graph ID: 145, number of nodes: 33, label: -1
# Graph ID: 146, number of nodes: 36, label: -1
# Graph ID: 147, number of nodes: 38, label: -1
# Graph ID: 148, number of nodes: 38, label: -1
# Graph ID: 149, number of nodes: 38, label: -1
# Graph ID: 150, number of nodes: 40, label: -1
# Graph ID: 151, number of nodes: 43, label: -1
# Graph ID: 152, number of nodes: 43, label: -1
# Graph ID: 153, number of nodes: 43, label: -1
# Graph ID: 154, number of nodes: 38, label: -1
# Graph ID: 155, number of nodes: 34, label: -1
# Graph ID: 156, number of nodes: 30, label: -1
# Graph ID: 157, number of nodes: 37, label: -1
# Graph ID: 158, number of nodes: 37, label: -1
# Graph ID: 159, number of nodes: 36, label: -1
# Graph ID: 160, number of nodes: 34, label: -1
# Graph ID: 161, number of nodes: 32, label: -1
# Graph ID: 162, number of nodes: 32, label: -1
# Graph ID: 163, number of nodes: 32, label: -1
# Graph ID: 164, number of nodes: 32, label: -1
# Graph ID: 165, number of nodes: 32, label: -1
# Graph ID: 166, number of nodes: 35, label: 1
# Graph ID: 167, number of nodes: 35, label: -1
# Graph ID: 168, number of nodes: 40, label: -1
# Graph ID: 169, number of nodes: 40, label: -1
# Graph ID: 170, number of nodes: 40, label: -1
# Graph ID: 171, number of nodes: 50, label: -1
# Graph ID: 172, number of nodes: 52, label: -1
# Graph ID: 173, number of nodes: 49, label: -1
# Graph ID: 174, number of nodes: 46, label: -1
# Graph ID: 175, number of nodes: 50, label: -1
# Graph ID: 176, number of nodes: 46, label: -1
# Graph ID: 177, number of nodes: 46, label: -1
# Graph ID: 178, number of nodes: 46, label: -1
# Graph ID: 179, number of nodes: 46, label: -1
# Graph ID: 180, number of nodes: 46, label: -1
# Graph ID: 181, number of nodes: 46, label: -1
# Graph ID: 182, number of nodes: 46, label: -1
# Graph ID: 183, number of nodes: 49, label: -1
# Graph ID: 184, number of nodes: 48, label: -1
# Graph ID: 185, number of nodes: 43, label: -1
# Graph ID: 186, number of nodes: 43, label: -1
# Graph ID: 187, number of nodes: 41, label: -1
# Graph ID: 188, number of nodes: 46, label: -1
# Graph ID: 189, number of nodes: 46, label: -1
# Graph ID: 190, number of nodes: 46, label: -1
# Graph ID: 191, number of nodes: 44, label: -1
# Graph ID: 192, number of nodes: 52, label: -1
# Graph ID: 193, number of nodes: 50, label: -1
# Graph ID: 194, number of nodes: 53, label: -1
# Graph ID: 195, number of nodes: 56, label: -1
# Graph ID: 196, number of nodes: 47, label: -1
# Graph ID: 197, number of nodes: 44, label: -1
# Graph ID: 198, number of nodes: 31, label: 1
# Graph ID: 199, number of nodes: 36, label: -1
# Graph ID: 200, number of nodes: 36, label: -1
# Graph ID: 201, number of nodes: 36, label: -1
# Graph ID: 202, number of nodes: 36, label: 1
# Graph ID: 203, number of nodes: 36, label: 1
# Graph ID: 204, number of nodes: 36, label: -1
# Graph ID: 205, number of nodes: 36, label: -1
# Graph ID: 206, number of nodes: 36, label: 1
# Graph ID: 207, number of nodes: 34, label: -1
# Graph ID: 208, number of nodes: 37, label: -1
# Graph ID: 209, number of nodes: 43, label: -1
# Graph ID: 210, number of nodes: 41, label: -1
# Graph ID: 211, number of nodes: 47, label: -1
# Graph ID: 212, number of nodes: 44, label: -1
# Graph ID: 213, number of nodes: 43, label: -1
# Graph ID: 214, number of nodes: 43, label: -1
# Graph ID: 215, number of nodes: 43, label: -1
# Graph ID: 216, number of nodes: 43, label: -1
# Graph ID: 217, number of nodes: 43, label: -1
# Graph ID: 218, number of nodes: 44, label: -1
# Graph ID: 219, number of nodes: 51, label: -1
# Graph ID: 220, number of nodes: 29, label: -1
# Graph ID: 221, number of nodes: 31, label: -1
# Graph ID: 222, number of nodes: 35, label: -1
# Graph ID: 223, number of nodes: 31, label: -1
# Graph ID: 224, number of nodes: 44, label: 1
# Graph ID: 225, number of nodes: 48, label: 1
# Graph ID: 226, number of nodes: 44, label: 1
# Graph ID: 227, number of nodes: 44, label: 1
# Graph ID: 228, number of nodes: 31, label: 1
# Graph ID: 229, number of nodes: 35, label: 1
# Graph ID: 230, number of nodes: 31, label: 1
# Graph ID: 231, number of nodes: 31, label: 1
# Graph ID: 232, number of nodes: 31, label: 1
# Graph ID: 233, number of nodes: 30, label: 1
# Graph ID: 234, number of nodes: 48, label: -1
# Graph ID: 235, number of nodes: 48, label: -1
# Graph ID: 236, number of nodes: 23, label: 1
# Graph ID: 237, number of nodes: 20, label: 1
# Graph ID: 238, number of nodes: 19, label: 1
# Graph ID: 239, number of nodes: 23, label: 1
# Graph ID: 240, number of nodes: 17, label: 1
# Graph ID: 241, number of nodes: 31, label: 1
# Graph ID: 242, number of nodes: 23, label: 1
# Graph ID: 243, number of nodes: 29, label: 1
# Graph ID: 244, number of nodes: 24, label: 1
# Graph ID: 245, number of nodes: 27, label: 1
# Graph ID: 246, number of nodes: 35, label: 1
# Graph ID: 247, number of nodes: 26, label: 1
# Graph ID: 248, number of nodes: 31, label: 1
# Graph ID: 249, number of nodes: 30, label: 1
# Graph ID: 250, number of nodes: 36, label: 1
# Graph ID: 251, number of nodes: 42, label: -1
# Graph ID: 252, number of nodes: 42, label: -1
# Graph ID: 253, number of nodes: 43, label: -1
# Graph ID: 254, number of nodes: 43, label: -1
# Graph ID: 255, number of nodes: 45, label: -1
# Graph ID: 256, number of nodes: 46, label: -1
# Graph ID: 257, number of nodes: 46, label: -1
# Graph ID: 258, number of nodes: 44, label: -1
# Graph ID: 259, number of nodes: 44, label: -1
# Graph ID: 260, number of nodes: 46, label: -1
# Graph ID: 261, number of nodes: 44, label: -1
# Graph ID: 262, number of nodes: 47, label: -1
# Graph ID: 263, number of nodes: 46, label: -1
# Graph ID: 264, number of nodes: 31, label: -1
# Graph ID: 265, number of nodes: 46, label: -1
# Graph ID: 266, number of nodes: 46, label: -1
# Graph ID: 267, number of nodes: 43, label: -1
# Graph ID: 268, number of nodes: 47, label: -1
# Graph ID: 269, number of nodes: 49, label: -1
# Graph ID: 270, number of nodes: 49, label: 1
# Graph ID: 271, number of nodes: 49, label: -1
# Graph ID: 272, number of nodes: 50, label: -1
# Graph ID: 273, number of nodes: 47, label: -1
# Graph ID: 274, number of nodes: 49, label: -1
# Graph ID: 275, number of nodes: 49, label: -1
# Graph ID: 276, number of nodes: 34, label: -1
# Graph ID: 277, number of nodes: 44, label: -1
# Graph ID: 278, number of nodes: 41, label: -1
# Graph ID: 279, number of nodes: 13, label: 1
# Graph ID: 280, number of nodes: 13, label: 1
# Graph ID: 281, number of nodes: 16, label: 1
# Graph ID: 282, number of nodes: 21, label: 1
# Graph ID: 283, number of nodes: 31, label: 1
# Graph ID: 284, number of nodes: 34, label: 1
# Graph ID: 285, number of nodes: 20, label: 1
# Graph ID: 286, number of nodes: 30, label: 1
# Graph ID: 287, number of nodes: 44, label: 1
# Graph ID: 288, number of nodes: 50, label: 1
# Graph ID: 289, number of nodes: 25, label: 1
# Graph ID: 290, number of nodes: 31, label: -1
# Graph ID: 291, number of nodes: 34, label: -1
# Graph ID: 292, number of nodes: 28, label: -1
# Graph ID: 293, number of nodes: 41, label: -1
# Graph ID: 294, number of nodes: 27, label: -1
# Graph ID: 295, number of nodes: 34, label: -1
# Graph ID: 296, number of nodes: 34, label: -1
# Graph ID: 297, number of nodes: 37, label: -1
# Graph ID: 298, number of nodes: 37, label: -1
# Graph ID: 299, number of nodes: 35, label: 1
# Graph ID: 300, number of nodes: 35, label: -1
# Graph ID: 301, number of nodes: 30, label: -1
# Graph ID: 302, number of nodes: 39, label: -1
# Graph ID: 303, number of nodes: 36, label: -1
# Graph ID: 304, number of nodes: 34, label: -1
# Graph ID: 305, number of nodes: 33, label: -1
# Graph ID: 306, number of nodes: 37, label: -1
# Graph ID: 307, number of nodes: 23, label: 1
# Graph ID: 308, number of nodes: 24, label: 1
# Graph ID: 309, number of nodes: 24, label: 1
# Graph ID: 310, number of nodes: 26, label: -1
# Graph ID: 311, number of nodes: 23, label: -1
# Graph ID: 312, number of nodes: 28, label: -1
# Graph ID: 313, number of nodes: 33, label: -1
# Graph ID: 314, number of nodes: 30, label: 1
# Graph ID: 315, number of nodes: 25, label: -1
# Graph ID: 316, number of nodes: 28, label: -1
# Graph ID: 317, number of nodes: 31, label: -1
# Graph ID: 318, number of nodes: 34, label: -1
# Graph ID: 319, number of nodes: 32, label: -1
# Graph ID: 320, number of nodes: 33, label: -1
# Graph ID: 321, number of nodes: 25, label: -1
# Graph ID: 322, number of nodes: 30, label: -1
# Graph ID: 323, number of nodes: 21, label: -1
# Graph ID: 324, number of nodes: 23, label: -1
# Graph ID: 325, number of nodes: 23, label: -1
# Graph ID: 326, number of nodes: 21, label: -1
# Graph ID: 327, number of nodes: 25, label: -1
# Graph ID: 328, number of nodes: 28, label: -1
# Graph ID: 329, number of nodes: 31, label: -1
# Graph ID: 330, number of nodes: 23, label: 1
# Graph ID: 331, number of nodes: 22, label: -1
# Graph ID: 332, number of nodes: 36, label: -1
# Graph ID: 333, number of nodes: 36, label: 1
# Graph ID: 334, number of nodes: 42, label: -1
# Graph ID: 335, number of nodes: 40, label: -1
# Graph ID: 336, number of nodes: 23, label: -1
# Graph ID: 337, number of nodes: 37, label: 1
# Graph ID: 338, number of nodes: 27, label: -1
# Graph ID: 339, number of nodes: 29, label: -1
# Graph ID: 340, number of nodes: 30, label: 1
# Graph ID: 341, number of nodes: 32, label: -1
# Graph ID: 342, number of nodes: 29, label: -1
# Graph ID: 343, number of nodes: 31, label: -1
# Graph ID: 344, number of nodes: 41, label: 1
# Graph ID: 345, number of nodes: 34, label: -1
# Graph ID: 346, number of nodes: 44, label: 1
# Graph ID: 347, number of nodes: 39, label: -1
# Graph ID: 348, number of nodes: 34, label: 1
# Graph ID: 349, number of nodes: 35, label: -1
# Graph ID: 350, number of nodes: 37, label: 1
# Graph ID: 351, number of nodes: 38, label: 1
# Graph ID: 352, number of nodes: 32, label: -1
# Graph ID: 353, number of nodes: 29, label: 1
# Graph ID: 354, number of nodes: 25, label: 1
# Graph ID: 355, number of nodes: 28, label: 1
# Graph ID: 356, number of nodes: 26, label: 1
# Graph ID: 357, number of nodes: 40, label: -1
# Graph ID: 358, number of nodes: 40, label: 1
# Graph ID: 359, number of nodes: 31, label: -1
# Graph ID: 360, number of nodes: 31, label: -1
# Graph ID: 361, number of nodes: 31, label: -1
# Graph ID: 362, number of nodes: 35, label: -1
# Graph ID: 363, number of nodes: 31, label: -1
# Graph ID: 364, number of nodes: 35, label: -1
# Graph ID: 365, number of nodes: 34, label: -1
# Graph ID: 366, number of nodes: 34, label: -1
# Graph ID: 367, number of nodes: 34, label: -1
# Graph ID: 368, number of nodes: 34, label: -1
# Graph ID: 369, number of nodes: 34, label: -1
# Graph ID: 370, number of nodes: 34, label: -1
# Graph ID: 371, number of nodes: 37, label: -1
# Graph ID: 372, number of nodes: 35, label: -1
# Graph ID: 373, number of nodes: 31, label: -1
# Graph ID: 374, number of nodes: 37, label: -1
# Graph ID: 375, number of nodes: 31, label: -1
# Graph ID: 376, number of nodes: 31, label: -1
# Graph ID: 377, number of nodes: 45, label: -1
# Graph ID: 378, number of nodes: 32, label: -1
# Graph ID: 379, number of nodes: 31, label: -1
# Graph ID: 380, number of nodes: 31, label: -1
# Graph ID: 381, number of nodes: 31, label: -1
# Graph ID: 382, number of nodes: 31, label: -1
# Graph ID: 383, number of nodes: 45, label: 1
# Graph ID: 384, number of nodes: 32, label: -1
# Graph ID: 385, number of nodes: 45, label: 1
# Graph ID: 386, number of nodes: 32, label: -1
# Graph ID: 387, number of nodes: 33, label: -1
# Graph ID: 388, number of nodes: 33, label: -1
# Graph ID: 389, number of nodes: 33, label: -1
# Graph ID: 390, number of nodes: 33, label: -1
# Graph ID: 391, number of nodes: 33, label: 1
# Graph ID: 392, number of nodes: 33, label: -1
# Graph ID: 393, number of nodes: 31, label: -1
# Graph ID: 394, number of nodes: 31, label: 1
# Graph ID: 395, number of nodes: 31, label: -1
# Graph ID: 396, number of nodes: 37, label: -1
# Graph ID: 397, number of nodes: 37, label: 1
# Graph ID: 398, number of nodes: 37, label: 1
# Graph ID: 399, number of nodes: 35, label: -1
# Graph ID: 400, number of nodes: 32, label: -1
# Graph ID: 401, number of nodes: 30, label: -1
# Graph ID: 402, number of nodes: 30, label: -1
# Graph ID: 403, number of nodes: 30, label: -1
# Graph ID: 404, number of nodes: 36, label: 1
# Graph ID: 405, number of nodes: 31, label: -1

# %%
graphs_list = []
labels_list = []
for graph_id, graph in graphs.items():
    # Add the graph object to the list
    graphs_list.append(graph)

    # Extract the label and add to the label list
    label = graph.graph['label']
    labels_list.append(label)

# Convert graphs into pairwise distance matrices
distance_matrices = [compute_bzr_distance_matrix(graph) for graph in graphs_list]

# %%
# GW Distances Scatterplots #
# Normalize the matrices
Ms = []
for matrix in distance_matrices:
    Ms.append(matrix / np.max(matrix))

N=405
heights = [
    np.full(len(graph), 1 / len(graph)) for graph in graphs_list
]
gw = np.zeros((N,N))

# Track negative values during computation
negative_count = 0
negative_pairs = []

for i in range(N):
    for j in range(i+1,N):
        tmp = ot.gromov.gromov_wasserstein2(Ms[i],Ms[j],heights[i],heights[j],loss_fun="square_loss",log=True)
        gw_value = tmp[0]
        gw[i,j] = gw_value
        
        # Check for negative values
        if gw_value < 0:
            negative_count += 1
            negative_pairs.append((i, j, gw_value))
            print(f"Negative GW distance found: graphs {i} and {j}, value: {gw_value}")
        
        # Check for NaN values
        if np.isnan(gw_value):
            print(f"NaN GW distance found: graphs {i} and {j}")
        
        #Ps_gw[i,j] = tmp[1]["T"]

# Handle negative values by taking absolute value before sqrt
gw_abs = np.abs(gw)
gw = np.sqrt(gw_abs)
gw += gw.T

print(f"\nGW computation summary:")
print(f"Total negative values found: {negative_count}")
print(f"Min GW value: {np.min(gw[gw != 0])}")
print(f"Max GW value: {np.max(gw)}")
print(f"Number of NaN values: {np.sum(np.isnan(gw))}")

# Print first few negative pairs if any
if negative_pairs:
    print(f"\nFirst 5 negative pairs:")
    for i, (idx_i, idx_j, val) in enumerate(negative_pairs[:5]):
        print(f"  Pair {i+1}: graphs {idx_i} and {idx_j}, value: {val}")
# Out:
# Negative GW distance found: graphs 19 and 21, value: -7.632783294297951e-17
# Negative GW distance found: graphs 19 and 25, value: -7.632783294297951e-17
# Negative GW distance found: graphs 19 and 26, value: -7.632783294297951e-17
# Negative GW distance found: graphs 21 and 25, value: -7.632783294297951e-17
# Negative GW distance found: graphs 21 and 26, value: -7.632783294297951e-17
# Negative GW distance found: graphs 25 and 26, value: -7.632783294297951e-17
# Negative GW distance found: graphs 31 and 32, value: -5.876375774871434e-17
# Negative GW distance found: graphs 55 and 63, value: -4.391018798566293e-18
# Negative GW distance found: graphs 102 and 112, value: -3.469446951953614e-18
# Negative GW distance found: graphs 102 and 140, value: -3.469446951953614e-18
# Negative GW distance found: graphs 112 and 140, value: -3.469446951953614e-18
# Negative GW distance found: graphs 165 and 166, value: -3.8163916471489756e-17
# Negative GW distance found: graphs 208 and 213, value: -1.734723475976807e-17
# Negative GW distance found: graphs 208 and 214, value: -1.734723475976807e-17
# Negative GW distance found: graphs 208 and 215, value: -1.734723475976807e-17
# Negative GW distance found: graphs 213 and 214, value: -1.734723475976807e-17
# Negative GW distance found: graphs 213 and 215, value: -1.734723475976807e-17
# Negative GW distance found: graphs 214 and 215, value: -1.734723475976807e-17
# Negative GW distance found: graphs 220 and 222, value: -1.3877787807814457e-17
# Negative GW distance found: graphs 223 and 225, value: -9.025983085941824e-17
# Negative GW distance found: graphs 223 and 226, value: -9.025983085941824e-17
# Negative GW distance found: graphs 225 and 226, value: -9.025983085941824e-17
# Negative GW distance found: graphs 227 and 229, value: -5.421010862427522e-18
# Negative GW distance found: graphs 227 and 230, value: -5.421010862427522e-18
# Negative GW distance found: graphs 227 and 231, value: -5.421010862427522e-18
# Negative GW distance found: graphs 229 and 230, value: -5.421010862427522e-18
# Negative GW distance found: graphs 229 and 231, value: -5.421010862427522e-18
# Negative GW distance found: graphs 230 and 231, value: -5.421010862427522e-18
# Negative GW distance found: graphs 310 and 323, value: -1.9949319973733282e-17
# Negative GW distance found: graphs 310 and 329, value: -1.9949319973733282e-17
# Negative GW distance found: graphs 322 and 325, value: -1.0148132334464322e-16
# Negative GW distance found: graphs 323 and 329, value: -4.423544863740858e-17
# Negative GW distance found: graphs 338 and 341, value: -3.122502256758253e-17
# Negative GW distance found: graphs 358 and 359, value: -2.0816681711721685e-17
# Negative GW distance found: graphs 358 and 360, value: -2.0816681711721685e-17
# Negative GW distance found: graphs 358 and 362, value: -2.0816681711721685e-17
# Negative GW distance found: graphs 358 and 372, value: -1.734723475976807e-17
# Negative GW distance found: graphs 358 and 374, value: -1.734723475976807e-17
# Negative GW distance found: graphs 358 and 375, value: -1.734723475976807e-17
# Negative GW distance found: graphs 358 and 378, value: -1.734723475976807e-17
# Negative GW distance found: graphs 358 and 379, value: -1.734723475976807e-17
# Negative GW distance found: graphs 358 and 380, value: -1.734723475976807e-17
# Negative GW distance found: graphs 358 and 381, value: -1.734723475976807e-17
# Negative GW distance found: graphs 358 and 392, value: -1.734723475976807e-17
# Negative GW distance found: graphs 358 and 393, value: -1.734723475976807e-17
# Negative GW distance found: graphs 358 and 394, value: -1.734723475976807e-17
# Negative GW distance found: graphs 358 and 404, value: -3.122502256758253e-17
# Negative GW distance found: graphs 359 and 360, value: -2.0816681711721685e-17
# Negative GW distance found: graphs 359 and 362, value: -2.0816681711721685e-17
# Negative GW distance found: graphs 359 and 372, value: -1.734723475976807e-17
# Negative GW distance found: graphs 359 and 374, value: -1.734723475976807e-17
# Negative GW distance found: graphs 359 and 375, value: -1.734723475976807e-17
# Negative GW distance found: graphs 359 and 378, value: -1.734723475976807e-17
# Negative GW distance found: graphs 359 and 379, value: -1.734723475976807e-17
# Negative GW distance found: graphs 359 and 380, value: -1.734723475976807e-17
# Negative GW distance found: graphs 359 and 381, value: -1.734723475976807e-17
# Negative GW distance found: graphs 359 and 392, value: -1.734723475976807e-17
# Negative GW distance found: graphs 359 and 393, value: -1.734723475976807e-17
# Negative GW distance found: graphs 359 and 394, value: -1.734723475976807e-17
# Negative GW distance found: graphs 359 and 404, value: -3.122502256758253e-17
# Negative GW distance found: graphs 360 and 362, value: -2.0816681711721685e-17
# Negative GW distance found: graphs 360 and 372, value: -1.734723475976807e-17
# Negative GW distance found: graphs 360 and 374, value: -1.734723475976807e-17
# Negative GW distance found: graphs 360 and 375, value: -1.734723475976807e-17
# Negative GW distance found: graphs 360 and 378, value: -1.734723475976807e-17
# Negative GW distance found: graphs 360 and 379, value: -1.734723475976807e-17
# Negative GW distance found: graphs 360 and 380, value: -1.734723475976807e-17
# Negative GW distance found: graphs 360 and 381, value: -1.734723475976807e-17
# Negative GW distance found: graphs 360 and 392, value: -1.734723475976807e-17
# Negative GW distance found: graphs 360 and 393, value: -1.734723475976807e-17
# Negative GW distance found: graphs 360 and 394, value: -1.734723475976807e-17
# Negative GW distance found: graphs 360 and 404, value: -3.122502256758253e-17
# Negative GW distance found: graphs 362 and 372, value: -1.734723475976807e-17
# Negative GW distance found: graphs 362 and 374, value: -1.734723475976807e-17
# Negative GW distance found: graphs 362 and 375, value: -1.734723475976807e-17
# Negative GW distance found: graphs 362 and 378, value: -1.734723475976807e-17
# Negative GW distance found: graphs 362 and 379, value: -1.734723475976807e-17
# Negative GW distance found: graphs 362 and 380, value: -1.734723475976807e-17
# Negative GW distance found: graphs 362 and 381, value: -1.734723475976807e-17
# Negative GW distance found: graphs 362 and 392, value: -1.734723475976807e-17
# Negative GW distance found: graphs 362 and 393, value: -1.734723475976807e-17
# Negative GW distance found: graphs 362 and 394, value: -1.734723475976807e-17
# Negative GW distance found: graphs 362 and 404, value: -3.122502256758253e-17
# Negative GW distance found: graphs 372 and 374, value: -3.469446951953614e-18
# Negative GW distance found: graphs 372 and 375, value: -3.469446951953614e-18
# Negative GW distance found: graphs 372 and 378, value: -3.469446951953614e-18
# Negative GW distance found: graphs 372 and 379, value: -3.469446951953614e-18
# Negative GW distance found: graphs 372 and 380, value: -3.469446951953614e-18
# Negative GW distance found: graphs 372 and 381, value: -3.469446951953614e-18
# Negative GW distance found: graphs 372 and 392, value: -3.469446951953614e-18
# Negative GW distance found: graphs 372 and 393, value: -3.469446951953614e-18
# Negative GW distance found: graphs 372 and 394, value: -3.469446951953614e-18
# Negative GW distance found: graphs 374 and 375, value: -3.469446951953614e-18
# Negative GW distance found: graphs 374 and 378, value: -3.469446951953614e-18
# Negative GW distance found: graphs 374 and 379, value: -3.469446951953614e-18
# Negative GW distance found: graphs 374 and 380, value: -3.469446951953614e-18
# Negative GW distance found: graphs 374 and 381, value: -3.469446951953614e-18
# Negative GW distance found: graphs 374 and 392, value: -3.469446951953614e-18
# Negative GW distance found: graphs 374 and 393, value: -3.469446951953614e-18
# Negative GW distance found: graphs 374 and 394, value: -3.469446951953614e-18
# Negative GW distance found: graphs 375 and 378, value: -3.469446951953614e-18
# Negative GW distance found: graphs 375 and 379, value: -3.469446951953614e-18
# Negative GW distance found: graphs 375 and 380, value: -3.469446951953614e-18
# Negative GW distance found: graphs 375 and 381, value: -3.469446951953614e-18
# Negative GW distance found: graphs 375 and 392, value: -3.469446951953614e-18
# Negative GW distance found: graphs 375 and 393, value: -3.469446951953614e-18
# Negative GW distance found: graphs 375 and 394, value: -3.469446951953614e-18
# Negative GW distance found: graphs 378 and 379, value: -3.469446951953614e-18
# Negative GW distance found: graphs 378 and 380, value: -3.469446951953614e-18
# Negative GW distance found: graphs 378 and 381, value: -3.469446951953614e-18
# Negative GW distance found: graphs 378 and 392, value: -3.469446951953614e-18
# Negative GW distance found: graphs 378 and 393, value: -3.469446951953614e-18
# Negative GW distance found: graphs 378 and 394, value: -3.469446951953614e-18
# Negative GW distance found: graphs 379 and 380, value: -3.469446951953614e-18
# Negative GW distance found: graphs 379 and 381, value: -3.469446951953614e-18
# Negative GW distance found: graphs 379 and 392, value: -3.469446951953614e-18
# Negative GW distance found: graphs 379 and 393, value: -3.469446951953614e-18
# Negative GW distance found: graphs 379 and 394, value: -3.469446951953614e-18
# Negative GW distance found: graphs 380 and 381, value: -3.469446951953614e-18
# Negative GW distance found: graphs 380 and 392, value: -3.469446951953614e-18
# Negative GW distance found: graphs 380 and 393, value: -3.469446951953614e-18
# Negative GW distance found: graphs 380 and 394, value: -3.469446951953614e-18
# Negative GW distance found: graphs 381 and 392, value: -3.469446951953614e-18
# Negative GW distance found: graphs 381 and 393, value: -3.469446951953614e-18
# Negative GW distance found: graphs 381 and 394, value: -3.469446951953614e-18
# Negative GW distance found: graphs 392 and 393, value: -3.469446951953614e-18
# Negative GW distance found: graphs 392 and 394, value: -3.469446951953614e-18
# Negative GW distance found: graphs 393 and 394, value: -3.469446951953614e-18
#
# GW computation summary:
# Total negative values found: 128
# Min GW value: 1.6130980174698654e-09
# Max GW value: 0.2792244719922027
# Number of NaN values: 0
#
# First 5 negative pairs:
#   Pair 1: graphs 19 and 21, value: -7.632783294297951e-17
#   Pair 2: graphs 19 and 25, value: -7.632783294297951e-17
#   Pair 3: graphs 19 and 26, value: -7.632783294297951e-17
#   Pair 4: graphs 21 and 25, value: -7.632783294297951e-17
#   Pair 5: graphs 21 and 26, value: -7.632783294297951e-17

# %%
### WHY NEGATIVE DISTANCES? ###
def check_graph_isomorphism(graph1, graph2):
    """Check if two graphs are isomorphic, considering both structure and node labels."""
    # First check structural isomorphism
    if not nx.is_isomorphic(graph1, graph2):
        return False, "Not structurally isomorphic"
    
    # If structurally isomorphic, check if node labels match
    def node_match(n1, n2):
        return n1.get('label', None) == n2.get('label', None)
    
    if nx.is_isomorphic(graph1, graph2, node_match=node_match):
        return True, "Isomorphic with matching node labels"
    else:
        return True, "Structurally isomorphic but different node labels"

print(f"\n=== ISOMORPHISM ANALYSIS FOR NEGATIVE GW PAIRS ===")
if negative_pairs:
    print(f"Analyzing {len(negative_pairs)} pairs with negative GW distances...\n")
    
    isomorphic_count = 0
    structural_iso_count = 0
    same_label_count = 0
    different_label_count = 0
    
    for idx, (i, j, gw_value) in enumerate(negative_pairs):
        graph1 = graphs_list[i]
        graph2 = graphs_list[j]
        
        is_iso, iso_type = check_graph_isomorphism(graph1, graph2)
        
        # Check if classification labels are the same
        label1 = labels_list[i]
        label2 = labels_list[j]
        same_label = label1 == label2
        
        if same_label:
            same_label_count += 1
            label_status = "Same classification label"
        else:
            different_label_count += 1
            label_status = "Different classification labels"
        
        print(f"Pair {idx+1}: Graphs {i} and {j} (GW distance: {gw_value})")
        print(f"  Nodes: {graph1.number_of_nodes()} vs {graph2.number_of_nodes()}")
        print(f"  Edges: {graph1.number_of_edges()} vs {graph2.number_of_edges()}")
        print(f"  Graph labels: {graph1.graph['label']} vs {graph2.graph['label']}")
        print(f"  Classification labels: {label1} vs {label2} ({label_status})")
        print(f"  Isomorphism: {iso_type}")
        
        if "Isomorphic with matching" in iso_type:
            isomorphic_count += 1
        elif "Structurally isomorphic" in iso_type:
            structural_iso_count += 1
        
        print()
    
    print(f"SUMMARY:")
    print(f"  Total negative pairs: {len(negative_pairs)}")
    print(f"  Pairs with same classification label: {same_label_count}")
    print(f"  Pairs with different classification labels: {different_label_count}")
    print(f"  Fully isomorphic (structure + labels): {isomorphic_count}")
    print(f"  Structurally isomorphic only: {structural_iso_count}")
    print(f"  Not isomorphic: {len(negative_pairs) - isomorphic_count - structural_iso_count}")
else:
    print("No negative GW distances found.")
# Out:
# === ISOMORPHISM ANALYSIS FOR NEGATIVE GW PAIRS ===
# Analyzing 128 pairs with negative GW distances...
#
# Pair 1: Graphs 19 and 21 (GW distance: -7.632783294297951e-17)
#   Nodes: 35 vs 35
#   Edges: 37 vs 37
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 2: Graphs 19 and 25 (GW distance: -7.632783294297951e-17)
#   Nodes: 35 vs 35
#   Edges: 37 vs 37
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 3: Graphs 19 and 26 (GW distance: -7.632783294297951e-17)
#   Nodes: 35 vs 35
#   Edges: 37 vs 37
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 4: Graphs 21 and 25 (GW distance: -7.632783294297951e-17)
#   Nodes: 35 vs 35
#   Edges: 37 vs 37
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 5: Graphs 21 and 26 (GW distance: -7.632783294297951e-17)
#   Nodes: 35 vs 35
#   Edges: 37 vs 37
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 6: Graphs 25 and 26 (GW distance: -7.632783294297951e-17)
#   Nodes: 35 vs 35
#   Edges: 37 vs 37
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 7: Graphs 31 and 32 (GW distance: -5.876375774871434e-17)
#   Nodes: 34 vs 34
#   Edges: 36 vs 36
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 8: Graphs 55 and 63 (GW distance: -4.391018798566293e-18)
#   Nodes: 38 vs 38
#   Edges: 40 vs 40
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 9: Graphs 102 and 112 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 33 vs 33
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 10: Graphs 102 and 140 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 33 vs 33
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 11: Graphs 112 and 140 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 33 vs 33
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 12: Graphs 165 and 166 (GW distance: -3.8163916471489756e-17)
#   Nodes: 35 vs 35
#   Edges: 38 vs 38
#   Graph labels: 1 vs -1
#   Classification labels: 1 vs -1 (Different classification labels)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 13: Graphs 208 and 213 (GW distance: -1.734723475976807e-17)
#   Nodes: 43 vs 43
#   Edges: 46 vs 46
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 14: Graphs 208 and 214 (GW distance: -1.734723475976807e-17)
#   Nodes: 43 vs 43
#   Edges: 46 vs 46
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 15: Graphs 208 and 215 (GW distance: -1.734723475976807e-17)
#   Nodes: 43 vs 43
#   Edges: 46 vs 46
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 16: Graphs 213 and 214 (GW distance: -1.734723475976807e-17)
#   Nodes: 43 vs 43
#   Edges: 46 vs 46
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 17: Graphs 213 and 215 (GW distance: -1.734723475976807e-17)
#   Nodes: 43 vs 43
#   Edges: 46 vs 46
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 18: Graphs 214 and 215 (GW distance: -1.734723475976807e-17)
#   Nodes: 43 vs 43
#   Edges: 46 vs 46
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 19: Graphs 220 and 222 (GW distance: -1.3877787807814457e-17)
#   Nodes: 31 vs 31
#   Edges: 34 vs 34
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 20: Graphs 223 and 225 (GW distance: -9.025983085941824e-17)
#   Nodes: 44 vs 44
#   Edges: 48 vs 48
#   Graph labels: 1 vs 1
#   Classification labels: 1 vs 1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 21: Graphs 223 and 226 (GW distance: -9.025983085941824e-17)
#   Nodes: 44 vs 44
#   Edges: 48 vs 48
#   Graph labels: 1 vs 1
#   Classification labels: 1 vs 1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 22: Graphs 225 and 226 (GW distance: -9.025983085941824e-17)
#   Nodes: 44 vs 44
#   Edges: 48 vs 48
#   Graph labels: 1 vs 1
#   Classification labels: 1 vs 1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 23: Graphs 227 and 229 (GW distance: -5.421010862427522e-18)
#   Nodes: 31 vs 31
#   Edges: 34 vs 34
#   Graph labels: 1 vs 1
#   Classification labels: 1 vs 1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 24: Graphs 227 and 230 (GW distance: -5.421010862427522e-18)
#   Nodes: 31 vs 31
#   Edges: 34 vs 34
#   Graph labels: 1 vs 1
#   Classification labels: 1 vs 1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 25: Graphs 227 and 231 (GW distance: -5.421010862427522e-18)
#   Nodes: 31 vs 31
#   Edges: 34 vs 34
#   Graph labels: 1 vs 1
#   Classification labels: 1 vs 1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 26: Graphs 229 and 230 (GW distance: -5.421010862427522e-18)
#   Nodes: 31 vs 31
#   Edges: 34 vs 34
#   Graph labels: 1 vs 1
#   Classification labels: 1 vs 1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 27: Graphs 229 and 231 (GW distance: -5.421010862427522e-18)
#   Nodes: 31 vs 31
#   Edges: 34 vs 34
#   Graph labels: 1 vs 1
#   Classification labels: 1 vs 1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 28: Graphs 230 and 231 (GW distance: -5.421010862427522e-18)
#   Nodes: 31 vs 31
#   Edges: 34 vs 34
#   Graph labels: 1 vs 1
#   Classification labels: 1 vs 1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 29: Graphs 310 and 323 (GW distance: -1.9949319973733282e-17)
#   Nodes: 23 vs 23
#   Edges: 25 vs 25
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 30: Graphs 310 and 329 (GW distance: -1.9949319973733282e-17)
#   Nodes: 23 vs 23
#   Edges: 25 vs 25
#   Graph labels: -1 vs 1
#   Classification labels: -1 vs 1 (Different classification labels)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 31: Graphs 322 and 325 (GW distance: -1.0148132334464322e-16)
#   Nodes: 21 vs 21
#   Edges: 23 vs 23
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 32: Graphs 323 and 329 (GW distance: -4.423544863740858e-17)
#   Nodes: 23 vs 23
#   Edges: 25 vs 25
#   Graph labels: -1 vs 1
#   Classification labels: -1 vs 1 (Different classification labels)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 33: Graphs 338 and 341 (GW distance: -3.122502256758253e-17)
#   Nodes: 29 vs 29
#   Edges: 31 vs 31
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 34: Graphs 358 and 359 (GW distance: -2.0816681711721685e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 35: Graphs 358 and 360 (GW distance: -2.0816681711721685e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 36: Graphs 358 and 362 (GW distance: -2.0816681711721685e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 37: Graphs 358 and 372 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 38: Graphs 358 and 374 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 39: Graphs 358 and 375 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 40: Graphs 358 and 378 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 41: Graphs 358 and 379 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 42: Graphs 358 and 380 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 43: Graphs 358 and 381 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 44: Graphs 358 and 392 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 45: Graphs 358 and 393 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs 1
#   Classification labels: -1 vs 1 (Different classification labels)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 46: Graphs 358 and 394 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 47: Graphs 358 and 404 (GW distance: -3.122502256758253e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Isomorphic with matching node labels
#
# Pair 48: Graphs 359 and 360 (GW distance: -2.0816681711721685e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 49: Graphs 359 and 362 (GW distance: -2.0816681711721685e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 50: Graphs 359 and 372 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 51: Graphs 359 and 374 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 52: Graphs 359 and 375 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 53: Graphs 359 and 378 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 54: Graphs 359 and 379 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 55: Graphs 359 and 380 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 56: Graphs 359 and 381 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 57: Graphs 359 and 392 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 58: Graphs 359 and 393 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs 1
#   Classification labels: -1 vs 1 (Different classification labels)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 59: Graphs 359 and 394 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 60: Graphs 359 and 404 (GW distance: -3.122502256758253e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 61: Graphs 360 and 362 (GW distance: -2.0816681711721685e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 62: Graphs 360 and 372 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 63: Graphs 360 and 374 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 64: Graphs 360 and 375 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 65: Graphs 360 and 378 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 66: Graphs 360 and 379 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 67: Graphs 360 and 380 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 68: Graphs 360 and 381 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 69: Graphs 360 and 392 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 70: Graphs 360 and 393 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs 1
#   Classification labels: -1 vs 1 (Different classification labels)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 71: Graphs 360 and 394 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 72: Graphs 360 and 404 (GW distance: -3.122502256758253e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 73: Graphs 362 and 372 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 74: Graphs 362 and 374 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 75: Graphs 362 and 375 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 76: Graphs 362 and 378 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 77: Graphs 362 and 379 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 78: Graphs 362 and 380 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 79: Graphs 362 and 381 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 80: Graphs 362 and 392 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 81: Graphs 362 and 393 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs 1
#   Classification labels: -1 vs 1 (Different classification labels)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 82: Graphs 362 and 394 (GW distance: -1.734723475976807e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 83: Graphs 362 and 404 (GW distance: -3.122502256758253e-17)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 84: Graphs 372 and 374 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 85: Graphs 372 and 375 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 86: Graphs 372 and 378 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 87: Graphs 372 and 379 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 88: Graphs 372 and 380 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 89: Graphs 372 and 381 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 90: Graphs 372 and 392 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 91: Graphs 372 and 393 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs 1
#   Classification labels: -1 vs 1 (Different classification labels)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 92: Graphs 372 and 394 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 93: Graphs 374 and 375 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 94: Graphs 374 and 378 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 95: Graphs 374 and 379 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 96: Graphs 374 and 380 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 97: Graphs 374 and 381 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 98: Graphs 374 and 392 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 99: Graphs 374 and 393 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs 1
#   Classification labels: -1 vs 1 (Different classification labels)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 100: Graphs 374 and 394 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 101: Graphs 375 and 378 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 102: Graphs 375 and 379 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 103: Graphs 375 and 380 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 104: Graphs 375 and 381 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 105: Graphs 375 and 392 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 106: Graphs 375 and 393 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs 1
#   Classification labels: -1 vs 1 (Different classification labels)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 107: Graphs 375 and 394 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 108: Graphs 378 and 379 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 109: Graphs 378 and 380 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 110: Graphs 378 and 381 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 111: Graphs 378 and 392 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 112: Graphs 378 and 393 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs 1
#   Classification labels: -1 vs 1 (Different classification labels)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 113: Graphs 378 and 394 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 114: Graphs 379 and 380 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 115: Graphs 379 and 381 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 116: Graphs 379 and 392 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 117: Graphs 379 and 393 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs 1
#   Classification labels: -1 vs 1 (Different classification labels)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 118: Graphs 379 and 394 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 119: Graphs 380 and 381 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 120: Graphs 380 and 392 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 121: Graphs 380 and 393 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs 1
#   Classification labels: -1 vs 1 (Different classification labels)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 122: Graphs 380 and 394 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 123: Graphs 381 and 392 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 124: Graphs 381 and 393 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs 1
#   Classification labels: -1 vs 1 (Different classification labels)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 125: Graphs 381 and 394 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 126: Graphs 392 and 393 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs 1
#   Classification labels: -1 vs 1 (Different classification labels)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 127: Graphs 392 and 394 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 128: Graphs 393 and 394 (GW distance: -3.469446951953614e-18)
#   Nodes: 31 vs 31
#   Edges: 35 vs 35
#   Graph labels: 1 vs -1
#   Classification labels: 1 vs -1 (Different classification labels)
#   Isomorphism: Structurally isomorphic but different node labels
#
# SUMMARY:
#   Total negative pairs: 128
#   Pairs with same classification label: 112
#   Pairs with different classification labels: 16
#   Fully isomorphic (structure + labels): 1
#   Structurally isomorphic only: 127
#   Not isomorphic: 0

# %%
### Compare all graphs in dataset to determine which are isomorphic ###
# Check for isomorphic graphs
isomorphic_pairs = []
same_label_count = 0
neg_one_pairs = 0
pos_one_pairs = 0

for i in range(N):
    for j in range(i + 1, N):
        if check_graph_isomorphism(graphs_list[i], graphs_list[j])[0]:
            isomorphic_pairs.append((i, j))
            print(f"Graphs {i} and {j} are isomorphic.")
            print(
                f"  Graph {i} has {graphs_list[i].number_of_nodes()} nodes and {graphs_list[i].number_of_edges()} edges."
            )
            print(
                f"  Graph {j} has {graphs_list[j].number_of_nodes()} nodes and {graphs_list[j].number_of_edges()} edges."
            )
            print(
                f"  Classification labels: {labels_list[i]} vs {labels_list[j]}"
            )
            tmp = ot.gromov.gromov_wasserstein2(Ms[i],Ms[j],heights[i],heights[j],loss_fun="square_loss",log=True)
            print(f"  GW Distance between Graph {i} and Graph {j}: {np.sqrt(np.abs(tmp[0]))}")
            if labels_list[i] == labels_list[j]:
                same_label_count += 1
                print("Same classification label.")
            if labels_list[i] == 1 and labels_list[j] == 1:
                pos_one_pairs += 1
                print("Both graphs have label 1.")
            if labels_list[i] == -1 and labels_list[j] == -1:
                neg_one_pairs += 1
                print("Both graphs have label -1.")
            print()

print(f"Total number of graph pairs: {N * (N - 1) / 2}")
print(f"Total isomorphic pairs found: {len(isomorphic_pairs)}")
print(f"Pairs with same classification label: {same_label_count}")
print(f"Pairs with both graphs having label 1: {pos_one_pairs}")
print(f"Pairs with both graphs having label -1: {neg_one_pairs}")
# Out:
# Graphs 0 and 2 are isomorphic.
#   Graph 0 has 30 nodes and 32 edges.
#   Graph 2 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 0 and Graph 2: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 0 and 4 are isomorphic.
#   Graph 0 has 30 nodes and 32 edges.
#   Graph 4 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 0 and Graph 4: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 0 and 6 are isomorphic.
#   Graph 0 has 30 nodes and 32 edges.
#   Graph 6 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 0 and Graph 6: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 0 and 7 are isomorphic.
#   Graph 0 has 30 nodes and 32 edges.
#   Graph 7 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 0 and Graph 7: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 0 and 9 are isomorphic.
#   Graph 0 has 30 nodes and 32 edges.
#   Graph 9 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 0 and Graph 9: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 0 and 10 are isomorphic.
#   Graph 0 has 30 nodes and 32 edges.
#   Graph 10 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 0 and Graph 10: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 0 and 11 are isomorphic.
#   Graph 0 has 30 nodes and 32 edges.
#   Graph 11 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 0 and Graph 11: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 0 and 38 are isomorphic.
#   Graph 0 has 30 nodes and 32 edges.
#   Graph 38 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 0 and Graph 38: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 0 and 39 are isomorphic.
#   Graph 0 has 30 nodes and 32 edges.
#   Graph 39 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 0 and Graph 39: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 0 and 40 are isomorphic.
#   Graph 0 has 30 nodes and 32 edges.
#   Graph 40 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 0 and Graph 40: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 0 and 43 are isomorphic.
#   Graph 0 has 30 nodes and 32 edges.
#   Graph 43 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 0 and Graph 43: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 0 and 45 are isomorphic.
#   Graph 0 has 30 nodes and 32 edges.
#   Graph 45 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 0 and Graph 45: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 0 and 50 are isomorphic.
#   Graph 0 has 30 nodes and 32 edges.
#   Graph 50 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 0 and Graph 50: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 0 and 52 are isomorphic.
#   Graph 0 has 30 nodes and 32 edges.
#   Graph 52 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 0 and Graph 52: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 0 and 155 are isomorphic.
#   Graph 0 has 30 nodes and 32 edges.
#   Graph 155 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 0 and Graph 155: 0.03265986323711
# Same classification label.
# Both graphs have label -1.
#
# Graphs 1 and 3 are isomorphic.
#   Graph 1 has 33 nodes and 35 edges.
#   Graph 3 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 1 and Graph 3: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 1 and 5 are isomorphic.
#   Graph 1 has 33 nodes and 35 edges.
#   Graph 5 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 1 and Graph 5: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 1 and 8 are isomorphic.
#   Graph 1 has 33 nodes and 35 edges.
#   Graph 8 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 1 and Graph 8: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 1 and 12 are isomorphic.
#   Graph 1 has 33 nodes and 35 edges.
#   Graph 12 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 1 and Graph 12: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 1 and 13 are isomorphic.
#   Graph 1 has 33 nodes and 35 edges.
#   Graph 13 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 1 and Graph 13: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 1 and 14 are isomorphic.
#   Graph 1 has 33 nodes and 35 edges.
#   Graph 14 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 1 and Graph 14: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 1 and 41 are isomorphic.
#   Graph 1 has 33 nodes and 35 edges.
#   Graph 41 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 1 and Graph 41: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 1 and 42 are isomorphic.
#   Graph 1 has 33 nodes and 35 edges.
#   Graph 42 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 1 and Graph 42: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 1 and 44 are isomorphic.
#   Graph 1 has 33 nodes and 35 edges.
#   Graph 44 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 1 and Graph 44: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 1 and 47 are isomorphic.
#   Graph 1 has 33 nodes and 35 edges.
#   Graph 47 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 1 and Graph 47: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 1 and 48 are isomorphic.
#   Graph 1 has 33 nodes and 35 edges.
#   Graph 48 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 1 and Graph 48: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 1 and 49 are isomorphic.
#   Graph 1 has 33 nodes and 35 edges.
#   Graph 49 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 1 and Graph 49: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 1 and 89 are isomorphic.
#   Graph 1 has 33 nodes and 35 edges.
#   Graph 89 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 1 and Graph 89: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 2 and 4 are isomorphic.
#   Graph 2 has 30 nodes and 32 edges.
#   Graph 4 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 2 and Graph 4: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 2 and 6 are isomorphic.
#   Graph 2 has 30 nodes and 32 edges.
#   Graph 6 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 2 and Graph 6: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 2 and 7 are isomorphic.
#   Graph 2 has 30 nodes and 32 edges.
#   Graph 7 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 2 and Graph 7: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 2 and 9 are isomorphic.
#   Graph 2 has 30 nodes and 32 edges.
#   Graph 9 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 2 and Graph 9: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 2 and 10 are isomorphic.
#   Graph 2 has 30 nodes and 32 edges.
#   Graph 10 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 2 and Graph 10: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 2 and 11 are isomorphic.
#   Graph 2 has 30 nodes and 32 edges.
#   Graph 11 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 2 and Graph 11: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 2 and 38 are isomorphic.
#   Graph 2 has 30 nodes and 32 edges.
#   Graph 38 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 2 and Graph 38: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 2 and 39 are isomorphic.
#   Graph 2 has 30 nodes and 32 edges.
#   Graph 39 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 2 and Graph 39: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 2 and 40 are isomorphic.
#   Graph 2 has 30 nodes and 32 edges.
#   Graph 40 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 2 and Graph 40: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 2 and 43 are isomorphic.
#   Graph 2 has 30 nodes and 32 edges.
#   Graph 43 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 2 and Graph 43: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 2 and 45 are isomorphic.
#   Graph 2 has 30 nodes and 32 edges.
#   Graph 45 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 2 and Graph 45: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 2 and 50 are isomorphic.
#   Graph 2 has 30 nodes and 32 edges.
#   Graph 50 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 2 and Graph 50: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 2 and 52 are isomorphic.
#   Graph 2 has 30 nodes and 32 edges.
#   Graph 52 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 2 and Graph 52: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 2 and 155 are isomorphic.
#   Graph 2 has 30 nodes and 32 edges.
#   Graph 155 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 2 and Graph 155: 0.03265986323711
# Same classification label.
# Both graphs have label -1.
#
# Graphs 3 and 5 are isomorphic.
#   Graph 3 has 33 nodes and 35 edges.
#   Graph 5 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 3 and Graph 5: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 3 and 8 are isomorphic.
#   Graph 3 has 33 nodes and 35 edges.
#   Graph 8 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 3 and Graph 8: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 3 and 12 are isomorphic.
#   Graph 3 has 33 nodes and 35 edges.
#   Graph 12 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 3 and Graph 12: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 3 and 13 are isomorphic.
#   Graph 3 has 33 nodes and 35 edges.
#   Graph 13 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 3 and Graph 13: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 3 and 14 are isomorphic.
#   Graph 3 has 33 nodes and 35 edges.
#   Graph 14 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 3 and Graph 14: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 3 and 41 are isomorphic.
#   Graph 3 has 33 nodes and 35 edges.
#   Graph 41 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 3 and Graph 41: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 3 and 42 are isomorphic.
#   Graph 3 has 33 nodes and 35 edges.
#   Graph 42 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 3 and Graph 42: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 3 and 44 are isomorphic.
#   Graph 3 has 33 nodes and 35 edges.
#   Graph 44 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 3 and Graph 44: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 3 and 47 are isomorphic.
#   Graph 3 has 33 nodes and 35 edges.
#   Graph 47 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 3 and Graph 47: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 3 and 48 are isomorphic.
#   Graph 3 has 33 nodes and 35 edges.
#   Graph 48 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 3 and Graph 48: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 3 and 49 are isomorphic.
#   Graph 3 has 33 nodes and 35 edges.
#   Graph 49 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 3 and Graph 49: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 3 and 89 are isomorphic.
#   Graph 3 has 33 nodes and 35 edges.
#   Graph 89 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 3 and Graph 89: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 4 and 6 are isomorphic.
#   Graph 4 has 30 nodes and 32 edges.
#   Graph 6 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 4 and Graph 6: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 4 and 7 are isomorphic.
#   Graph 4 has 30 nodes and 32 edges.
#   Graph 7 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 4 and Graph 7: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 4 and 9 are isomorphic.
#   Graph 4 has 30 nodes and 32 edges.
#   Graph 9 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 4 and Graph 9: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 4 and 10 are isomorphic.
#   Graph 4 has 30 nodes and 32 edges.
#   Graph 10 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 4 and Graph 10: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 4 and 11 are isomorphic.
#   Graph 4 has 30 nodes and 32 edges.
#   Graph 11 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 4 and Graph 11: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 4 and 38 are isomorphic.
#   Graph 4 has 30 nodes and 32 edges.
#   Graph 38 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 4 and Graph 38: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 4 and 39 are isomorphic.
#   Graph 4 has 30 nodes and 32 edges.
#   Graph 39 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 4 and Graph 39: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 4 and 40 are isomorphic.
#   Graph 4 has 30 nodes and 32 edges.
#   Graph 40 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 4 and Graph 40: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 4 and 43 are isomorphic.
#   Graph 4 has 30 nodes and 32 edges.
#   Graph 43 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 4 and Graph 43: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 4 and 45 are isomorphic.
#   Graph 4 has 30 nodes and 32 edges.
#   Graph 45 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 4 and Graph 45: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 4 and 50 are isomorphic.
#   Graph 4 has 30 nodes and 32 edges.
#   Graph 50 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 4 and Graph 50: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 4 and 52 are isomorphic.
#   Graph 4 has 30 nodes and 32 edges.
#   Graph 52 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 4 and Graph 52: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 4 and 155 are isomorphic.
#   Graph 4 has 30 nodes and 32 edges.
#   Graph 155 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 4 and Graph 155: 0.03265986323711
# Same classification label.
# Both graphs have label -1.
#
# Graphs 5 and 8 are isomorphic.
#   Graph 5 has 33 nodes and 35 edges.
#   Graph 8 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 5 and Graph 8: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 5 and 12 are isomorphic.
#   Graph 5 has 33 nodes and 35 edges.
#   Graph 12 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 5 and Graph 12: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 5 and 13 are isomorphic.
#   Graph 5 has 33 nodes and 35 edges.
#   Graph 13 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 5 and Graph 13: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 5 and 14 are isomorphic.
#   Graph 5 has 33 nodes and 35 edges.
#   Graph 14 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 5 and Graph 14: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 5 and 41 are isomorphic.
#   Graph 5 has 33 nodes and 35 edges.
#   Graph 41 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 5 and Graph 41: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 5 and 42 are isomorphic.
#   Graph 5 has 33 nodes and 35 edges.
#   Graph 42 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 5 and Graph 42: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 5 and 44 are isomorphic.
#   Graph 5 has 33 nodes and 35 edges.
#   Graph 44 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 5 and Graph 44: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 5 and 47 are isomorphic.
#   Graph 5 has 33 nodes and 35 edges.
#   Graph 47 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 5 and Graph 47: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 5 and 48 are isomorphic.
#   Graph 5 has 33 nodes and 35 edges.
#   Graph 48 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 5 and Graph 48: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 5 and 49 are isomorphic.
#   Graph 5 has 33 nodes and 35 edges.
#   Graph 49 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 5 and Graph 49: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 5 and 89 are isomorphic.
#   Graph 5 has 33 nodes and 35 edges.
#   Graph 89 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 5 and Graph 89: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 6 and 7 are isomorphic.
#   Graph 6 has 30 nodes and 32 edges.
#   Graph 7 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 6 and Graph 7: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 6 and 9 are isomorphic.
#   Graph 6 has 30 nodes and 32 edges.
#   Graph 9 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 6 and Graph 9: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 6 and 10 are isomorphic.
#   Graph 6 has 30 nodes and 32 edges.
#   Graph 10 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 6 and Graph 10: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 6 and 11 are isomorphic.
#   Graph 6 has 30 nodes and 32 edges.
#   Graph 11 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 6 and Graph 11: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 6 and 38 are isomorphic.
#   Graph 6 has 30 nodes and 32 edges.
#   Graph 38 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 6 and Graph 38: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 6 and 39 are isomorphic.
#   Graph 6 has 30 nodes and 32 edges.
#   Graph 39 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 6 and Graph 39: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 6 and 40 are isomorphic.
#   Graph 6 has 30 nodes and 32 edges.
#   Graph 40 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 6 and Graph 40: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 6 and 43 are isomorphic.
#   Graph 6 has 30 nodes and 32 edges.
#   Graph 43 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 6 and Graph 43: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 6 and 45 are isomorphic.
#   Graph 6 has 30 nodes and 32 edges.
#   Graph 45 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 6 and Graph 45: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 6 and 50 are isomorphic.
#   Graph 6 has 30 nodes and 32 edges.
#   Graph 50 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 6 and Graph 50: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 6 and 52 are isomorphic.
#   Graph 6 has 30 nodes and 32 edges.
#   Graph 52 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 6 and Graph 52: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 6 and 155 are isomorphic.
#   Graph 6 has 30 nodes and 32 edges.
#   Graph 155 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 6 and Graph 155: 0.03265986323711
# Same classification label.
# Both graphs have label -1.
#
# Graphs 7 and 9 are isomorphic.
#   Graph 7 has 30 nodes and 32 edges.
#   Graph 9 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 7 and Graph 9: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 7 and 10 are isomorphic.
#   Graph 7 has 30 nodes and 32 edges.
#   Graph 10 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 7 and Graph 10: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 7 and 11 are isomorphic.
#   Graph 7 has 30 nodes and 32 edges.
#   Graph 11 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 7 and Graph 11: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 7 and 38 are isomorphic.
#   Graph 7 has 30 nodes and 32 edges.
#   Graph 38 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 7 and Graph 38: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 7 and 39 are isomorphic.
#   Graph 7 has 30 nodes and 32 edges.
#   Graph 39 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 7 and Graph 39: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 7 and 40 are isomorphic.
#   Graph 7 has 30 nodes and 32 edges.
#   Graph 40 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 7 and Graph 40: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 7 and 43 are isomorphic.
#   Graph 7 has 30 nodes and 32 edges.
#   Graph 43 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 7 and Graph 43: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 7 and 45 are isomorphic.
#   Graph 7 has 30 nodes and 32 edges.
#   Graph 45 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 7 and Graph 45: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 7 and 50 are isomorphic.
#   Graph 7 has 30 nodes and 32 edges.
#   Graph 50 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 7 and Graph 50: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 7 and 52 are isomorphic.
#   Graph 7 has 30 nodes and 32 edges.
#   Graph 52 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 7 and Graph 52: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 7 and 155 are isomorphic.
#   Graph 7 has 30 nodes and 32 edges.
#   Graph 155 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 7 and Graph 155: 0.03265986323711
# Same classification label.
# Both graphs have label -1.
#
# Graphs 8 and 12 are isomorphic.
#   Graph 8 has 33 nodes and 35 edges.
#   Graph 12 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 8 and Graph 12: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 8 and 13 are isomorphic.
#   Graph 8 has 33 nodes and 35 edges.
#   Graph 13 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 8 and Graph 13: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 8 and 14 are isomorphic.
#   Graph 8 has 33 nodes and 35 edges.
#   Graph 14 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 8 and Graph 14: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 8 and 41 are isomorphic.
#   Graph 8 has 33 nodes and 35 edges.
#   Graph 41 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 8 and Graph 41: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 8 and 42 are isomorphic.
#   Graph 8 has 33 nodes and 35 edges.
#   Graph 42 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 8 and Graph 42: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 8 and 44 are isomorphic.
#   Graph 8 has 33 nodes and 35 edges.
#   Graph 44 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 8 and Graph 44: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 8 and 47 are isomorphic.
#   Graph 8 has 33 nodes and 35 edges.
#   Graph 47 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 8 and Graph 47: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 8 and 48 are isomorphic.
#   Graph 8 has 33 nodes and 35 edges.
#   Graph 48 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 8 and Graph 48: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 8 and 49 are isomorphic.
#   Graph 8 has 33 nodes and 35 edges.
#   Graph 49 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 8 and Graph 49: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 8 and 89 are isomorphic.
#   Graph 8 has 33 nodes and 35 edges.
#   Graph 89 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 8 and Graph 89: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 9 and 10 are isomorphic.
#   Graph 9 has 30 nodes and 32 edges.
#   Graph 10 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 9 and Graph 10: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 9 and 11 are isomorphic.
#   Graph 9 has 30 nodes and 32 edges.
#   Graph 11 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 9 and Graph 11: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 9 and 38 are isomorphic.
#   Graph 9 has 30 nodes and 32 edges.
#   Graph 38 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 9 and Graph 38: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 9 and 39 are isomorphic.
#   Graph 9 has 30 nodes and 32 edges.
#   Graph 39 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 9 and Graph 39: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 9 and 40 are isomorphic.
#   Graph 9 has 30 nodes and 32 edges.
#   Graph 40 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 9 and Graph 40: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 9 and 43 are isomorphic.
#   Graph 9 has 30 nodes and 32 edges.
#   Graph 43 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 9 and Graph 43: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 9 and 45 are isomorphic.
#   Graph 9 has 30 nodes and 32 edges.
#   Graph 45 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 9 and Graph 45: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 9 and 50 are isomorphic.
#   Graph 9 has 30 nodes and 32 edges.
#   Graph 50 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 9 and Graph 50: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 9 and 52 are isomorphic.
#   Graph 9 has 30 nodes and 32 edges.
#   Graph 52 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 9 and Graph 52: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 9 and 155 are isomorphic.
#   Graph 9 has 30 nodes and 32 edges.
#   Graph 155 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 9 and Graph 155: 0.03265986323711
# Same classification label.
# Both graphs have label -1.
#
# Graphs 10 and 11 are isomorphic.
#   Graph 10 has 30 nodes and 32 edges.
#   Graph 11 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 10 and Graph 11: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 10 and 38 are isomorphic.
#   Graph 10 has 30 nodes and 32 edges.
#   Graph 38 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 10 and Graph 38: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 10 and 39 are isomorphic.
#   Graph 10 has 30 nodes and 32 edges.
#   Graph 39 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 10 and Graph 39: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 10 and 40 are isomorphic.
#   Graph 10 has 30 nodes and 32 edges.
#   Graph 40 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 10 and Graph 40: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 10 and 43 are isomorphic.
#   Graph 10 has 30 nodes and 32 edges.
#   Graph 43 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 10 and Graph 43: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 10 and 45 are isomorphic.
#   Graph 10 has 30 nodes and 32 edges.
#   Graph 45 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 10 and Graph 45: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 10 and 50 are isomorphic.
#   Graph 10 has 30 nodes and 32 edges.
#   Graph 50 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 10 and Graph 50: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 10 and 52 are isomorphic.
#   Graph 10 has 30 nodes and 32 edges.
#   Graph 52 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 10 and Graph 52: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 10 and 155 are isomorphic.
#   Graph 10 has 30 nodes and 32 edges.
#   Graph 155 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 10 and Graph 155: 0.03265986323711
# Same classification label.
# Both graphs have label -1.
#
# Graphs 11 and 38 are isomorphic.
#   Graph 11 has 30 nodes and 32 edges.
#   Graph 38 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 11 and Graph 38: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 11 and 39 are isomorphic.
#   Graph 11 has 30 nodes and 32 edges.
#   Graph 39 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 11 and Graph 39: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 11 and 40 are isomorphic.
#   Graph 11 has 30 nodes and 32 edges.
#   Graph 40 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 11 and Graph 40: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 11 and 43 are isomorphic.
#   Graph 11 has 30 nodes and 32 edges.
#   Graph 43 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 11 and Graph 43: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 11 and 45 are isomorphic.
#   Graph 11 has 30 nodes and 32 edges.
#   Graph 45 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 11 and Graph 45: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 11 and 50 are isomorphic.
#   Graph 11 has 30 nodes and 32 edges.
#   Graph 50 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 11 and Graph 50: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 11 and 52 are isomorphic.
#   Graph 11 has 30 nodes and 32 edges.
#   Graph 52 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 11 and Graph 52: 0.03265986323710984
# Same classification label.
# Both graphs have label -1.
#
# Graphs 11 and 155 are isomorphic.
#   Graph 11 has 30 nodes and 32 edges.
#   Graph 155 has 30 nodes and 32 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 11 and Graph 155: 0.03265986323711
# Same classification label.
# Both graphs have label -1.
#
# Graphs 12 and 13 are isomorphic.
#   Graph 12 has 33 nodes and 35 edges.
#   Graph 13 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 12 and Graph 13: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 12 and 14 are isomorphic.
#   Graph 12 has 33 nodes and 35 edges.
#   Graph 14 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 12 and Graph 14: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 12 and 41 are isomorphic.
#   Graph 12 has 33 nodes and 35 edges.
#   Graph 41 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 12 and Graph 41: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 12 and 42 are isomorphic.
#   Graph 12 has 33 nodes and 35 edges.
#   Graph 42 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 12 and Graph 42: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 12 and 44 are isomorphic.
#   Graph 12 has 33 nodes and 35 edges.
#   Graph 44 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 12 and Graph 44: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 12 and 47 are isomorphic.
#   Graph 12 has 33 nodes and 35 edges.
#   Graph 47 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 12 and Graph 47: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 12 and 48 are isomorphic.
#   Graph 12 has 33 nodes and 35 edges.
#   Graph 48 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 12 and Graph 48: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 12 and 49 are isomorphic.
#   Graph 12 has 33 nodes and 35 edges.
#   Graph 49 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 12 and Graph 49: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 12 and 89 are isomorphic.
#   Graph 12 has 33 nodes and 35 edges.
#   Graph 89 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 12 and Graph 89: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 13 and 14 are isomorphic.
#   Graph 13 has 33 nodes and 35 edges.
#   Graph 14 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 13 and Graph 14: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 13 and 41 are isomorphic.
#   Graph 13 has 33 nodes and 35 edges.
#   Graph 41 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 13 and Graph 41: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 13 and 42 are isomorphic.
#   Graph 13 has 33 nodes and 35 edges.
#   Graph 42 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 13 and Graph 42: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 13 and 44 are isomorphic.
#   Graph 13 has 33 nodes and 35 edges.
#   Graph 44 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 13 and Graph 44: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 13 and 47 are isomorphic.
#   Graph 13 has 33 nodes and 35 edges.
#   Graph 47 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 13 and Graph 47: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 13 and 48 are isomorphic.
#   Graph 13 has 33 nodes and 35 edges.
#   Graph 48 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 13 and Graph 48: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 13 and 49 are isomorphic.
#   Graph 13 has 33 nodes and 35 edges.
#   Graph 49 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 13 and Graph 49: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 13 and 89 are isomorphic.
#   Graph 13 has 33 nodes and 35 edges.
#   Graph 89 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 13 and Graph 89: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 14 and 41 are isomorphic.
#   Graph 14 has 33 nodes and 35 edges.
#   Graph 41 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 14 and Graph 41: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 14 and 42 are isomorphic.
#   Graph 14 has 33 nodes and 35 edges.
#   Graph 42 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 14 and Graph 42: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 14 and 44 are isomorphic.
#   Graph 14 has 33 nodes and 35 edges.
#   Graph 44 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 14 and Graph 44: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 14 and 47 are isomorphic.
#   Graph 14 has 33 nodes and 35 edges.
#   Graph 47 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 14 and Graph 47: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 14 and 48 are isomorphic.
#   Graph 14 has 33 nodes and 35 edges.
#   Graph 48 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 14 and Graph 48: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 14 and 49 are isomorphic.
#   Graph 14 has 33 nodes and 35 edges.
#   Graph 49 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 14 and Graph 49: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 14 and 89 are isomorphic.
#   Graph 14 has 33 nodes and 35 edges.
#   Graph 89 has 33 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 14 and Graph 89: 0.029690784761010773
# Same classification label.
# Both graphs have label -1.
#
# Graphs 17 and 18 are isomorphic.
#   Graph 17 has 32 nodes and 34 edges.
#   Graph 18 has 32 nodes and 34 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 17 and Graph 18: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 17 and 20 are isomorphic.
#   Graph 17 has 32 nodes and 34 edges.
#   Graph 20 has 32 nodes and 34 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 17 and Graph 20: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 17 and 24 are isomorphic.
#   Graph 17 has 32 nodes and 34 edges.
#   Graph 24 has 32 nodes and 34 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 17 and Graph 24: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 17 and 27 are isomorphic.
#   Graph 17 has 32 nodes and 34 edges.
#   Graph 27 has 32 nodes and 34 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 17 and Graph 27: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 17 and 35 are isomorphic.
#   Graph 17 has 32 nodes and 34 edges.
#   Graph 35 has 32 nodes and 34 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 17 and Graph 35: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 18 and 20 are isomorphic.
#   Graph 18 has 32 nodes and 34 edges.
#   Graph 20 has 32 nodes and 34 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 18 and Graph 20: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 18 and 24 are isomorphic.
#   Graph 18 has 32 nodes and 34 edges.
#   Graph 24 has 32 nodes and 34 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 18 and Graph 24: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 18 and 27 are isomorphic.
#   Graph 18 has 32 nodes and 34 edges.
#   Graph 27 has 32 nodes and 34 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 18 and Graph 27: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 18 and 35 are isomorphic.
#   Graph 18 has 32 nodes and 34 edges.
#   Graph 35 has 32 nodes and 34 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 18 and Graph 35: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 19 and 21 are isomorphic.
#   Graph 19 has 35 nodes and 37 edges.
#   Graph 21 has 35 nodes and 37 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 19 and Graph 21: 8.736580162911545e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 19 and 25 are isomorphic.
#   Graph 19 has 35 nodes and 37 edges.
#   Graph 25 has 35 nodes and 37 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 19 and Graph 25: 8.736580162911545e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 19 and 26 are isomorphic.
#   Graph 19 has 35 nodes and 37 edges.
#   Graph 26 has 35 nodes and 37 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 19 and Graph 26: 8.736580162911545e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 20 and 24 are isomorphic.
#   Graph 20 has 32 nodes and 34 edges.
#   Graph 24 has 32 nodes and 34 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 20 and Graph 24: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 20 and 27 are isomorphic.
#   Graph 20 has 32 nodes and 34 edges.
#   Graph 27 has 32 nodes and 34 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 20 and Graph 27: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 20 and 35 are isomorphic.
#   Graph 20 has 32 nodes and 34 edges.
#   Graph 35 has 32 nodes and 34 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 20 and Graph 35: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 21 and 25 are isomorphic.
#   Graph 21 has 35 nodes and 37 edges.
#   Graph 25 has 35 nodes and 37 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 21 and Graph 25: 8.736580162911545e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 21 and 26 are isomorphic.
#   Graph 21 has 35 nodes and 37 edges.
#   Graph 26 has 35 nodes and 37 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 21 and Graph 26: 8.736580162911545e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 24 and 27 are isomorphic.
#   Graph 24 has 32 nodes and 34 edges.
#   Graph 27 has 32 nodes and 34 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 24 and Graph 27: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 24 and 35 are isomorphic.
#   Graph 24 has 32 nodes and 34 edges.
#   Graph 35 has 32 nodes and 34 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 24 and Graph 35: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 25 and 26 are isomorphic.
#   Graph 25 has 35 nodes and 37 edges.
#   Graph 26 has 35 nodes and 37 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 25 and Graph 26: 8.736580162911545e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 27 and 35 are isomorphic.
#   Graph 27 has 32 nodes and 34 edges.
#   Graph 35 has 32 nodes and 34 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 27 and Graph 35: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 31 and 32 are isomorphic.
#   Graph 31 has 34 nodes and 36 edges.
#   Graph 32 has 34 nodes and 36 edges.
#   Classification labels: -1 vs -1
# ...
# Both graphs have label -1.
#
# Graphs 372 and 404 are isomorphic.
#   Graph 372 has 31 nodes and 35 edges.
#   Graph 404 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 372 and Graph 404: 1.6130980174698654e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 374 and 375 are isomorphic.
#   Graph 374 has 31 nodes and 35 edges.
#   Graph 375 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 374 and Graph 375: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 374 and 378 are isomorphic.
#   Graph 374 has 31 nodes and 35 edges.
#   Graph 378 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 374 and Graph 378: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 374 and 379 are isomorphic.
#   Graph 374 has 31 nodes and 35 edges.
#   Graph 379 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 374 and Graph 379: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 374 and 380 are isomorphic.
#   Graph 374 has 31 nodes and 35 edges.
#   Graph 380 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 374 and Graph 380: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 374 and 381 are isomorphic.
#   Graph 374 has 31 nodes and 35 edges.
#   Graph 381 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 374 and Graph 381: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 374 and 392 are isomorphic.
#   Graph 374 has 31 nodes and 35 edges.
#   Graph 392 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 374 and Graph 392: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 374 and 393 are isomorphic.
#   Graph 374 has 31 nodes and 35 edges.
#   Graph 393 has 31 nodes and 35 edges.
#   Classification labels: -1 vs 1
#   GW Distance between Graph 374 and Graph 393: 1.862645149230957e-09
#
# Graphs 374 and 394 are isomorphic.
#   Graph 374 has 31 nodes and 35 edges.
#   Graph 394 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 374 and Graph 394: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 374 and 404 are isomorphic.
#   Graph 374 has 31 nodes and 35 edges.
#   Graph 404 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 374 and Graph 404: 1.6130980174698654e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 375 and 378 are isomorphic.
#   Graph 375 has 31 nodes and 35 edges.
#   Graph 378 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 375 and Graph 378: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 375 and 379 are isomorphic.
#   Graph 375 has 31 nodes and 35 edges.
#   Graph 379 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 375 and Graph 379: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 375 and 380 are isomorphic.
#   Graph 375 has 31 nodes and 35 edges.
#   Graph 380 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 375 and Graph 380: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 375 and 381 are isomorphic.
#   Graph 375 has 31 nodes and 35 edges.
#   Graph 381 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 375 and Graph 381: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 375 and 392 are isomorphic.
#   Graph 375 has 31 nodes and 35 edges.
#   Graph 392 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 375 and Graph 392: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 375 and 393 are isomorphic.
#   Graph 375 has 31 nodes and 35 edges.
#   Graph 393 has 31 nodes and 35 edges.
#   Classification labels: -1 vs 1
#   GW Distance between Graph 375 and Graph 393: 1.862645149230957e-09
#
# Graphs 375 and 394 are isomorphic.
#   Graph 375 has 31 nodes and 35 edges.
#   Graph 394 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 375 and Graph 394: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 375 and 404 are isomorphic.
#   Graph 375 has 31 nodes and 35 edges.
#   Graph 404 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 375 and Graph 404: 1.6130980174698654e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 378 and 379 are isomorphic.
#   Graph 378 has 31 nodes and 35 edges.
#   Graph 379 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 378 and Graph 379: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 378 and 380 are isomorphic.
#   Graph 378 has 31 nodes and 35 edges.
#   Graph 380 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 378 and Graph 380: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 378 and 381 are isomorphic.
#   Graph 378 has 31 nodes and 35 edges.
#   Graph 381 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 378 and Graph 381: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 378 and 392 are isomorphic.
#   Graph 378 has 31 nodes and 35 edges.
#   Graph 392 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 378 and Graph 392: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 378 and 393 are isomorphic.
#   Graph 378 has 31 nodes and 35 edges.
#   Graph 393 has 31 nodes and 35 edges.
#   Classification labels: -1 vs 1
#   GW Distance between Graph 378 and Graph 393: 1.862645149230957e-09
#
# Graphs 378 and 394 are isomorphic.
#   Graph 378 has 31 nodes and 35 edges.
#   Graph 394 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 378 and Graph 394: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 378 and 404 are isomorphic.
#   Graph 378 has 31 nodes and 35 edges.
#   Graph 404 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 378 and Graph 404: 1.6130980174698654e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 379 and 380 are isomorphic.
#   Graph 379 has 31 nodes and 35 edges.
#   Graph 380 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 379 and Graph 380: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 379 and 381 are isomorphic.
#   Graph 379 has 31 nodes and 35 edges.
#   Graph 381 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 379 and Graph 381: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 379 and 392 are isomorphic.
#   Graph 379 has 31 nodes and 35 edges.
#   Graph 392 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 379 and Graph 392: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 379 and 393 are isomorphic.
#   Graph 379 has 31 nodes and 35 edges.
#   Graph 393 has 31 nodes and 35 edges.
#   Classification labels: -1 vs 1
#   GW Distance between Graph 379 and Graph 393: 1.862645149230957e-09
#
# Graphs 379 and 394 are isomorphic.
#   Graph 379 has 31 nodes and 35 edges.
#   Graph 394 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 379 and Graph 394: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 379 and 404 are isomorphic.
#   Graph 379 has 31 nodes and 35 edges.
#   Graph 404 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 379 and Graph 404: 1.6130980174698654e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 380 and 381 are isomorphic.
#   Graph 380 has 31 nodes and 35 edges.
#   Graph 381 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 380 and Graph 381: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 380 and 392 are isomorphic.
#   Graph 380 has 31 nodes and 35 edges.
#   Graph 392 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 380 and Graph 392: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 380 and 393 are isomorphic.
#   Graph 380 has 31 nodes and 35 edges.
#   Graph 393 has 31 nodes and 35 edges.
#   Classification labels: -1 vs 1
#   GW Distance between Graph 380 and Graph 393: 1.862645149230957e-09
#
# Graphs 380 and 394 are isomorphic.
#   Graph 380 has 31 nodes and 35 edges.
#   Graph 394 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 380 and Graph 394: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 380 and 404 are isomorphic.
#   Graph 380 has 31 nodes and 35 edges.
#   Graph 404 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 380 and Graph 404: 1.6130980174698654e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 381 and 392 are isomorphic.
#   Graph 381 has 31 nodes and 35 edges.
#   Graph 392 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 381 and Graph 392: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 381 and 393 are isomorphic.
#   Graph 381 has 31 nodes and 35 edges.
#   Graph 393 has 31 nodes and 35 edges.
#   Classification labels: -1 vs 1
#   GW Distance between Graph 381 and Graph 393: 1.862645149230957e-09
#
# Graphs 381 and 394 are isomorphic.
#   Graph 381 has 31 nodes and 35 edges.
#   Graph 394 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 381 and Graph 394: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 381 and 404 are isomorphic.
#   Graph 381 has 31 nodes and 35 edges.
#   Graph 404 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 381 and Graph 404: 1.6130980174698654e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 386 and 387 are isomorphic.
#   Graph 386 has 33 nodes and 37 edges.
#   Graph 387 has 33 nodes and 37 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 386 and Graph 387: 7.450580596923828e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 386 and 388 are isomorphic.
#   Graph 386 has 33 nodes and 37 edges.
#   Graph 388 has 33 nodes and 37 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 386 and Graph 388: 7.450580596923828e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 386 and 389 are isomorphic.
#   Graph 386 has 33 nodes and 37 edges.
#   Graph 389 has 33 nodes and 37 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 386 and Graph 389: 7.450580596923828e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 386 and 390 are isomorphic.
#   Graph 386 has 33 nodes and 37 edges.
#   Graph 390 has 33 nodes and 37 edges.
#   Classification labels: -1 vs 1
#   GW Distance between Graph 386 and Graph 390: 7.450580596923828e-09
#
# Graphs 386 and 391 are isomorphic.
#   Graph 386 has 33 nodes and 37 edges.
#   Graph 391 has 33 nodes and 37 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 386 and Graph 391: 7.450580596923828e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 387 and 388 are isomorphic.
#   Graph 387 has 33 nodes and 37 edges.
#   Graph 388 has 33 nodes and 37 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 387 and Graph 388: 7.450580596923828e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 387 and 389 are isomorphic.
#   Graph 387 has 33 nodes and 37 edges.
#   Graph 389 has 33 nodes and 37 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 387 and Graph 389: 7.450580596923828e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 387 and 390 are isomorphic.
#   Graph 387 has 33 nodes and 37 edges.
#   Graph 390 has 33 nodes and 37 edges.
#   Classification labels: -1 vs 1
#   GW Distance between Graph 387 and Graph 390: 7.450580596923828e-09
#
# Graphs 387 and 391 are isomorphic.
#   Graph 387 has 33 nodes and 37 edges.
#   Graph 391 has 33 nodes and 37 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 387 and Graph 391: 7.450580596923828e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 388 and 389 are isomorphic.
#   Graph 388 has 33 nodes and 37 edges.
#   Graph 389 has 33 nodes and 37 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 388 and Graph 389: 7.450580596923828e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 388 and 390 are isomorphic.
#   Graph 388 has 33 nodes and 37 edges.
#   Graph 390 has 33 nodes and 37 edges.
#   Classification labels: -1 vs 1
#   GW Distance between Graph 388 and Graph 390: 7.450580596923828e-09
#
# Graphs 388 and 391 are isomorphic.
#   Graph 388 has 33 nodes and 37 edges.
#   Graph 391 has 33 nodes and 37 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 388 and Graph 391: 7.450580596923828e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 389 and 390 are isomorphic.
#   Graph 389 has 33 nodes and 37 edges.
#   Graph 390 has 33 nodes and 37 edges.
#   Classification labels: -1 vs 1
#   GW Distance between Graph 389 and Graph 390: 7.450580596923828e-09
#
# Graphs 389 and 391 are isomorphic.
#   Graph 389 has 33 nodes and 37 edges.
#   Graph 391 has 33 nodes and 37 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 389 and Graph 391: 7.450580596923828e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 390 and 391 are isomorphic.
#   Graph 390 has 33 nodes and 37 edges.
#   Graph 391 has 33 nodes and 37 edges.
#   Classification labels: 1 vs -1
#   GW Distance between Graph 390 and Graph 391: 7.450580596923828e-09
#
# Graphs 392 and 393 are isomorphic.
#   Graph 392 has 31 nodes and 35 edges.
#   Graph 393 has 31 nodes and 35 edges.
#   Classification labels: -1 vs 1
#   GW Distance between Graph 392 and Graph 393: 1.862645149230957e-09
#
# Graphs 392 and 394 are isomorphic.
#   Graph 392 has 31 nodes and 35 edges.
#   Graph 394 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 392 and Graph 394: 1.862645149230957e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 392 and 404 are isomorphic.
#   Graph 392 has 31 nodes and 35 edges.
#   Graph 404 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 392 and Graph 404: 1.6130980174698654e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 393 and 394 are isomorphic.
#   Graph 393 has 31 nodes and 35 edges.
#   Graph 394 has 31 nodes and 35 edges.
#   Classification labels: 1 vs -1
#   GW Distance between Graph 393 and Graph 394: 1.862645149230957e-09
#
# Graphs 393 and 404 are isomorphic.
#   Graph 393 has 31 nodes and 35 edges.
#   Graph 404 has 31 nodes and 35 edges.
#   Classification labels: 1 vs -1
#   GW Distance between Graph 393 and Graph 404: 1.6130980174698654e-09
#
# Graphs 394 and 404 are isomorphic.
#   Graph 394 has 31 nodes and 35 edges.
#   Graph 404 has 31 nodes and 35 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 394 and Graph 404: 1.6130980174698654e-09
# Same classification label.
# Both graphs have label -1.
#
# Total number of graph pairs: 81810.0
# Total isomorphic pairs found: 491
# Pairs with same classification label: 453
# Pairs with both graphs having label 1: 13
# Pairs with both graphs having label -1: 440

# %%
# Create scatterplot of GW distances by class
plt.figure(figsize=(10, 8))

# Convert labels to numpy array for easier indexing
labels_array = np.array(labels_list)

# Get indices for each class
class_1_indices = np.where(labels_array == 1)[0]  # Active class
class_minus1_indices = np.where(labels_array == -1)[0]  # Inactive class

# Extract GW distances for different class combinations
# Within class 1 (active vs active)
within_class1_distances = []
for i in range(len(class_1_indices)):
    for j in range(i+1, len(class_1_indices)):
        idx_i, idx_j = class_1_indices[i], class_1_indices[j]
        within_class1_distances.append(gw[idx_i, idx_j])

# Within class -1 (inactive vs inactive)
within_class_minus1_distances = []
for i in range(len(class_minus1_indices)):
    for j in range(i+1, len(class_minus1_indices)):
        idx_i, idx_j = class_minus1_indices[i], class_minus1_indices[j]
        within_class_minus1_distances.append(gw[idx_i, idx_j])

# Between classes (active vs inactive)
between_classes_distances = []
for i in class_1_indices:
    for j in class_minus1_indices:
        between_classes_distances.append(gw[i, j])

# Create scatter plot
x_positions = []
distances = []
colors = []
labels_plot = []

# Add within class 1 distances
x_positions.extend([0] * len(within_class1_distances))
distances.extend(within_class1_distances)
colors.extend(['blue'] * len(within_class1_distances))
labels_plot.extend(['Active vs Active'] * len(within_class1_distances))

# Add within class -1 distances
x_positions.extend([1] * len(within_class_minus1_distances))
distances.extend(within_class_minus1_distances)
colors.extend(['orange'] * len(within_class_minus1_distances))
labels_plot.extend(['Inactive vs Inactive'] * len(within_class_minus1_distances))

# Add between classes distances
x_positions.extend([2] * len(between_classes_distances))
distances.extend(between_classes_distances)
colors.extend(['gray'] * len(between_classes_distances))
labels_plot.extend(['Active vs Inactive'] * len(between_classes_distances))

# Create the scatter plot
scatter = plt.scatter(x_positions, distances, c=colors, alpha=0.6, s=30)
# Customize the plot
plt.xlabel('Class Comparison')
plt.ylabel('Gromov-Wasserstein Distance')
plt.title('Gromov-Wasserstein Distances Between Graph Classes')
plt.xticks([0, 1, 2], ['Active vs Active\n(Class 1)', 'Inactive vs Inactive\n(Class -1)', 'Active vs Inactive\n(Cross-class)'])
legend_elements = [Patch(facecolor='blue', label='Active vs Active'),
                   Patch(facecolor='orange', label='Inactive vs Inactive'),
                   Patch(facecolor='gray', label='Active vs Inactive')]
plt.legend(handles=legend_elements)

# Add some statistics
print(f"Within Active class - Mean: {np.mean(within_class1_distances):.4f}, Std: {np.std(within_class1_distances):.4f}")
print(f"Within Inactive class - Mean: {np.mean(within_class_minus1_distances):.4f}, Std: {np.std(within_class_minus1_distances):.4f}")
print(f"Between classes - Mean: {np.mean(between_classes_distances):.4f}, Std: {np.std(between_classes_distances):.4f}")

plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Within Active class - Mean: 0.1269, Std: 0.0295
# Within Inactive class - Mean: 0.1174, Std: 0.0276
# Between classes - Mean: 0.1234, Std: 0.0275

# %%
# Perform statistical test
active_vs_inactive_mean = np.mean(between_classes_distances)
within_active_mean = np.mean(within_class1_distances)
within_inactive_mean = np.mean(within_class_minus1_distances)

print(f"\nStatistical Summary:")
print(f"Number of Active graphs: {len(class_1_indices)}")
print(f"Number of Inactive graphs: {len(class_minus1_indices)}")
print(f"Number of within-Active comparisons: {len(within_class1_distances)}")
print(f"Number of within-Inactive comparisons: {len(within_class_minus1_distances)}")
print(f"Number of cross-class comparisons: {len(between_classes_distances)}")

# Test if between-class distances are significantly different from within-class distances
all_within_class = within_class1_distances + within_class_minus1_distances
t_stat, p_value = ttest_ind(between_classes_distances, all_within_class)
print(f"\nT-test (Between-class vs Within-class distances):")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")
print(f"Significant difference: {'Yes' if p_value < 0.05 else 'No'}")
# Out:
# Statistical Summary:
# Number of Active graphs: 86
# Number of Inactive graphs: 319
# Number of within-Active comparisons: 3655
# Number of within-Inactive comparisons: 50721
# Number of cross-class comparisons: 27434
#
# T-test (Between-class vs Within-class distances):
# T-statistic: 25.8982
# P-value: 0.0000
# Significant difference: Yes

# %%
# gLGW Distances Scatterplots #

# %%
k_bary = 36  # use dataset average
idx_bary = []
classes = [-1,1]

for i in classes:
    # Find the indices of instances with label i
    labels_list = np.asarray(labels_list) 
    indices = np.where(labels_list == i)[0]
    if indices.size > 0:
        idx_bary.extend(np.random.choice(indices, size=min(5, len(indices)), replace=False))

# Initialize reference matrix with k_bary size
M_ref = np.zeros((k_bary, k_bary))
selected_Ms = [Ms[i] for i in idx_bary]
selected_heights = [heights[i] for i in idx_bary]
lambdas = ot.unif(len(idx_bary))

M_ref = ot.gromov.gromov_barycenters(k_bary,
                                     Cs=selected_Ms,
                                     ps=selected_heights,
                                     p=ot.unif(k_bary),
                                     lambdas=lambdas,
                                     loss_fun='square_loss',
                                     max_iter=200,
                                     tol=1e-12,
                                     random_state=42)

height_ref = ot.unif(k_bary)
lgw_matrix, lgw_time = lgw_procedure(M_ref,
                                     height_ref,
                                     None,
                                     Ms,
                                     heights,
                                     mode="graph")

# %%
print(f"\ngLGW computation summary:")
print(f"gLGW computation time: {lgw_time:.4f} seconds")
print(f"Min gLGW value: {np.min(lgw_matrix[lgw_matrix != 0])}")
print(f"Max gLGW value: {np.max(lgw_matrix)}")
print(f"Number of NaN values: {np.sum(np.isnan(lgw_matrix))}")

negative_lgw_count = np.sum(lgw_matrix < 0)
if negative_lgw_count > 0:
    print(f"Warning: {negative_lgw_count} negative gLGW values found!")
# Out:
# gLGW computation summary:
# gLGW computation time: 2.2443 seconds
# Min gLGW value: 0.020925242605989703
# Max gLGW value: 0.2530046377562879
# Number of NaN values: 0

# %%
# Create scatterplot of gLGW distances by class
plt.figure(figsize=(10, 8))

# Convert labels to numpy array for easier indexing
labels_array = np.array(labels_list)

# Get indices for each class
class_1_indices = np.where(labels_array == 1)[0]  # Active class
class_minus1_indices = np.where(labels_array == -1)[0]  # Inactive class

# Extract gLGW distances for different class combinations
# Within class 1 (active vs active)
within_class1_lgw_distances = []
for i in range(len(class_1_indices)):
    for j in range(i+1, len(class_1_indices)):
        idx_i, idx_j = class_1_indices[i], class_1_indices[j]
        within_class1_lgw_distances.append(lgw_matrix[idx_i, idx_j])

# Within class -1 (inactive vs inactive)
within_class_minus1_lgw_distances = []
for i in range(len(class_minus1_indices)):
    for j in range(i+1, len(class_minus1_indices)):
        idx_i, idx_j = class_minus1_indices[i], class_minus1_indices[j]
        within_class_minus1_lgw_distances.append(lgw_matrix[idx_i, idx_j])

# Between classes (active vs inactive)
between_classes_lgw_distances = []
for i in class_1_indices:
    for j in class_minus1_indices:
        between_classes_lgw_distances.append(lgw_matrix[i, j])

# Create scatter plot
x_positions_lgw = []
distances_lgw = []
colors_lgw = []
labels_plot_lgw = []

# Add within class 1 distances
x_positions_lgw.extend([0] * len(within_class1_lgw_distances))
distances_lgw.extend(within_class1_lgw_distances)
colors_lgw.extend(['blue'] * len(within_class1_lgw_distances))
labels_plot_lgw.extend(['Active vs Active'] * len(within_class1_lgw_distances))

# Add within class -1 distances
x_positions_lgw.extend([1] * len(within_class_minus1_lgw_distances))
distances_lgw.extend(within_class_minus1_lgw_distances)
colors_lgw.extend(['orange'] * len(within_class_minus1_lgw_distances))
labels_plot_lgw.extend(['Inactive vs Inactive'] * len(within_class_minus1_lgw_distances))

# Add between classes distances
x_positions_lgw.extend([2] * len(between_classes_lgw_distances))
distances_lgw.extend(between_classes_lgw_distances)
colors_lgw.extend(['gray'] * len(between_classes_lgw_distances))
labels_plot_lgw.extend(['Active vs Inactive'] * len(between_classes_lgw_distances))

# Create the scatter plot
scatter_lgw = plt.scatter(x_positions_lgw, distances_lgw, c=colors_lgw, alpha=0.6, s=30)

# Customize the plot
plt.xlabel('Class Comparison')
plt.ylabel('Generalized Linear Gromov-Wasserstein Distance')
plt.title('Generalized Linear Gromov-Wasserstein Distances Between Graph Classes')
plt.xticks([0, 1, 2], ['Active vs Active\n(Class 1)', 'Inactive vs Inactive\n(Class -1)', 'Active vs Inactive\n(Cross-class)'])

# Add legend
from matplotlib.patches import Patch
legend_elements_lgw = [Patch(facecolor='blue', label='Active vs Active'),
                       Patch(facecolor='orange', label='Inactive vs Inactive'),
                       Patch(facecolor='gray', label='Active vs Inactive')]
plt.legend(handles=legend_elements_lgw)

# Add some statistics
print(f"\ngLGW Distance Statistics:")
print(f"Within Active class - Mean: {np.mean(within_class1_lgw_distances):.4f}, Std: {np.std(within_class1_lgw_distances):.4f}")
print(f"Within Inactive class - Mean: {np.mean(within_class_minus1_lgw_distances):.4f}, Std: {np.std(within_class_minus1_lgw_distances):.4f}")
print(f"Between classes - Mean: {np.mean(between_classes_lgw_distances):.4f}, Std: {np.std(between_classes_lgw_distances):.4f}")

plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# gLGW Distance Statistics:
# Within Active class - Mean: 0.1513, Std: 0.0330
# Within Inactive class - Mean: 0.1413, Std: 0.0270
# Between classes - Mean: 0.1469, Std: 0.0291

# %%
# Perform statistical test for gLGW
active_vs_inactive_lgw_mean = np.mean(between_classes_lgw_distances)
within_active_lgw_mean = np.mean(within_class1_lgw_distances)
within_inactive_lgw_mean = np.mean(within_class_minus1_lgw_distances)

print(f"\ngLGW Statistical Summary:")
print(f"Number of Active graphs: {len(class_1_indices)}")
print(f"Number of Inactive graphs: {len(class_minus1_indices)}")
print(f"Number of within-Active comparisons: {len(within_class1_lgw_distances)}")
print(f"Number of within-Inactive comparisons: {len(within_class_minus1_lgw_distances)}")
print(f"Number of cross-class comparisons: {len(between_classes_lgw_distances)}")

# Test if between-class gLGW distances are significantly different from within-class distances
all_within_class_lgw = within_class1_lgw_distances + within_class_minus1_lgw_distances
t_stat_lgw, p_value_lgw = ttest_ind(between_classes_lgw_distances, all_within_class_lgw)
print(f"\nT-test for LGW (Between-class vs Within-class distances):")
print(f"T-statistic: {t_stat_lgw:.4f}")
print(f"P-value: {p_value_lgw:.4f}")
print(f"Significant difference: {'Yes' if p_value_lgw < 0.05 else 'No'}")

# Additional comparison between GW and LGW results
print(f"gLGW between-class mean: {active_vs_inactive_lgw_mean:.4f}")
print(f"gLGW within-active mean: {within_active_lgw_mean:.4f}")
print(f"gLGW within-inactive mean: {within_inactive_lgw_mean:.4f}")
# Out:
# gLGW Statistical Summary:
# Number of Active graphs: 86
# Number of Inactive graphs: 319
# Number of within-Active comparisons: 3655
# Number of within-Inactive comparisons: 50721
# Number of cross-class comparisons: 27434
#
# T-test for LGW (Between-class vs Within-class distances):
# T-statistic: 23.5883
# P-value: 0.0000
# Significant difference: Yes
# gLGW between-class mean: 0.1469
# gLGW within-active mean: 0.1513
# gLGW within-inactive mean: 0.1413

# %%
## 2D GW vs. gLGW comparison ##
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))
labels_array = np.array(labels_list)

def create_within_class_gw_vs_lgw_scatterplot(gw_matrix, lgw_matrix, labels_array, ax, title, class_label):
    """Create a 2D scatterplot comparing within-class GW vs gLGW distances for a specific class"""

    # Get indices for the specific class
    if class_label == 1:
        class_indices = np.where(labels_array == 1)[0]  # ER class
        class_name = "Active"
        color = 'blue'
    else:
        class_indices = np.where(labels_array == -1)[0]  # SBM class
        class_name = "Inactive"
        color = 'orange'

    # Extract within-class distances only
    gw_within_class = []
    lgw_within_class = []

    for i in range(len(class_indices)):
        for j in range(i + 1, len(class_indices)):
            idx_i, idx_j = class_indices[i], class_indices[j]
            gw_within_class.append(gw_matrix[idx_i, idx_j])
            lgw_within_class.append(lgw_matrix[idx_i, idx_j])

    # Create scatter plot
    ax.scatter(gw_within_class, lgw_within_class, alpha=0.6, s=30, color=color, 
               edgecolors='black', linewidth=0.5)

    # Add diagonal line for comparison
    if len(gw_within_class) > 0:
        min_val = min(min(gw_within_class), min(lgw_within_class))
        max_val = max(max(gw_within_class), max(lgw_within_class))
        ax.plot([min_val, max_val], [min_val, max_val], 'k--', alpha=0.7, linewidth=2, label='y=x diagonal')

    # Customize the plot
    ax.set_xlabel('GW Distance (Within-class)')
    ax.set_ylabel('gLGW Distance (Within-class)')
    ax.set_title(f'{title} - {class_name} Class')
    ax.grid(True, alpha=0.3)
    ax.legend()

    # Calculate correlation coefficient if there are enough points
    if len(gw_within_class) > 1:
        correlation = np.corrcoef(gw_within_class, lgw_within_class)[0, 1]
        ax.text(0.05, 0.95, f'Correlation: {correlation:.4f}', transform=ax.transAxes, 
                bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
    else:
        correlation = np.nan
        ax.text(0.05, 0.95, 'Insufficient data', transform=ax.transAxes, 
                bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

    return gw_within_class, lgw_within_class, correlation

# Create scatterplots for both datasets and both classes
gw_within_active_1, lgw_within_active_1, corr_active_1 = create_within_class_gw_vs_lgw_scatterplot(
    gw, lgw_matrix, labels_array, ax1, 'BZR', 1
)

gw_within_inactive_1, lgw_within_inactive_1, corr_inactive_1 = create_within_class_gw_vs_lgw_scatterplot(
    gw, lgw_matrix, labels_array, ax2, 'BZR', -1
)
plt.tight_layout()

# %%
# fGW Distances Scatterplots #

# Initialize fGW distance matrix
fgw_matrix = np.zeros((N, N))

# Track negative values during computation
negative_fgw_count = 0
negative_fgw_pairs = []

# Compute fused Gromov-Wasserstein distances
for i in range(N):
    for j in range(i + 1, N):
        # Get features for both graphs
        graph_i = graphs_list[i]
        graph_j = graphs_list[j]

        # Extract node features
        features_i = np.array(
            [graph_i.nodes[n]['attributes'] for n in graph_i.nodes()])
        features_j = np.array(
            [graph_j.nodes[n]['attributes'] for n in graph_j.nodes()])

        # Compute metric cost matrix between features
        M = ot.dist(features_i, features_j, metric='euclidean')

        # Compute fGW distance
        try:
            fgw_result = ot.gromov.fused_gromov_wasserstein2(
                M,
                distance_matrices[i],
                distance_matrices[j],
                heights[i],
                heights[j],
                loss_fun='square_loss',
                alpha=0.9,
                log=True)
            fgw_value = fgw_result[0]
            fgw_matrix[i, j] = fgw_value

            # Check for negative values
            if fgw_value < 0:
                negative_fgw_count += 1
                negative_fgw_pairs.append((i, j, fgw_value))

            # Check for NaN values
            if np.isnan(fgw_value):
                print(f"NaN fGW distance found: graphs {i} and {j}")

        except Exception as e:
            print(
                f"Error computing fGW distance between graphs {i} and {j}: {e}"
            )
            fgw_matrix[i, j] = np.nan

# Make matrix symmetric
fgw_matrix += fgw_matrix.T

print(f"\nfGW computation summary:")
print(f"Total negative values found: {negative_fgw_count}")
print(f"Min fGW value: {np.min(fgw_matrix[fgw_matrix != 0])}")
print(f"Max fGW value: {np.max(fgw_matrix)}")
print(f"Number of NaN values: {np.sum(np.isnan(fgw_matrix))}")

# Print first few negative pairs if any
if negative_fgw_pairs:
    print(f"\nFirst 5 negative fGW pairs:")
    for i, (idx_i, idx_j, val) in enumerate(negative_fgw_pairs[:5]):
        print(f"  Pair {i+1}: graphs {idx_i} and {idx_j}, value: {val}")

# Handle negative values by taking absolute value if needed
if negative_fgw_count > 0:
    print("Taking absolute values of negative fGW distances...")
    fgw_matrix = np.abs(fgw_matrix)
# Out:
# fGW computation summary:
# Total negative values found: 0
# Min fGW value: 0.0010767015007226988
# Max fGW value: 33.43964909929668
# Number of NaN values: 0

# %%
# Create scatterplot of fGW distances by class
plt.figure(figsize=(10, 8))

# Convert labels to numpy array for easier indexing
labels_array = np.array(labels_list)

# Get indices for each class
class_1_indices = np.where(labels_array == 1)[0]  # Active class
class_minus1_indices = np.where(labels_array == -1)[0]  # Inactive class

# Extract fGW distances for different class combinations
# Within class 1 (active vs active)
within_class1_fgw_distances = []
for i in range(len(class_1_indices)):
    for j in range(i + 1, len(class_1_indices)):
        idx_i, idx_j = class_1_indices[i], class_1_indices[j]
        within_class1_fgw_distances.append(fgw_matrix[idx_i, idx_j])

# Within class -1 (inactive vs inactive)
within_class_minus1_fgw_distances = []
for i in range(len(class_minus1_indices)):
    for j in range(i + 1, len(class_minus1_indices)):
        idx_i, idx_j = class_minus1_indices[i], class_minus1_indices[j]
        within_class_minus1_fgw_distances.append(fgw_matrix[idx_i, idx_j])

# Between classes (active vs inactive)
between_classes_fgw_distances = []
for i in class_1_indices:
    for j in class_minus1_indices:
        between_classes_fgw_distances.append(fgw_matrix[i, j])

# Create scatter plot
x_positions_fgw = []
distances_fgw = []
colors_fgw = []
labels_plot_fgw = []

# Add within class 1 distances
x_positions_fgw.extend([0] * len(within_class1_fgw_distances))
distances_fgw.extend(within_class1_fgw_distances)
colors_fgw.extend(['blue'] * len(within_class1_fgw_distances))
labels_plot_fgw.extend(['Active vs Active'] * len(within_class1_fgw_distances))

# Add within class -1 distances
x_positions_fgw.extend([1] * len(within_class_minus1_fgw_distances))
distances_fgw.extend(within_class_minus1_fgw_distances)
colors_fgw.extend(['orange'] * len(within_class_minus1_fgw_distances))
labels_plot_fgw.extend(['Inactive vs Inactive'] *
                       len(within_class_minus1_fgw_distances))

# Add between classes distances
x_positions_fgw.extend([2] * len(between_classes_fgw_distances))
distances_fgw.extend(between_classes_fgw_distances)
colors_fgw.extend(['gray'] * len(between_classes_fgw_distances))
labels_plot_fgw.extend(['Active vs Inactive'] *
                       len(between_classes_fgw_distances))

# Create the scatter plot
scatter_fgw = plt.scatter(x_positions_fgw,
                          distances_fgw,
                          c=colors_fgw,
                          alpha=0.6,
                          s=30)

# Customize the plot
plt.xlabel('Class Comparison')
plt.ylabel('Fused Gromov-Wasserstein Distance')
plt.title('Fused Gromov-Wasserstein Distances Between Graph Classes')
plt.xticks([0, 1, 2], [
    'Active vs Active\n(Class 1)', 'Inactive vs Inactive\n(Class -1)',
    'Active vs Inactive\n(Cross-class)'
])

# Add legend
legend_elements_fgw = [
    Patch(facecolor='blue', label='Active vs Active'),
    Patch(facecolor='orange', label='Inactive vs Inactive'),
    Patch(facecolor='gray', label='Active vs Inactive')
]
plt.legend(handles=legend_elements_fgw)

# Add some statistics
print(f"\nfGW Distance Statistics:")
print(
    f"Within Active class - Mean: {np.mean(within_class1_fgw_distances):.4f}, Std: {np.std(within_class1_fgw_distances):.4f}"
)
print(
    f"Within Inactive class - Mean: {np.mean(within_class_minus1_fgw_distances):.4f}, Std: {np.std(within_class_minus1_fgw_distances):.4f}"
)
print(
    f"Between classes - Mean: {np.mean(between_classes_fgw_distances):.4f}, Std: {np.std(between_classes_fgw_distances):.4f}"
)

plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# fGW Distance Statistics:
# Within Active class - Mean: 3.6903, Std: 2.7498
# Within Inactive class - Mean: 3.5984, Std: 2.7276
# Between classes - Mean: 3.8714, Std: 2.9816

# %%
# Perform statistical test for fGW
active_vs_inactive_fgw_mean = np.mean(between_classes_fgw_distances)
within_active_fgw_mean = np.mean(within_class1_fgw_distances)
within_inactive_fgw_mean = np.mean(within_class_minus1_fgw_distances)

print(f"\nfGW Statistical Summary:")
print(f"Number of Active graphs: {len(class_1_indices)}")
print(f"Number of Inactive graphs: {len(class_minus1_indices)}")
print(
    f"Number of within-Active comparisons: {len(within_class1_fgw_distances)}")
print(
    f"Number of within-Inactive comparisons: {len(within_class_minus1_fgw_distances)}"
)
print(
    f"Number of cross-class comparisons: {len(between_classes_fgw_distances)}")

# Test if between-class fGW distances are significantly different from within-class distances
all_within_class_fgw = within_class1_fgw_distances + within_class_minus1_fgw_distances
t_stat_fgw, p_value_fgw = ttest_ind(between_classes_fgw_distances,
                                    all_within_class_fgw)
print(f"\nT-test for fGW (Between-class vs Within-class distances):")
print(f"T-statistic: {t_stat_fgw:.4f}")
print(f"P-value: {p_value_fgw:.4f}")
print(f"Significant difference: {'Yes' if p_value_fgw < 0.05 else 'No'}")

# Final comparison between all three methods
print(f"fGW between-class mean: {active_vs_inactive_fgw_mean:.4f}")
print(f"fGW within-active mean: {within_active_fgw_mean:.4f}")
print(f"fGW within-inactive mean: {within_inactive_fgw_mean:.4f}")
# Out:
# fGW Statistical Summary:
# Number of Active graphs: 86
# Number of Inactive graphs: 319
# Number of within-Active comparisons: 3655
# Number of within-Inactive comparisons: 50721
# Number of cross-class comparisons: 27434
#
# T-test for fGW (Between-class vs Within-class distances):
# T-statistic: 12.7897
# P-value: 0.0000
# Significant difference: Yes
# fGW between-class mean: 3.8714
# fGW within-active mean: 3.6903
# fGW within-inactive mean: 3.5984

# %%
### Distances Scatterplots: Distances from GW & fGW Barycenters of Each Class ###
# Compute the GW barycenter for each category
num_nodes = 36
seed = 42
X_class1 = [
           distance_matrices[j] for j in range(len(distance_matrices)) if labels_list[j] == -1
        ]
X_class2 = [
            distance_matrices[j] for j in range(len(distance_matrices)) if labels_list[j] == 1
        ]
barycenter_matrix_class1 = ot.gromov.gromov_barycenters(
    N=num_nodes,
    Cs=X_class1,
    loss_fun='square_loss',
    random_state=seed)
print("GW barycenter for Class 1 graphs:",
          barycenter_matrix_class1)
print("GW barycenter for Class 1 graphs computed")
barycenter_matrix_class2 = ot.gromov.gromov_barycenters(
    N=num_nodes,
    Cs=X_class2,
    loss_fun='square_loss',
    random_state=seed)
print("GW barycenter for Class 2 graphs:",
          barycenter_matrix_class2)
print("GW barycenter for Class 2 graphs computed")
# Out:
# GW barycenter for Class 1 graphs: [[0.39369686 3.93306677 1.34467752 ... 2.20882423 4.40127825 2.85611441]
#  [3.93306677 0.51539675 4.82467705 ... 2.7505939  7.99004809 4.08935843]
#  [1.34467752 4.82467705 0.4005443  ... 2.94290825 3.46216639 3.58216802]
#  ...
#  [2.20882423 2.7505939  2.94290825 ... 0.49949786 6.17417117 2.60822543]
#  [4.40127825 7.99004809 3.46216639 ... 6.17417117 0.50176171 6.80834228]
#  [2.85611441 4.08935843 3.58216802 ... 2.60822543 6.80834228 0.60041516]]
# GW barycenter for Class 1 graphs computed
# GW barycenter for Class 2 graphs: [[0.19962676 5.61003209 1.95992381 ... 3.05494015 3.49470422 3.65286837]
#  [5.61003209 0.26727105 5.82800789 ... 3.16345499 8.94585851 2.60187731]
#  [1.95992381 5.82800789 0.36108329 ... 3.65792342 4.57882855 4.05525076]
#  ...
#  [3.05494015 3.16345499 3.65792342 ... 0.45466163 6.38943894 1.8142597 ]
#  [3.49470422 8.94585851 4.57882855 ... 6.38943894 0.29689562 7.01546297]
#  [3.65286837 2.60187731 4.05525076 ... 1.8142597  7.01546297 0.36713879]]
# GW barycenter for Class 2 graphs computed

# %%
def compute_gromov_wasserstein_distance(adj_matrix1, adj_matrix2):
    """
    Compute the Gromov-Wasserstein distance between two adjacency matrices.
    
    Args:
        adj_matrix1: First adjacency matrix
        adj_matrix2: Second adjacency matrix
    
    Returns:
        The Gromov-Wasserstein distance
    """
    n1, n2 = adj_matrix1.shape[0], adj_matrix2.shape[0]
    
    # Create uniform distributions
    p = np.ones(n1) / n1
    q = np.ones(n2) / n2
    
    # Compute Gromov-Wasserstein distance
    gw_dist = np.abs(ot.gromov.gromov_wasserstein2(adj_matrix1, adj_matrix2, p, q, 'square_loss'))
    
    return np.sqrt(gw_dist)

# %%
# Distances from each class to each barycenter
gw_distances_from_negone_to_negonebary = []
gw_distances_from_one_to_negonebary = []
gw_distances_from_negone_to_onebary = []
gw_distances_from_one_to_onebary = []

for j in range(len(distance_matrices)):
    if labels_list[j] == -1:
        dist_negone = compute_gromov_wasserstein_distance(distance_matrices[j], barycenter_matrix_class1)
        dist_one = compute_gromov_wasserstein_distance(distance_matrices[j], barycenter_matrix_class2)
        gw_distances_from_negone_to_negonebary.append(dist_negone)
        gw_distances_from_negone_to_onebary.append(dist_one)
    else:
        dist_negone = compute_gromov_wasserstein_distance(distance_matrices[j], barycenter_matrix_class1)
        dist_one = compute_gromov_wasserstein_distance(distance_matrices[j], barycenter_matrix_class2)
        gw_distances_from_one_to_negonebary.append(dist_negone)
        gw_distances_from_one_to_onebary.append(dist_one)

# %%
# Plot results
distances = (gw_distances_from_negone_to_negonebary + gw_distances_from_one_to_negonebary + 
            gw_distances_from_negone_to_onebary + gw_distances_from_one_to_onebary)
min_dist = min(distances)
max_dist = max(distances)
margin = (max_dist - min_dist) * 0.05  # Add 5% margin

axis_min = min_dist - margin
axis_max = max_dist + margin

plt.figure(figsize=(12, 5))
plt.scatter(gw_distances_from_negone_to_negonebary, gw_distances_from_negone_to_onebary, 
           alpha=0.6, label='Class -1 Graphs', color='blue')
plt.scatter(gw_distances_from_one_to_negonebary, gw_distances_from_one_to_onebary, 
           alpha=0.6, label='Class 1 Graphs', color='orange')
# Add diagonal line
plt.plot([axis_min, axis_max], [axis_min, axis_max],'k--', alpha=0.5, linewidth=1, label='y = x')
plt.xlabel('Distance to Class 1 (Active) Barycenter')
plt.ylabel('Distance to Class -1 (Inactive) Barycenter')
plt.title('BZR: GW Distances to GW Barycenters')
plt.legend()
plt.grid(True, alpha=0.3)

# %%
## Repeat the same experiment with fGW distances and fGW barycenters ##
# Compute the fGW barycenter for each category
# Get node attributes for class 1
num_nodes_class1 = 36
num_nodes_class2 = 36
features_class1 = []
class1_indices = [
    j for j in range(len(distance_matrices)) if labels_list[j] == -1
]
for graph_idx in class1_indices:
    graph = graphs_list[graph_idx]
    graph_features = np.array(
        [graph.nodes[n]['attributes'] for n in graph.nodes()])
    features_class1.append(graph_features)

# Create uniform distributions for each graph
ps_class1 = [
    np.ones(len(features)) / len(features)
    for features in features_class1
]
lambdas_class1 = np.ones(len(features_class1)) / len(features_class1)

barycenter_features_class1, barycenter_matrix_class1, log_class1 = ot.gromov.fgw_barycenters(
    N=num_nodes_class1,
    Ys=features_class1,
    Cs=X_class1,
    ps=ps_class1,
    lambdas=lambdas_class1,
    alpha=0.3,
    loss_fun='square_loss',
    random_state=seed,
    log=True)

print("GW barycenter for Class 1 graphs:",
          barycenter_matrix_class1)
print("GW barycenter for Class 1 graphs computed")

# Get node attributes for class 2
features_class2 = []
class2_indices = [
    j for j in range(len(distance_matrices)) if labels_list[j] == 1
]
for graph_idx in class2_indices:
    graph = graphs_list[graph_idx]
    graph_features = np.array(
        [graph.nodes[n]['attributes'] for n in graph.nodes()])
    features_class2.append(graph_features)

# Create uniform distributions for each graph
ps_class2 = [
    np.ones(len(features)) / len(features)
    for features in features_class2
]
lambdas_class2 = np.ones(len(features_class2)) / len(features_class2)

barycenter_features_class2, barycenter_matrix_class2, log_class2 = ot.gromov.fgw_barycenters(
    N=num_nodes_class2,
    Ys=features_class2,
    Cs=X_class2,
    ps=ps_class2,
    lambdas=lambdas_class2,
    alpha=0.3,
    loss_fun='square_loss',
    random_state=seed,
    log=True)
print("GW barycenter for Class 2 graphs:",
          barycenter_matrix_class2)
print("GW barycenter for Class 2 graphs computed")
# Out:
# GW barycenter for Class 1 graphs: [[0.38491689 3.61264224 1.58543476 ... 2.64100557 4.69781846 3.77848299]
#  [3.61264224 0.66907876 4.69543625 ... 2.07074635 6.88316777 3.51710493]
#  [1.58543476 4.69543625 0.3870469  ... 3.89877521 3.64800289 4.97831084]
#  ...
#  [2.64100557 2.07074635 3.89877521 ... 0.34489064 6.68908963 1.70752253]
#  [4.69781846 6.88316777 3.64800289 ... 6.68908963 0.44716973 7.8534072 ]
#  [3.77848299 3.51710493 4.97831084 ... 1.70752253 7.8534072  0.29263357]]
# GW barycenter for Class 1 graphs computed
# GW barycenter for Class 2 graphs: [[0.41166951 2.98903313 1.26536342 ... 2.91983322 2.41028848 3.80657935]
#  [2.98903313 0.47763293 3.8906499  ... 2.9834438  4.93331074 2.49023658]
#  [1.26536342 3.8906499  0.28567188 ... 3.32431896 2.02332396 4.3907061 ]
#  ...
#  [2.91983322 2.9834438  3.32431896 ... 0.39683896 4.93357015 2.16986904]
#  [2.41028848 4.93331074 2.02332396 ... 4.93357015 0.40964878 5.86881595]
#  [3.80657935 2.49023658 4.3907061  ... 2.16986904 5.86881595 0.43896041]]
# GW barycenter for Class 2 graphs computed

# %%
def compute_fused_gromov_wasserstein_distance(graph_obj, matrix1, matrix2, bary_features):
    for n in graph_obj.nodes():
        m1_features = [graph_obj.nodes[n]['attributes']]

    # Compute metric cost matrix for graph
    M = ot.dist(np.array(m1_features), bary_features)

    fgw, log_fgw = ot.gromov.fused_gromov_wasserstein(
        M,
        matrix1,
        matrix2,
        loss_fun='square_loss',
        alpha=0.9,
        log=True)

    return log_fgw['fgw_dist']

# %%
# Distances from each class to each barycenter
fgw_distances_from_negone_to_negonebary = []
fgw_distances_from_one_to_negonebary = []
fgw_distances_from_negone_to_onebary = []
fgw_distances_from_one_to_onebary = []

for j in range(len(distance_matrices)):
    if labels_list[j] == -1:
        
        dist_negone = compute_fused_gromov_wasserstein_distance(graphs_list[j], distance_matrices[j], barycenter_matrix_class1, barycenter_features_class1)
        dist_one = compute_fused_gromov_wasserstein_distance(graphs_list[j], distance_matrices[j], barycenter_matrix_class2, barycenter_features_class2)
        fgw_distances_from_negone_to_negonebary.append(dist_negone)
        fgw_distances_from_negone_to_onebary.append(dist_one) 
    else:
        dist_negone = compute_fused_gromov_wasserstein_distance(graphs_list[j], distance_matrices[j], barycenter_matrix_class1, barycenter_features_class1)
        dist_one = compute_fused_gromov_wasserstein_distance(graphs_list[j], distance_matrices[j], barycenter_matrix_class2, barycenter_features_class2)
        fgw_distances_from_one_to_negonebary.append(dist_negone)
        fgw_distances_from_one_to_onebary.append(dist_one)

# %%
# Plot results
distances_fgw = (fgw_distances_from_negone_to_negonebary + fgw_distances_from_one_to_negonebary + 
            fgw_distances_from_negone_to_onebary + fgw_distances_from_one_to_onebary)
min_dist = min(distances_fgw)
max_dist = max(distances_fgw)
margin = (max_dist - min_dist) * 0.03  # Add 3% margin

axis_min = min_dist - margin
axis_max = max_dist + margin

plt.figure(figsize=(12, 5))
plt.scatter(fgw_distances_from_negone_to_negonebary, fgw_distances_from_negone_to_onebary, 
           alpha=0.6, label='Class -1 Graphs', color='blue')
plt.scatter(fgw_distances_from_one_to_negonebary, fgw_distances_from_one_to_onebary, 
           alpha=0.6, label='Class 1 Graphs', color='orange')
# Add diagonal line
plt.plot([axis_min, axis_max], [axis_min, axis_max],'k--', alpha=0.5, linewidth=1, label='y = x')
plt.xlabel('Distance to Class 1 (Active) Barycenter')
plt.ylabel('Distance to Class -1 (Inactive) Barycenter')
plt.title('BZR: fGW Distances to fGW Barycenters')
plt.legend()
plt.grid(True, alpha=0.3)
