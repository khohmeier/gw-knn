# %%
import networkx as nx
import numpy as np
from gwgraphs import *

# %%
def read_graph_data():
    # Read the adjacency matrix (edges)
    with open("COX2_A.txt", "r") as f:
        edges = [tuple(map(int, line.split(','))) for line in f]

    # Read graph indicators
    with open("COX2_graph_indicator.txt", "r") as f:
        graph_indicators = [int(line.strip()) for line in f if line.strip()]

    # Read graph labels
    with open("COX2_graph_labels.txt", "r") as f:
        graph_labels = [int(line.strip()) for line in f]

    # Read node labels
    with open("COX2_node_labels.txt", "r") as f:
        node_labels = [int(line.strip()) for line in f]

    return edges, graph_indicators, graph_labels, node_labels


def construct_networkx_graph(edges, graph_indicators, graph_labels,
                             node_labels):
    graphs = {}
    for node_id, graph_id in enumerate(graph_indicators, start=1):
        if graph_id not in graphs:
            graphs[graph_id] = nx.Graph(label=graph_labels[graph_id - 1])

    for edge in edges:
        node1, node2 = edge
        graph_id = graph_indicators[
            node1 - 1]  # Determine which graph the edge belongs to
        graphs[graph_id].add_edge(node1, node2)

    for node_id, (graph_id,
                  node_label) in enumerate(zip(graph_indicators, node_labels),
                                           start=1):
        graphs[graph_id].nodes[node_id]['label'] = node_label

    return graphs


def compute_averages(graphs):
    # Initialize variables
    total_nodes = 0
    class_nodes = {}
    class_counts = {}
    # Iterate through graphs to compute totals
    for graph_id, graph in graphs.items():
        num_nodes = graph.number_of_nodes()
        total_nodes += num_nodes
        
        # Get the class label for the current graph
        graph_label = graph.graph['label']
        
        if graph_label not in class_nodes:
            class_nodes[graph_label] = 0
            class_counts[graph_label] = 0
        
        class_nodes[graph_label] += num_nodes
        class_counts[graph_label] += 1
    # Calculate total average
    total_avg = round(total_nodes / len(graphs))
    
    # Calculate class-based averages
    class_averages = {label: round(class_nodes[label] / count)
                      for label, count in class_counts.items()}
    
    return total_avg, class_averages


def compute_distance_matrix(graph):
    num_nodes = len(graph.nodes)
    distance_matrix = np.full((num_nodes, num_nodes), 10000.0)

    # Get the correct node indices to be used for indexing the matrix
    node_list = list(graph.nodes())
    node_index = {node: i for i, node in enumerate(node_list)}

    for node in graph.nodes:
        lengths = nx.shortest_path_length(graph, source=node, weight="weight")

        for target, length in lengths.items():
            if target in node_index:
                distance_matrix[node_index[node], node_index[target]] = length

    return distance_matrix

# %%
edges, graph_indicators, graph_labels, node_labels = read_graph_data()
graphs = construct_networkx_graph(edges, graph_indicators, graph_labels,
                                      node_labels)
for graph_id, graph in graphs.items():
    print(
        f"Graph ID: {graph_id}, number of nodes: {graph.number_of_nodes()}, label: {graph.graph['label']}"
        )
total_avg, class_averages = compute_averages(graphs)
print(f"Average number of nodes in entire dataset: {total_avg}")
print("Average number of nodes for each class:")
for class_label, avg_nodes in class_averages.items():
        print(f"  Class {class_label}: {avg_nodes}")
# Out:
# Graph ID: 1, number of nodes: 39, label: -1
# Graph ID: 2, number of nodes: 36, label: -1
# Graph ID: 3, number of nodes: 36, label: 1
# Graph ID: 4, number of nodes: 39, label: -1
# Graph ID: 5, number of nodes: 42, label: -1
# Graph ID: 6, number of nodes: 42, label: -1
# Graph ID: 7, number of nodes: 44, label: -1
# Graph ID: 8, number of nodes: 39, label: -1
# Graph ID: 9, number of nodes: 42, label: 1
# Graph ID: 10, number of nodes: 42, label: 1
# Graph ID: 11, number of nodes: 45, label: 1
# Graph ID: 12, number of nodes: 49, label: 1
# Graph ID: 13, number of nodes: 42, label: 1
# Graph ID: 14, number of nodes: 35, label: -1
# Graph ID: 15, number of nodes: 44, label: 1
# Graph ID: 16, number of nodes: 47, label: 1
# Graph ID: 17, number of nodes: 45, label: 1
# Graph ID: 18, number of nodes: 39, label: 1
# Graph ID: 19, number of nodes: 44, label: -1
# Graph ID: 20, number of nodes: 44, label: -1
# Graph ID: 21, number of nodes: 51, label: -1
# Graph ID: 22, number of nodes: 45, label: -1
# Graph ID: 23, number of nodes: 41, label: 1
# Graph ID: 24, number of nodes: 40, label: -1
# Graph ID: 25, number of nodes: 39, label: -1
# Graph ID: 26, number of nodes: 39, label: -1
# Graph ID: 27, number of nodes: 50, label: 1
# Graph ID: 28, number of nodes: 48, label: -1
# Graph ID: 29, number of nodes: 43, label: 1
# Graph ID: 30, number of nodes: 53, label: -1
# Graph ID: 31, number of nodes: 53, label: -1
# Graph ID: 32, number of nodes: 46, label: -1
# Graph ID: 33, number of nodes: 45, label: -1
# Graph ID: 34, number of nodes: 56, label: 1
# Graph ID: 35, number of nodes: 45, label: -1
# Graph ID: 36, number of nodes: 38, label: -1
# Graph ID: 37, number of nodes: 38, label: -1
# Graph ID: 38, number of nodes: 38, label: -1
# Graph ID: 39, number of nodes: 38, label: -1
# Graph ID: 40, number of nodes: 41, label: -1
# Graph ID: 41, number of nodes: 42, label: -1
# Graph ID: 42, number of nodes: 43, label: -1
# Graph ID: 43, number of nodes: 46, label: -1
# Graph ID: 44, number of nodes: 42, label: -1
# Graph ID: 45, number of nodes: 43, label: 1
# Graph ID: 46, number of nodes: 44, label: 1
# Graph ID: 47, number of nodes: 37, label: -1
# Graph ID: 48, number of nodes: 37, label: -1
# Graph ID: 49, number of nodes: 37, label: -1
# Graph ID: 50, number of nodes: 40, label: -1
# Graph ID: 51, number of nodes: 38, label: -1
# Graph ID: 52, number of nodes: 38, label: -1
# Graph ID: 53, number of nodes: 38, label: -1
# Graph ID: 54, number of nodes: 41, label: -1
# Graph ID: 55, number of nodes: 41, label: -1
# Graph ID: 56, number of nodes: 42, label: -1
# Graph ID: 57, number of nodes: 42, label: -1
# Graph ID: 58, number of nodes: 45, label: 1
# Graph ID: 59, number of nodes: 46, label: 1
# Graph ID: 60, number of nodes: 43, label: -1
# Graph ID: 61, number of nodes: 40, label: 1
# Graph ID: 62, number of nodes: 40, label: -1
# Graph ID: 63, number of nodes: 37, label: -1
# Graph ID: 64, number of nodes: 37, label: -1
# Graph ID: 65, number of nodes: 37, label: -1
# Graph ID: 66, number of nodes: 40, label: -1
# Graph ID: 67, number of nodes: 38, label: -1
# Graph ID: 68, number of nodes: 38, label: -1
# Graph ID: 69, number of nodes: 41, label: -1
# Graph ID: 70, number of nodes: 42, label: 1
# Graph ID: 71, number of nodes: 37, label: -1
# Graph ID: 72, number of nodes: 40, label: -1
# Graph ID: 73, number of nodes: 42, label: -1
# Graph ID: 74, number of nodes: 42, label: -1
# Graph ID: 75, number of nodes: 42, label: -1
# Graph ID: 76, number of nodes: 46, label: -1
# Graph ID: 77, number of nodes: 46, label: -1
# Graph ID: 78, number of nodes: 43, label: -1
# Graph ID: 79, number of nodes: 41, label: -1
# Graph ID: 80, number of nodes: 41, label: -1
# Graph ID: 81, number of nodes: 41, label: -1
# Graph ID: 82, number of nodes: 41, label: -1
# Graph ID: 83, number of nodes: 42, label: -1
# Graph ID: 84, number of nodes: 46, label: -1
# Graph ID: 85, number of nodes: 41, label: -1
# Graph ID: 86, number of nodes: 38, label: -1
# Graph ID: 87, number of nodes: 44, label: -1
# Graph ID: 88, number of nodes: 41, label: -1
# Graph ID: 89, number of nodes: 41, label: -1
# Graph ID: 90, number of nodes: 42, label: -1
# Graph ID: 91, number of nodes: 41, label: 1
# Graph ID: 92, number of nodes: 38, label: -1
# Graph ID: 93, number of nodes: 41, label: 1
# Graph ID: 94, number of nodes: 41, label: 1
# Graph ID: 95, number of nodes: 41, label: -1
# Graph ID: 96, number of nodes: 41, label: -1
# Graph ID: 97, number of nodes: 41, label: -1
# Graph ID: 98, number of nodes: 41, label: -1
# Graph ID: 99, number of nodes: 40, label: -1
# Graph ID: 100, number of nodes: 41, label: -1
# Graph ID: 101, number of nodes: 37, label: -1
# Graph ID: 102, number of nodes: 40, label: -1
# Graph ID: 103, number of nodes: 40, label: -1
# Graph ID: 104, number of nodes: 41, label: -1
# Graph ID: 105, number of nodes: 42, label: -1
# Graph ID: 106, number of nodes: 42, label: -1
# Graph ID: 107, number of nodes: 42, label: -1
# Graph ID: 108, number of nodes: 48, label: -1
# Graph ID: 109, number of nodes: 48, label: 1
# Graph ID: 110, number of nodes: 46, label: -1
# Graph ID: 111, number of nodes: 41, label: -1
# Graph ID: 112, number of nodes: 35, label: 1
# Graph ID: 113, number of nodes: 38, label: -1
# Graph ID: 114, number of nodes: 38, label: -1
# Graph ID: 115, number of nodes: 37, label: -1
# Graph ID: 116, number of nodes: 36, label: -1
# Graph ID: 117, number of nodes: 44, label: 1
# Graph ID: 118, number of nodes: 38, label: 1
# Graph ID: 119, number of nodes: 52, label: 1
# Graph ID: 120, number of nodes: 40, label: 1
# Graph ID: 121, number of nodes: 45, label: -1
# Graph ID: 122, number of nodes: 49, label: -1
# Graph ID: 123, number of nodes: 49, label: -1
# Graph ID: 124, number of nodes: 42, label: 1
# Graph ID: 125, number of nodes: 39, label: 1
# Graph ID: 126, number of nodes: 42, label: -1
# Graph ID: 127, number of nodes: 44, label: 1
# Graph ID: 128, number of nodes: 39, label: -1
# Graph ID: 129, number of nodes: 37, label: -1
# Graph ID: 130, number of nodes: 40, label: 1
# Graph ID: 131, number of nodes: 40, label: -1
# Graph ID: 132, number of nodes: 40, label: -1
# Graph ID: 133, number of nodes: 40, label: 1
# Graph ID: 134, number of nodes: 41, label: -1
# Graph ID: 135, number of nodes: 41, label: 1
# Graph ID: 136, number of nodes: 37, label: -1
# Graph ID: 137, number of nodes: 36, label: -1
# Graph ID: 138, number of nodes: 39, label: -1
# Graph ID: 139, number of nodes: 39, label: -1
# Graph ID: 140, number of nodes: 39, label: -1
# Graph ID: 141, number of nodes: 39, label: 1
# Graph ID: 142, number of nodes: 40, label: 1
# Graph ID: 143, number of nodes: 36, label: -1
# Graph ID: 144, number of nodes: 37, label: 1
# Graph ID: 145, number of nodes: 35, label: 1
# Graph ID: 146, number of nodes: 37, label: 1
# Graph ID: 147, number of nodes: 43, label: 1
# Graph ID: 148, number of nodes: 38, label: 1
# Graph ID: 149, number of nodes: 36, label: -1
# Graph ID: 150, number of nodes: 40, label: -1
# Graph ID: 151, number of nodes: 40, label: -1
# Graph ID: 152, number of nodes: 40, label: -1
# Graph ID: 153, number of nodes: 40, label: 1
# Graph ID: 154, number of nodes: 39, label: -1
# Graph ID: 155, number of nodes: 39, label: -1
# Graph ID: 156, number of nodes: 39, label: -1
# Graph ID: 157, number of nodes: 39, label: -1
# Graph ID: 158, number of nodes: 43, label: -1
# Graph ID: 159, number of nodes: 43, label: -1
# Graph ID: 160, number of nodes: 43, label: -1
# Graph ID: 161, number of nodes: 45, label: -1
# Graph ID: 162, number of nodes: 41, label: -1
# Graph ID: 163, number of nodes: 41, label: -1
# Graph ID: 164, number of nodes: 35, label: 1
# Graph ID: 165, number of nodes: 35, label: -1
# Graph ID: 166, number of nodes: 34, label: -1
# Graph ID: 167, number of nodes: 35, label: -1
# Graph ID: 168, number of nodes: 38, label: -1
# Graph ID: 169, number of nodes: 37, label: -1
# Graph ID: 170, number of nodes: 36, label: -1
# Graph ID: 171, number of nodes: 36, label: -1
# Graph ID: 172, number of nodes: 36, label: -1
# Graph ID: 173, number of nodes: 37, label: 1
# Graph ID: 174, number of nodes: 36, label: -1
# Graph ID: 175, number of nodes: 39, label: -1
# Graph ID: 176, number of nodes: 43, label: -1
# Graph ID: 177, number of nodes: 39, label: -1
# Graph ID: 178, number of nodes: 42, label: -1
# Graph ID: 179, number of nodes: 39, label: -1
# Graph ID: 180, number of nodes: 42, label: -1
# Graph ID: 181, number of nodes: 39, label: -1
# Graph ID: 182, number of nodes: 40, label: 1
# Graph ID: 183, number of nodes: 43, label: 1
# Graph ID: 184, number of nodes: 46, label: 1
# Graph ID: 185, number of nodes: 43, label: -1
# Graph ID: 186, number of nodes: 42, label: -1
# Graph ID: 187, number of nodes: 45, label: -1
# Graph ID: 188, number of nodes: 45, label: -1
# Graph ID: 189, number of nodes: 45, label: -1
# Graph ID: 190, number of nodes: 51, label: 1
# Graph ID: 191, number of nodes: 45, label: -1
# Graph ID: 192, number of nodes: 39, label: -1
# Graph ID: 193, number of nodes: 39, label: -1
# Graph ID: 194, number of nodes: 42, label: 1
# Graph ID: 195, number of nodes: 39, label: 1
# Graph ID: 196, number of nodes: 39, label: -1
# Graph ID: 197, number of nodes: 43, label: -1
# Graph ID: 198, number of nodes: 43, label: -1
# Graph ID: 199, number of nodes: 43, label: -1
# Graph ID: 200, number of nodes: 42, label: -1
# Graph ID: 201, number of nodes: 47, label: -1
# Graph ID: 202, number of nodes: 42, label: -1
# Graph ID: 203, number of nodes: 38, label: -1
# Graph ID: 204, number of nodes: 38, label: -1
# Graph ID: 205, number of nodes: 38, label: -1
# Graph ID: 206, number of nodes: 38, label: -1
# Graph ID: 207, number of nodes: 38, label: -1
# Graph ID: 208, number of nodes: 38, label: -1
# Graph ID: 209, number of nodes: 42, label: -1
# Graph ID: 210, number of nodes: 42, label: -1
# Graph ID: 211, number of nodes: 42, label: -1
# Graph ID: 212, number of nodes: 42, label: -1
# Graph ID: 213, number of nodes: 41, label: -1
# Graph ID: 214, number of nodes: 46, label: -1
# Graph ID: 215, number of nodes: 41, label: -1
# Graph ID: 216, number of nodes: 41, label: -1
# Graph ID: 217, number of nodes: 38, label: -1
# Graph ID: 218, number of nodes: 38, label: -1
# Graph ID: 219, number of nodes: 38, label: -1
# Graph ID: 220, number of nodes: 42, label: 1
# Graph ID: 221, number of nodes: 42, label: 1
# Graph ID: 222, number of nodes: 37, label: -1
# Graph ID: 223, number of nodes: 37, label: -1
# Graph ID: 224, number of nodes: 37, label: -1
# Graph ID: 225, number of nodes: 41, label: -1
# Graph ID: 226, number of nodes: 41, label: -1
# Graph ID: 227, number of nodes: 38, label: -1
# Graph ID: 228, number of nodes: 38, label: -1
# Graph ID: 229, number of nodes: 41, label: -1
# Graph ID: 230, number of nodes: 42, label: -1
# Graph ID: 231, number of nodes: 42, label: -1
# Graph ID: 232, number of nodes: 42, label: 1
# Graph ID: 233, number of nodes: 45, label: -1
# Graph ID: 234, number of nodes: 46, label: -1
# Graph ID: 235, number of nodes: 44, label: -1
# Graph ID: 236, number of nodes: 41, label: -1
# Graph ID: 237, number of nodes: 41, label: -1
# Graph ID: 238, number of nodes: 41, label: -1
# Graph ID: 239, number of nodes: 44, label: -1
# Graph ID: 240, number of nodes: 41, label: -1
# Graph ID: 241, number of nodes: 46, label: -1
# Graph ID: 242, number of nodes: 37, label: -1
# Graph ID: 243, number of nodes: 37, label: -1
# Graph ID: 244, number of nodes: 40, label: -1
# Graph ID: 245, number of nodes: 41, label: -1
# Graph ID: 246, number of nodes: 41, label: -1
# Graph ID: 247, number of nodes: 41, label: -1
# Graph ID: 248, number of nodes: 44, label: -1
# Graph ID: 249, number of nodes: 45, label: -1
# Graph ID: 250, number of nodes: 43, label: -1
# Graph ID: 251, number of nodes: 40, label: -1
# Graph ID: 252, number of nodes: 40, label: -1
# Graph ID: 253, number of nodes: 40, label: -1
# Graph ID: 254, number of nodes: 43, label: -1
# Graph ID: 255, number of nodes: 40, label: -1
# Graph ID: 256, number of nodes: 45, label: -1
# Graph ID: 257, number of nodes: 38, label: -1
# Graph ID: 258, number of nodes: 41, label: -1
# Graph ID: 259, number of nodes: 38, label: 1
# Graph ID: 260, number of nodes: 44, label: 1
# Graph ID: 261, number of nodes: 40, label: -1
# Graph ID: 262, number of nodes: 39, label: -1
# Graph ID: 263, number of nodes: 40, label: 1
# Graph ID: 264, number of nodes: 39, label: -1
# Graph ID: 265, number of nodes: 37, label: -1
# Graph ID: 266, number of nodes: 37, label: -1
# Graph ID: 267, number of nodes: 37, label: 1
# Graph ID: 268, number of nodes: 37, label: -1
# Graph ID: 269, number of nodes: 37, label: -1
# Graph ID: 270, number of nodes: 37, label: -1
# Graph ID: 271, number of nodes: 40, label: -1
# Graph ID: 272, number of nodes: 40, label: -1
# Graph ID: 273, number of nodes: 40, label: -1
# Graph ID: 274, number of nodes: 43, label: -1
# Graph ID: 275, number of nodes: 40, label: 1
# Graph ID: 276, number of nodes: 39, label: -1
# Graph ID: 277, number of nodes: 38, label: 1
# Graph ID: 278, number of nodes: 41, label: -1
# Graph ID: 279, number of nodes: 41, label: -1
# Graph ID: 280, number of nodes: 44, label: -1
# Graph ID: 281, number of nodes: 41, label: -1
# Graph ID: 282, number of nodes: 39, label: -1
# Graph ID: 283, number of nodes: 45, label: 1
# Graph ID: 284, number of nodes: 42, label: -1
# Graph ID: 285, number of nodes: 45, label: -1
# Graph ID: 286, number of nodes: 41, label: 1
# Graph ID: 287, number of nodes: 40, label: 1
# Graph ID: 288, number of nodes: 44, label: -1
# Graph ID: 289, number of nodes: 47, label: -1
# Graph ID: 290, number of nodes: 45, label: -1
# Graph ID: 291, number of nodes: 44, label: -1
# Graph ID: 292, number of nodes: 45, label: -1
# Graph ID: 293, number of nodes: 42, label: -1
# Graph ID: 294, number of nodes: 44, label: -1
# Graph ID: 295, number of nodes: 37, label: -1
# Graph ID: 296, number of nodes: 37, label: -1
# Graph ID: 297, number of nodes: 37, label: 1
# Graph ID: 298, number of nodes: 43, label: -1
# Graph ID: 299, number of nodes: 37, label: -1
# Graph ID: 300, number of nodes: 40, label: 1
# Graph ID: 301, number of nodes: 40, label: -1
# Graph ID: 302, number of nodes: 38, label: 1
# Graph ID: 303, number of nodes: 43, label: 1
# Graph ID: 304, number of nodes: 41, label: 1
# Graph ID: 305, number of nodes: 40, label: 1
# Graph ID: 306, number of nodes: 41, label: -1
# Graph ID: 307, number of nodes: 41, label: -1
# Graph ID: 308, number of nodes: 41, label: -1
# Graph ID: 309, number of nodes: 41, label: -1
# Graph ID: 310, number of nodes: 41, label: -1
# Graph ID: 311, number of nodes: 43, label: 1
# Graph ID: 312, number of nodes: 37, label: -1
# Graph ID: 313, number of nodes: 40, label: 1
# Graph ID: 314, number of nodes: 37, label: 1
# Graph ID: 315, number of nodes: 48, label: -1
# Graph ID: 316, number of nodes: 41, label: -1
# Graph ID: 317, number of nodes: 37, label: 1
# Graph ID: 318, number of nodes: 39, label: 1
# Graph ID: 319, number of nodes: 48, label: -1
# Graph ID: 320, number of nodes: 35, label: -1
# Graph ID: 321, number of nodes: 38, label: -1
# Graph ID: 322, number of nodes: 51, label: -1
# Graph ID: 323, number of nodes: 37, label: -1
# Graph ID: 324, number of nodes: 38, label: -1
# Graph ID: 325, number of nodes: 38, label: 1
# Graph ID: 326, number of nodes: 37, label: -1
# Graph ID: 327, number of nodes: 37, label: -1
# Graph ID: 328, number of nodes: 38, label: -1
# Graph ID: 329, number of nodes: 35, label: -1
# Graph ID: 330, number of nodes: 37, label: 1
# Graph ID: 331, number of nodes: 40, label: -1
# Graph ID: 332, number of nodes: 38, label: -1
# Graph ID: 333, number of nodes: 34, label: -1
# Graph ID: 334, number of nodes: 34, label: -1
# Graph ID: 335, number of nodes: 34, label: 1
# Graph ID: 336, number of nodes: 34, label: 1
# Graph ID: 337, number of nodes: 37, label: 1
# Graph ID: 338, number of nodes: 38, label: -1
# Graph ID: 339, number of nodes: 36, label: -1
# Graph ID: 340, number of nodes: 40, label: 1
# Graph ID: 341, number of nodes: 36, label: 1
# Graph ID: 342, number of nodes: 37, label: -1
# Graph ID: 343, number of nodes: 40, label: -1
# Graph ID: 344, number of nodes: 43, label: -1
# Graph ID: 345, number of nodes: 46, label: 1
# Graph ID: 346, number of nodes: 41, label: -1
# Graph ID: 347, number of nodes: 38, label: 1
# Graph ID: 348, number of nodes: 37, label: -1
# Graph ID: 349, number of nodes: 41, label: -1
# Graph ID: 350, number of nodes: 43, label: 1
# Graph ID: 351, number of nodes: 40, label: 1
# Graph ID: 352, number of nodes: 34, label: 1
# Graph ID: 353, number of nodes: 37, label: 1
# Graph ID: 354, number of nodes: 32, label: 1
# Graph ID: 355, number of nodes: 32, label: 1
# Graph ID: 356, number of nodes: 40, label: -1
# Graph ID: 357, number of nodes: 36, label: -1
# Graph ID: 358, number of nodes: 36, label: 1
# Graph ID: 359, number of nodes: 38, label: -1
# Graph ID: 360, number of nodes: 40, label: -1
# Graph ID: 361, number of nodes: 36, label: 1
# Graph ID: 362, number of nodes: 36, label: 1
# Graph ID: 363, number of nodes: 36, label: 1
# Graph ID: 364, number of nodes: 34, label: -1
# Graph ID: 365, number of nodes: 34, label: -1
# Graph ID: 366, number of nodes: 40, label: -1
# Graph ID: 367, number of nodes: 40, label: -1
# Graph ID: 368, number of nodes: 41, label: -1
# Graph ID: 369, number of nodes: 44, label: -1
# Graph ID: 370, number of nodes: 45, label: -1
# Graph ID: 371, number of nodes: 42, label: -1
# Graph ID: 372, number of nodes: 43, label: -1
# Graph ID: 373, number of nodes: 37, label: 1
# Graph ID: 374, number of nodes: 40, label: -1
# Graph ID: 375, number of nodes: 43, label: -1
# Graph ID: 376, number of nodes: 47, label: -1
# Graph ID: 377, number of nodes: 46, label: -1
# Graph ID: 378, number of nodes: 42, label: -1
# Graph ID: 379, number of nodes: 43, label: -1
# Graph ID: 380, number of nodes: 42, label: -1
# Graph ID: 381, number of nodes: 46, label: -1
# Graph ID: 382, number of nodes: 47, label: -1
# Graph ID: 383, number of nodes: 46, label: -1
# Graph ID: 384, number of nodes: 47, label: -1
# Graph ID: 385, number of nodes: 46, label: -1
# Graph ID: 386, number of nodes: 46, label: -1
# Graph ID: 387, number of nodes: 45, label: -1
# Graph ID: 388, number of nodes: 47, label: -1
# Graph ID: 389, number of nodes: 46, label: -1
# Graph ID: 390, number of nodes: 47, label: -1
# Graph ID: 391, number of nodes: 46, label: -1
# Graph ID: 392, number of nodes: 46, label: -1
# Graph ID: 393, number of nodes: 43, label: -1
# Graph ID: 394, number of nodes: 42, label: -1
# Graph ID: 395, number of nodes: 43, label: -1
# Graph ID: 396, number of nodes: 42, label: -1
# Graph ID: 397, number of nodes: 43, label: -1
# Graph ID: 398, number of nodes: 42, label: -1
# Graph ID: 399, number of nodes: 43, label: -1
# Graph ID: 400, number of nodes: 43, label: -1
# Graph ID: 401, number of nodes: 47, label: -1
# Graph ID: 402, number of nodes: 46, label: -1
# Graph ID: 403, number of nodes: 46, label: -1
# Graph ID: 404, number of nodes: 49, label: -1
# Graph ID: 405, number of nodes: 52, label: 1
# Graph ID: 406, number of nodes: 41, label: -1
# Graph ID: 407, number of nodes: 45, label: -1
# Graph ID: 408, number of nodes: 36, label: -1
# Graph ID: 409, number of nodes: 37, label: -1
# Graph ID: 410, number of nodes: 35, label: -1
# Graph ID: 411, number of nodes: 37, label: -1
# Graph ID: 412, number of nodes: 37, label: -1
# Graph ID: 413, number of nodes: 44, label: -1
# Graph ID: 414, number of nodes: 37, label: -1
# Graph ID: 415, number of nodes: 37, label: -1
# Graph ID: 416, number of nodes: 44, label: 1
# Graph ID: 417, number of nodes: 40, label: -1
# Graph ID: 418, number of nodes: 46, label: -1
# Graph ID: 419, number of nodes: 43, label: -1
# Graph ID: 420, number of nodes: 38, label: -1
# Graph ID: 421, number of nodes: 47, label: -1
# Graph ID: 422, number of nodes: 50, label: -1
# Graph ID: 423, number of nodes: 53, label: -1
# Graph ID: 424, number of nodes: 53, label: -1
# Graph ID: 425, number of nodes: 44, label: -1
# Graph ID: 426, number of nodes: 44, label: -1
# Graph ID: 427, number of nodes: 48, label: -1
# Graph ID: 428, number of nodes: 41, label: -1
# Graph ID: 429, number of nodes: 43, label: -1
# Graph ID: 430, number of nodes: 43, label: -1
# Graph ID: 431, number of nodes: 56, label: 1
# Graph ID: 432, number of nodes: 44, label: -1
# Graph ID: 433, number of nodes: 44, label: -1
# Graph ID: 434, number of nodes: 44, label: -1
# Graph ID: 435, number of nodes: 44, label: 1
# Graph ID: 436, number of nodes: 44, label: -1
# Graph ID: 437, number of nodes: 43, label: -1
# Graph ID: 438, number of nodes: 47, label: -1
# Graph ID: 439, number of nodes: 36, label: -1
# Graph ID: 440, number of nodes: 36, label: -1
# Graph ID: 441, number of nodes: 36, label: -1
# Graph ID: 442, number of nodes: 36, label: -1
# Graph ID: 443, number of nodes: 36, label: -1
# Graph ID: 444, number of nodes: 52, label: -1
# Graph ID: 445, number of nodes: 47, label: -1
# Graph ID: 446, number of nodes: 40, label: -1
# Graph ID: 447, number of nodes: 43, label: -1
# Graph ID: 448, number of nodes: 43, label: -1
# Graph ID: 449, number of nodes: 35, label: 1
# Graph ID: 450, number of nodes: 38, label: 1
# Graph ID: 451, number of nodes: 42, label: 1
# Graph ID: 452, number of nodes: 51, label: -1
# Graph ID: 453, number of nodes: 45, label: -1
# Graph ID: 454, number of nodes: 54, label: -1
# Graph ID: 455, number of nodes: 44, label: -1
# Graph ID: 456, number of nodes: 50, label: -1
# Graph ID: 457, number of nodes: 55, label: -1
# Graph ID: 458, number of nodes: 43, label: -1
# Graph ID: 459, number of nodes: 43, label: -1
# Graph ID: 460, number of nodes: 41, label: -1
# Graph ID: 461, number of nodes: 42, label: -1
# Graph ID: 462, number of nodes: 40, label: -1
# Graph ID: 463, number of nodes: 45, label: -1
# Graph ID: 464, number of nodes: 44, label: -1
# Graph ID: 465, number of nodes: 45, label: -1
# Graph ID: 466, number of nodes: 44, label: -1
# Graph ID: 467, number of nodes: 36, label: 1
# Average number of nodes in entire dataset: 41
# Average number of nodes for each class:
#   Class -1: 41
#   Class 1: 41

# %%
graphs_list = []
labels_list = []
for graph_id, graph in graphs.items():
    # Add the graph object to the list
    graphs_list.append(graph)

    # Extract the label and add to the label list
    label = graph.graph['label']
    labels_list.append(label)

# Convert graphs into pairwise distance matrices
distance_matrices = [compute_distance_matrix(graph) for graph in graphs_list]

# %%
# Balance the dataset by selecting equal numbers from each class
class_1_indices = [i for i, label in enumerate(labels_list) if label == 1]
class_neg1_indices = [i for i, label in enumerate(labels_list) if label == -1]

# Randomly select 102 elements from class -1 to match class 1
random.seed(42)  # Set seed for reproducibility
selected_neg1_indices = random.sample(class_neg1_indices, 102)

# Combine selected indices
balanced_indices = class_1_indices + selected_neg1_indices
random.shuffle(balanced_indices)  # Shuffle to mix the classes

# Create balanced dataset
balanced_graphs_list = [graphs_list[i] for i in balanced_indices]
balanced_labels_list = [labels_list[i] for i in balanced_indices]
balanced_distance_matrices = [distance_matrices[i] for i in balanced_indices]

print(f"\nBalanced dataset:")
print("Elements of Class 1: ", balanced_labels_list.count(1))
print("Elements of Class -1: ", balanced_labels_list.count(-1))

# Update the variables to use balanced data
graphs_list = balanced_graphs_list
labels_list = balanced_labels_list
distance_matrices = balanced_distance_matrices
# Out:
# Balanced dataset:
# Elements of Class 1:  102
# Elements of Class -1:  102

# %%
# Use the dataset's average # of nodes for the barycenters
bzr_exp = gw_barycenter_class_alg_var_nodes(distance_matrices,
                                                 labels_list,
                                                 num_folds=10,
                                                 num_nodes_negone=41,
                                                 num_nodes_one=41,
                                                 method="kfold")
# Out:
# k-fold CV selected
# Fold 0:
# GW barycenter for Class -1 graphs computed
# GW barycenter for Class 1 graphs computed
# Distance between barycenters:  0.11216705956270029  Fold 0
# F1 Score (macro avg): 47.139588100686495%, Fold 0
# Classification Accuracy: 47.61904761904761% Fold 0
# Classification Accuracy for Class -1: 46.15384615384615% Fold 0
# Classification Accuracy for Class 1: 50.0% Fold 0
# Fold 1:
# GW barycenter for Class -1 graphs computed
# GW barycenter for Class 1 graphs computed
# Distance between barycenters:  0.3297991528122702  Fold 1
# F1 Score (macro avg): 45.64705882352942%, Fold 1
# Classification Accuracy: 47.61904761904761% Fold 1
# Classification Accuracy for Class -1: 77.77777777777779% Fold 1
# Classification Accuracy for Class 1: 25.0% Fold 1
# Fold 2:
# GW barycenter for Class -1 graphs computed
# GW barycenter for Class 1 graphs computed
# Distance between barycenters:  0.216101514035397  Fold 2
# F1 Score (macro avg): 52.27272727272727%, Fold 2
# Classification Accuracy: 52.38095238095239% Fold 2
# Classification Accuracy for Class -1: 71.42857142857143% Fold 2
# Classification Accuracy for Class 1: 42.857142857142854% Fold 2
# Fold 3:
# GW barycenter for Class -1 graphs computed
# GW barycenter for Class 1 graphs computed
# Distance between barycenters:  0.20866655660694478  Fold 3
# F1 Score (macro avg): 56.75057208237986%, Fold 3
# Classification Accuracy: 57.14285714285714% Fold 3
# Classification Accuracy for Class -1: 62.5% Fold 3
# Classification Accuracy for Class 1: 53.84615384615385% Fold 3
# Fold 4:
# GW barycenter for Class -1 graphs computed
# GW barycenter for Class 1 graphs computed
# Distance between barycenters:  0.23451967226788756  Fold 4
# F1 Score (macro avg): 59.5959595959596%, Fold 4
# Classification Accuracy: 60.0% Fold 4
# Classification Accuracy for Class -1: 71.42857142857143% Fold 4
# Classification Accuracy for Class 1: 53.84615384615385% Fold 4
# Fold 5:
# GW barycenter for Class -1 graphs computed
# GW barycenter for Class 1 graphs computed
# Distance between barycenters:  0.21667983399390173  Fold 5
# F1 Score (macro avg): 49.494949494949495%, Fold 5
# Classification Accuracy: 50.0% Fold 5
# Classification Accuracy for Class -1: 54.54545454545454% Fold 5
# Classification Accuracy for Class 1: 44.44444444444444% Fold 5
# Fold 6:
# GW barycenter for Class -1 graphs computed
# GW barycenter for Class 1 graphs computed
# Distance between barycenters:  0.32372569018047903  Fold 6
# F1 Score (macro avg): 43.73401534526854%, Fold 6
# Classification Accuracy: 45.0% Fold 6
# Classification Accuracy for Class -1: 60.0% Fold 6
# Classification Accuracy for Class 1: 30.0% Fold 6
# Fold 7:
# GW barycenter for Class -1 graphs computed
# GW barycenter for Class 1 graphs computed
# Distance between barycenters:  0.5779805399891954  Fold 7
# F1 Score (macro avg): 69.6969696969697%, Fold 7
# Classification Accuracy: 70.0% Fold 7
# Classification Accuracy for Class -1: 72.72727272727273% Fold 7
# Classification Accuracy for Class 1: 66.66666666666666% Fold 7
# Fold 8:
# GW barycenter for Class -1 graphs computed
# GW barycenter for Class 1 graphs computed
# Distance between barycenters:  0.4145054791558871  Fold 8
# F1 Score (macro avg): 50.0%, Fold 8
# Classification Accuracy: 50.0% Fold 8
# Classification Accuracy for Class -1: 41.66666666666667% Fold 8
# Classification Accuracy for Class 1: 62.5% Fold 8
# Fold 9:
# GW barycenter for Class -1 graphs computed
# GW barycenter for Class 1 graphs computed
# Distance between barycenters:  0.22658123823872414  Fold 9
# F1 Score (macro avg): 60.00000000000001%, Fold 9
# Classification Accuracy: 70.0% Fold 9
# Classification Accuracy for Class -1: 85.71428571428571% Fold 9
# Classification Accuracy for Class 1: 33.33333333333333% Fold 9
# Total runtime, seconds:
# 2168.283748149872
#
# ==================================================
# SUMMARY STATISTICS
# ==================================================
# Overall Classification Accuracy: 54.98% ± 8.63%
# Class -1 Classification Accuracy: 64.39% ± 13.31%
# Class 1 Classification Accuracy: 46.25% ± 13.07%
# F1 Score (macro avg): 53.43% ± 7.61%
