# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import ot
import pandas as pd
import time
import random
from gwgraphs import *
from scipy.stats import ttest_ind

# %%
np.random.seed(42)
random.seed(42)

# %%
# Read and Process Graph Data #
def read_graph_data():
    # Read the adjacency matrix (edges)
    with open("COX2_A.txt", "r") as f:
        edges = [tuple(map(int, line.split(','))) for line in f]

    # Read graph indicators
    with open("COX2_graph_indicator.txt", "r") as f:
        graph_indicators = [int(line.strip()) for line in f if line.strip()]

    # Read graph labels
    with open("COX2_graph_labels.txt", "r") as f:
        graph_labels = [int(line.strip()) for line in f]

    # Read node labels
    with open("COX2_node_labels.txt", "r") as f:
        node_labels = [int(line.strip()) for line in f]

    # Read node attributes
    with open("COX2_node_attributes.txt", "r") as f:
        node_attributes = [
            list(map(float,
                     line.strip().split(','))) for line in f if line.strip()
        ]

    return edges, graph_indicators, graph_labels, node_labels, node_attributes


def normalize_features(features):
    features = np.array(features)
    # Normalize each feature dimension independently
    mean = np.mean(features, axis=0)
    std = np.std(features, axis=0)
    # Avoid division by zero
    std[std == 0] = 1
    normalized_features = (features - mean) / std
    return normalized_features.tolist()


def construct_networkx_graph(edges, graph_indicators, graph_labels,
                             node_labels, node_attributes):
    graphs = {}
    graphs_normalized = {}
    
    # Normalize all node attributes
    normalized_attributes = normalize_features(node_attributes)
    
    for node_id, graph_id in enumerate(graph_indicators, start=1):
        if graph_id not in graphs:
            graphs[graph_id] = nx.Graph(label=graph_labels[graph_id - 1])
            graphs_normalized[graph_id] = nx.Graph(label=graph_labels[graph_id - 1])

    for edge in edges:
        node1, node2 = edge
        graph_id = graph_indicators[
            node1 - 1]  # Determine which graph the edge belongs to
        graphs[graph_id].add_edge(node1, node2)
        graphs_normalized[graph_id].add_edge(node1, node2)

    for node_id, (graph_id, node_label,
                  node_attr, norm_attr) in enumerate(zip(graph_indicators, node_labels,
                                              node_attributes, normalized_attributes),
                                          start=1):
        # Original graphs with original features
        graphs[graph_id].nodes[node_id]['label'] = node_label
        graphs[graph_id].nodes[node_id]['attributes'] = node_attr
        
        # Normalized graphs with normalized features
        graphs_normalized[graph_id].nodes[node_id]['label'] = node_label
        graphs_normalized[graph_id].nodes[node_id]['attributes'] = norm_attr

    return graphs, graphs_normalized


def compute_distance_matrix(graph):
    num_nodes = len(graph.nodes)
    distance_matrix = np.full((num_nodes, num_nodes), 10000.0)

    # Get the correct node indices to be used for indexing the matrix
    node_list = list(graph.nodes())
    node_index = {node: i for i, node in enumerate(node_list)}

    for node in graph.nodes:
        lengths = nx.shortest_path_length(graph, source=node, weight="weight")

        for target, length in lengths.items():
            if target in node_index:
                distance_matrix[node_index[node], node_index[target]] = length

    return distance_matrix

# %%
edges, graph_indicators, graph_labels, node_labels, node_attributes = read_graph_data(
)
graphs, graphs_normalized = construct_networkx_graph(edges, graph_indicators, graph_labels,
                                                   node_labels, node_attributes)
for graph_id, graph in graphs.items():
    print(
        f"Graph ID: {graph_id}, number of nodes: {graph.number_of_nodes()}, label: {graph.graph['label']}"
    )
# Out:
# Graph ID: 1, number of nodes: 39, label: -1
# Graph ID: 2, number of nodes: 36, label: -1
# Graph ID: 3, number of nodes: 36, label: 1
# Graph ID: 4, number of nodes: 39, label: -1
# Graph ID: 5, number of nodes: 42, label: -1
# Graph ID: 6, number of nodes: 42, label: -1
# Graph ID: 7, number of nodes: 44, label: -1
# Graph ID: 8, number of nodes: 39, label: -1
# Graph ID: 9, number of nodes: 42, label: 1
# Graph ID: 10, number of nodes: 42, label: 1
# Graph ID: 11, number of nodes: 45, label: 1
# Graph ID: 12, number of nodes: 49, label: 1
# Graph ID: 13, number of nodes: 42, label: 1
# Graph ID: 14, number of nodes: 35, label: -1
# Graph ID: 15, number of nodes: 44, label: 1
# Graph ID: 16, number of nodes: 47, label: 1
# Graph ID: 17, number of nodes: 45, label: 1
# Graph ID: 18, number of nodes: 39, label: 1
# Graph ID: 19, number of nodes: 44, label: -1
# Graph ID: 20, number of nodes: 44, label: -1
# Graph ID: 21, number of nodes: 51, label: -1
# Graph ID: 22, number of nodes: 45, label: -1
# Graph ID: 23, number of nodes: 41, label: 1
# Graph ID: 24, number of nodes: 40, label: -1
# Graph ID: 25, number of nodes: 39, label: -1
# Graph ID: 26, number of nodes: 39, label: -1
# Graph ID: 27, number of nodes: 50, label: 1
# Graph ID: 28, number of nodes: 48, label: -1
# Graph ID: 29, number of nodes: 43, label: 1
# Graph ID: 30, number of nodes: 53, label: -1
# Graph ID: 31, number of nodes: 53, label: -1
# Graph ID: 32, number of nodes: 46, label: -1
# Graph ID: 33, number of nodes: 45, label: -1
# Graph ID: 34, number of nodes: 56, label: 1
# Graph ID: 35, number of nodes: 45, label: -1
# Graph ID: 36, number of nodes: 38, label: -1
# Graph ID: 37, number of nodes: 38, label: -1
# Graph ID: 38, number of nodes: 38, label: -1
# Graph ID: 39, number of nodes: 38, label: -1
# Graph ID: 40, number of nodes: 41, label: -1
# Graph ID: 41, number of nodes: 42, label: -1
# Graph ID: 42, number of nodes: 43, label: -1
# Graph ID: 43, number of nodes: 46, label: -1
# Graph ID: 44, number of nodes: 42, label: -1
# Graph ID: 45, number of nodes: 43, label: 1
# Graph ID: 46, number of nodes: 44, label: 1
# Graph ID: 47, number of nodes: 37, label: -1
# Graph ID: 48, number of nodes: 37, label: -1
# Graph ID: 49, number of nodes: 37, label: -1
# Graph ID: 50, number of nodes: 40, label: -1
# Graph ID: 51, number of nodes: 38, label: -1
# Graph ID: 52, number of nodes: 38, label: -1
# Graph ID: 53, number of nodes: 38, label: -1
# Graph ID: 54, number of nodes: 41, label: -1
# Graph ID: 55, number of nodes: 41, label: -1
# Graph ID: 56, number of nodes: 42, label: -1
# Graph ID: 57, number of nodes: 42, label: -1
# Graph ID: 58, number of nodes: 45, label: 1
# Graph ID: 59, number of nodes: 46, label: 1
# Graph ID: 60, number of nodes: 43, label: -1
# Graph ID: 61, number of nodes: 40, label: 1
# Graph ID: 62, number of nodes: 40, label: -1
# Graph ID: 63, number of nodes: 37, label: -1
# Graph ID: 254, number of nodes: 43, label: -1
# Graph ID: 255, number of nodes: 40, label: -1
# Graph ID: 256, number of nodes: 45, label: -1
# Graph ID: 257, number of nodes: 38, label: -1
# Graph ID: 258, number of nodes: 41, label: -1
# Graph ID: 259, number of nodes: 38, label: 1
# Graph ID: 260, number of nodes: 44, label: 1
# Graph ID: 261, number of nodes: 40, label: -1
# Graph ID: 262, number of nodes: 39, label: -1
# Graph ID: 263, number of nodes: 40, label: 1
# Graph ID: 264, number of nodes: 39, label: -1
# Graph ID: 265, number of nodes: 37, label: -1
# Graph ID: 266, number of nodes: 37, label: -1
# Graph ID: 267, number of nodes: 37, label: 1
# Graph ID: 268, number of nodes: 37, label: -1
# Graph ID: 269, number of nodes: 37, label: -1
# Graph ID: 270, number of nodes: 37, label: -1
# Graph ID: 271, number of nodes: 40, label: -1
# Graph ID: 272, number of nodes: 40, label: -1
# Graph ID: 273, number of nodes: 40, label: -1
# Graph ID: 274, number of nodes: 43, label: -1
# Graph ID: 275, number of nodes: 40, label: 1
# Graph ID: 276, number of nodes: 39, label: -1
# Graph ID: 277, number of nodes: 38, label: 1
# Graph ID: 278, number of nodes: 41, label: -1
# Graph ID: 279, number of nodes: 41, label: -1
# Graph ID: 280, number of nodes: 44, label: -1
# Graph ID: 281, number of nodes: 41, label: -1
# Graph ID: 282, number of nodes: 39, label: -1
# Graph ID: 283, number of nodes: 45, label: 1
# Graph ID: 284, number of nodes: 42, label: -1
# Graph ID: 285, number of nodes: 45, label: -1
# Graph ID: 286, number of nodes: 41, label: 1
# Graph ID: 287, number of nodes: 40, label: 1
# Graph ID: 288, number of nodes: 44, label: -1
# Graph ID: 289, number of nodes: 47, label: -1
# Graph ID: 290, number of nodes: 45, label: -1
# Graph ID: 291, number of nodes: 44, label: -1
# Graph ID: 292, number of nodes: 45, label: -1
# Graph ID: 293, number of nodes: 42, label: -1
# Graph ID: 294, number of nodes: 44, label: -1
# Graph ID: 295, number of nodes: 37, label: -1
# Graph ID: 296, number of nodes: 37, label: -1
# Graph ID: 297, number of nodes: 37, label: 1
# Graph ID: 298, number of nodes: 43, label: -1
# Graph ID: 299, number of nodes: 37, label: -1
# Graph ID: 300, number of nodes: 40, label: 1
# Graph ID: 301, number of nodes: 40, label: -1
# Graph ID: 302, number of nodes: 38, label: 1
# Graph ID: 303, number of nodes: 43, label: 1
# Graph ID: 304, number of nodes: 41, label: 1
# Graph ID: 305, number of nodes: 40, label: 1
# Graph ID: 306, number of nodes: 41, label: -1
# Graph ID: 307, number of nodes: 41, label: -1
# Graph ID: 308, number of nodes: 41, label: -1
# Graph ID: 309, number of nodes: 41, label: -1
# Graph ID: 310, number of nodes: 41, label: -1
# Graph ID: 311, number of nodes: 43, label: 1
# Graph ID: 312, number of nodes: 37, label: -1
# Graph ID: 313, number of nodes: 40, label: 1
# Graph ID: 314, number of nodes: 37, label: 1
# Graph ID: 315, number of nodes: 48, label: -1
# Graph ID: 316, number of nodes: 41, label: -1
# Graph ID: 444, number of nodes: 52, label: -1
# Graph ID: 445, number of nodes: 47, label: -1
# Graph ID: 446, number of nodes: 40, label: -1
# Graph ID: 447, number of nodes: 43, label: -1
# Graph ID: 448, number of nodes: 43, label: -1
# Graph ID: 449, number of nodes: 35, label: 1
# Graph ID: 450, number of nodes: 38, label: 1
# Graph ID: 451, number of nodes: 42, label: 1
# Graph ID: 452, number of nodes: 51, label: -1
# Graph ID: 453, number of nodes: 45, label: -1
# Graph ID: 454, number of nodes: 54, label: -1
# Graph ID: 455, number of nodes: 44, label: -1
# Graph ID: 456, number of nodes: 50, label: -1
# Graph ID: 457, number of nodes: 55, label: -1
# Graph ID: 458, number of nodes: 43, label: -1
# Graph ID: 459, number of nodes: 43, label: -1
# Graph ID: 460, number of nodes: 41, label: -1
# Graph ID: 461, number of nodes: 42, label: -1
# Graph ID: 462, number of nodes: 40, label: -1
# Graph ID: 463, number of nodes: 45, label: -1
# Graph ID: 464, number of nodes: 44, label: -1
# Graph ID: 465, number of nodes: 45, label: -1
# Graph ID: 466, number of nodes: 44, label: -1
# Graph ID: 467, number of nodes: 36, label: 1

# %%
graphs_list = []
labels_list = []
for graph_id, graph in graphs.items():
    # Add the graph object to the list
    graphs_list.append(graph)

    # Extract the label and add to the label list
    label = graph.graph['label']
    labels_list.append(label)

# Convert graphs into pairwise distance matrices
distance_matrices = [compute_distance_matrix(graph) for graph in graphs_list]

# %%
# GW Distances Scatterplots #
# Normalize the matrices
Ms = []
for matrix in distance_matrices:
    Ms.append(matrix / np.max(matrix))
    
N=467
heights = [
    np.full(len(graph), 1 / len(graph)) for graph in graphs_list
]
gw = np.zeros((N,N))

# Track negative values during computation
negative_count = 0
negative_pairs = []

for i in range(N):
    for j in range(i+1,N):
        tmp = ot.gromov.gromov_wasserstein2(Ms[i],Ms[j],heights[i],heights[j],loss_fun="square_loss",log=True)
        gw_value = tmp[0]
        gw[i,j] = gw_value
        
        # Check for negative values
        if gw_value < 0:
            negative_count += 1
            negative_pairs.append((i, j, gw_value))
            print(f"Negative GW distance found: graphs {i} and {j}, value: {gw_value}")
        
        # Check for NaN values
        if np.isnan(gw_value):
            print(f"NaN GW distance found: graphs {i} and {j}")
        
        #Ps_gw[i,j] = tmp[1]["T"]

# Handle negative values by taking absolute value before sqrt
gw_abs = np.abs(gw)
gw = np.sqrt(gw_abs)
gw += gw.T

print(f"\nGW computation summary:")
print(f"Total negative values found: {negative_count}")
print(f"Min GW value: {np.min(gw[gw != 0])}")
print(f"Max GW value: {np.max(gw)}")
print(f"Number of NaN values: {np.sum(np.isnan(gw))}")

# Print first few negative pairs if any
if negative_pairs:
    print(f"\nFirst 5 negative pairs:")
    for i, (idx_i, idx_j, val) in enumerate(negative_pairs[:5]):
        print(f"  Pair {i+1}: graphs {idx_i} and {idx_j}, value: {val}")
# Out:
# Negative GW distance found: graphs 18 and 19, value: -6.418476861114186e-17
# Negative GW distance found: graphs 46 and 347, value: -5.377642775528102e-17
### WHY NEGATIVE DISTANCES? ###
def check_graph_isomorphism(graph1, graph2):
    """Check if two graphs are isomorphic, considering both structure and node labels."""
    # First check structural isomorphism
    if not nx.is_isomorphic(graph1, graph2):
        return False, "Not structurally isomorphic"
    
    # If structurally isomorphic, check if node labels match
    def node_match(n1, n2):
        return n1.get('label', None) == n2.get('label', None)
    
    if nx.is_isomorphic(graph1, graph2, node_match=node_match):
        return True, "Isomorphic with matching node labels"
    else:
        return True, "Structurally isomorphic but different node labels"

print(f"\n=== ISOMORPHISM ANALYSIS FOR NEGATIVE GW PAIRS ===")
if negative_pairs:
    print(f"Analyzing {len(negative_pairs)} pairs with negative GW distances...\n")
    
    isomorphic_count = 0
    structural_iso_count = 0
    same_label_count = 0
    different_label_count = 0
    
    for idx, (i, j, gw_value) in enumerate(negative_pairs):
        graph1 = graphs_list[i]
        graph2 = graphs_list[j]
        
        is_iso, iso_type = check_graph_isomorphism(graph1, graph2)
        
        # Check if classification labels are the same
        label1 = labels_list[i]
        label2 = labels_list[j]
        same_label = label1 == label2
        
        if same_label:
            same_label_count += 1
            label_status = "Same classification label"
        else:
            different_label_count += 1
            label_status = "Different classification labels"
        
        print(f"Pair {idx+1}: Graphs {i} and {j} (GW distance: {gw_value})")
        print(f"  Nodes: {graph1.number_of_nodes()} vs {graph2.number_of_nodes()}")
        print(f"  Edges: {graph1.number_of_edges()} vs {graph2.number_of_edges()}")
        print(f"  Graph labels: {graph1.graph['label']} vs {graph2.graph['label']}")
        print(f"  Classification labels: {label1} vs {label2} ({label_status})")
        print(f"  Isomorphism: {iso_type}")
        
        if "Isomorphic with matching" in iso_type:
            isomorphic_count += 1
        elif "Structurally isomorphic" in iso_type:
            structural_iso_count += 1
        
        print()
    
    print(f"SUMMARY:")
    print(f"  Total negative pairs: {len(negative_pairs)}")
    print(f"  Pairs with same classification label: {same_label_count}")
    print(f"  Pairs with different classification labels: {different_label_count}")
    print(f"  Fully isomorphic (structure + labels): {isomorphic_count}")
    print(f"  Structurally isomorphic only: {structural_iso_count}")
    print(f"  Not isomorphic: {len(negative_pairs) - isomorphic_count - structural_iso_count}")
else:
    print("No negative GW distances found.")
# Out:
# === ISOMORPHISM ANALYSIS FOR NEGATIVE GW PAIRS ===
# Analyzing 128 pairs with negative GW distances...
#
# Pair 1: Graphs 18 and 19 (GW distance: -6.418476861114186e-17)
#   Nodes: 44 vs 44
#   Edges: 46 vs 46
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 2: Graphs 46 and 347 (GW distance: -5.377642775528102e-17)
#   Nodes: 37 vs 37
#   Edges: 39 vs 39
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 3: Graphs 47 and 347 (GW distance: -5.377642775528102e-17)
#   Nodes: 37 vs 37
#   Edges: 39 vs 39
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 4: Graphs 48 and 347 (GW distance: -5.377642775528102e-17)
#   Nodes: 37 vs 37
#   Edges: 39 vs 39
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 5: Graphs 53 and 54 (GW distance: -1.491862189340054e-16)
#   Nodes: 41 vs 41
#   Edges: 43 vs 43
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 6: Graphs 53 and 80 (GW distance: -1.491862189340054e-16)
#   Nodes: 41 vs 41
#   Edges: 43 vs 43
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 7: Graphs 53 and 81 (GW distance: -1.491862189340054e-16)
#   Nodes: 41 vs 41
#   Edges: 43 vs 43
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 8: Graphs 53 and 87 (GW distance: -1.491862189340054e-16)
#   Nodes: 41 vs 41
#   Edges: 43 vs 43
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 9: Graphs 53 and 88 (GW distance: -1.491862189340054e-16)
#   Nodes: 41 vs 41
#   Edges: 43 vs 43
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 10: Graphs 53 and 90 (GW distance: -1.491862189340054e-16)
#   Nodes: 41 vs 41
#   Edges: 43 vs 43
#   Graph labels: -1 vs 1
#   Classification labels: -1 vs 1 (Different classification labels)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 11: Graphs 54 and 80 (GW distance: -1.491862189340054e-16)
#   Nodes: 41 vs 41
#   Edges: 43 vs 43
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 12: Graphs 54 and 81 (GW distance: -1.491862189340054e-16)
#   Nodes: 41 vs 41
#   Edges: 43 vs 43
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 13: Graphs 54 and 87 (GW distance: -1.491862189340054e-16)
#   Nodes: 41 vs 41
#   Edges: 43 vs 43
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 14: Graphs 54 and 88 (GW distance: -1.491862189340054e-16)
#   Nodes: 41 vs 41
#   Edges: 43 vs 43
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 15: Graphs 54 and 90 (GW distance: -1.491862189340054e-16)
#   Nodes: 41 vs 41
#   Edges: 43 vs 43
#   Graph labels: -1 vs 1
#   Classification labels: -1 vs 1 (Different classification labels)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 16: Graphs 62 and 347 (GW distance: -5.377642775528102e-17)
#   Nodes: 37 vs 37
#   Edges: 39 vs 39
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# Pair 128: Graphs 462 and 464 (GW distance: -1.0950441942103595e-17)
#   Nodes: 45 vs 45
#   Edges: 48 vs 48
#   Graph labels: -1 vs -1
#   Classification labels: -1 vs -1 (Same classification label)
#   Isomorphism: Structurally isomorphic but different node labels
#
# SUMMARY:
#   Total negative pairs: 128
#   Pairs with same classification label: 97
#   Pairs with different classification labels: 31
#   Fully isomorphic (structure + labels): 0
#   Structurally isomorphic only: 128
#   Not isomorphic: 0

# %%
### Compare all graphs in dataset to determine which are isomorphic ###
# Check for isomorphic graphs
isomorphic_pairs = []
same_label_count = 0
neg_one_pairs = 0
pos_one_pairs = 0

for i in range(N):
    for j in range(i + 1, N):
        if check_graph_isomorphism(graphs_list[i], graphs_list[j])[0]:
            isomorphic_pairs.append((i, j))
            print(f"Graphs {i} and {j} are isomorphic.")
            print(
                f"  Graph {i} has {graphs_list[i].number_of_nodes()} nodes and {graphs_list[i].number_of_edges()} edges."
            )
            print(
                f"  Graph {j} has {graphs_list[j].number_of_nodes()} nodes and {graphs_list[j].number_of_edges()} edges."
            )
            print(
                f"  Classification labels: {labels_list[i]} vs {labels_list[j]}"
            )
            tmp = ot.gromov.gromov_wasserstein2(Ms[i],Ms[j],heights[i],heights[j],loss_fun="square_loss",log=True)
            print(f"  GW Distance between Graph {i} and Graph {j}: {np.sqrt(np.abs(tmp[0]))}")
            if labels_list[i] == labels_list[j]:
                same_label_count += 1
                print("Same classification label.")
            if labels_list[i] == 1 and labels_list[j] == 1:
                pos_one_pairs += 1
                print("Both graphs have label 1.")
            if labels_list[i] == -1 and labels_list[j] == -1:
                neg_one_pairs += 1
                print("Both graphs have label -1.")
            print()

print(f"Total number of graph pairs: {N * (N - 1) / 2}")
print(f"Total isomorphic pairs found: {len(isomorphic_pairs)}")
print(f"Pairs with same classification label: {same_label_count}")
print(f"Pairs with both graphs having label 1: {pos_one_pairs}")
print(f"Pairs with both graphs having label -1: {neg_one_pairs}")
# Out:
# Graphs 0 and 3 are isomorphic.
#   Graph 0 has 39 nodes and 41 edges.
#   Graph 3 has 39 nodes and 41 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 0 and Graph 3: 0.019325362862192042
# Same classification label.
# Both graphs have label -1.
#
# Graphs 0 and 7 are isomorphic.
#   Graph 0 has 39 nodes and 41 edges.
#   Graph 7 has 39 nodes and 41 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 0 and Graph 7: 0.019325362862192042
# Same classification label.
# Both graphs have label -1.
#
# Graphs 0 and 17 are isomorphic.
#   Graph 0 has 39 nodes and 41 edges.
#   Graph 17 has 39 nodes and 41 edges.
#   Classification labels: -1 vs 1
#   GW Distance between Graph 0 and Graph 17: 0.022315006901348463
#
# Graphs 0 and 24 are isomorphic.
#   Graph 0 has 39 nodes and 41 edges.
#   Graph 24 has 39 nodes and 41 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 0 and Graph 24: 0.022315006901348463
# Same classification label.
# Both graphs have label -1.
#
# Graphs 0 and 25 are isomorphic.
#   Graph 0 has 39 nodes and 41 edges.
#   Graph 25 has 39 nodes and 41 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 0 and Graph 25: 0.022315006901348463
# Same classification label.
# Both graphs have label -1.
#
# Graphs 1 and 2 are isomorphic.
#   Graph 1 has 36 nodes and 38 edges.
#   Graph 2 has 36 nodes and 38 edges.
#   Classification labels: -1 vs 1
#   GW Distance between Graph 1 and Graph 2: 2.9451005721170265e-09
#
# Graphs 3 and 7 are isomorphic.
#   Graph 3 has 39 nodes and 41 edges.
#   Graph 7 has 39 nodes and 41 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 3 and Graph 7: 0.019325362862192264
# Same classification label.
# Both graphs have label -1.
#
# Graphs 3 and 17 are isomorphic.
#   Graph 3 has 39 nodes and 41 edges.
#   Graph 17 has 39 nodes and 41 edges.
#   Classification labels: -1 vs 1
#   GW Distance between Graph 3 and Graph 17: 0.019325362862192313
#
# Graphs 3 and 24 are isomorphic.
#   Graph 3 has 39 nodes and 41 edges.
#   Graph 24 has 39 nodes and 41 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 3 and Graph 24: 0.019325362862192313
# Same classification label.
# Both graphs have label -1.
#
# Graphs 3 and 25 are isomorphic.
#   Graph 3 has 39 nodes and 41 edges.
#   Graph 25 has 39 nodes and 41 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 3 and Graph 25: 0.019325362862192313
# Same classification label.
# Both graphs have label -1.
#
# Graphs 4 and 5 are isomorphic.
#   Graph 4 has 42 nodes and 44 edges.
#   Graph 5 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 4 and Graph 5: 0.016663195529133878
# Same classification label.
# Both graphs have label -1.
#
# Graphs 7 and 17 are isomorphic.
#   Graph 7 has 39 nodes and 41 edges.
#   Graph 17 has 39 nodes and 41 edges.
#   Classification labels: -1 vs 1
#   GW Distance between Graph 7 and Graph 17: 0.019325362862192313
#
# Graphs 7 and 24 are isomorphic.
#   Graph 7 has 39 nodes and 41 edges.
#   Graph 24 has 39 nodes and 41 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 7 and Graph 24: 0.019325362862192313
# Same classification label.
# Both graphs have label -1.
#
# Graphs 7 and 25 are isomorphic.
#   Graph 7 has 39 nodes and 41 edges.
#   Graph 25 has 39 nodes and 41 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 7 and Graph 25: 0.019325362862192313
# Same classification label.
# Both graphs have label -1.
#
# Graphs 17 and 24 are isomorphic.
#   Graph 17 has 39 nodes and 41 edges.
#   Graph 24 has 39 nodes and 41 edges.
#   Classification labels: 1 vs -1
#   GW Distance between Graph 17 and Graph 24: 0.0193253628621924
#
# Graphs 17 and 25 are isomorphic.
#   Graph 17 has 39 nodes and 41 edges.
#   Graph 25 has 39 nodes and 41 edges.
#   Classification labels: 1 vs -1
#   GW Distance between Graph 17 and Graph 25: 0.0193253628621924
#
# Graphs 18 and 19 are isomorphic.
#   Graph 18 has 44 nodes and 46 edges.
#   Graph 19 has 44 nodes and 46 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 18 and Graph 19: 8.011539715381923e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 21 and 32 are isomorphic.
#   Graph 21 has 45 nodes and 47 edges.
#   Graph 32 has 45 nodes and 47 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 21 and Graph 32: 9.041506722079403e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 24 and 25 are isomorphic.
#   Graph 24 has 39 nodes and 41 edges.
#   Graph 25 has 39 nodes and 41 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 24 and Graph 25: 0.0193253628621924
# Same classification label.
# Both graphs have label -1.
#
# Graphs 29 and 30 are isomorphic.
#   Graph 29 has 53 nodes and 56 edges.
#   Graph 30 has 53 nodes and 56 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 29 and Graph 30: 0.016340101958194075
# Same classification label.
# Both graphs have label -1.
#
# Graphs 35 and 36 are isomorphic.
#   Graph 35 has 38 nodes and 40 edges.
#   Graph 36 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 35 and Graph 36: 0.022902243925070273
# Same classification label.
# Both graphs have label -1.
#
# Graphs 35 and 37 are isomorphic.
#   Graph 35 has 38 nodes and 40 edges.
#   Graph 37 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 35 and Graph 37: 0.022902243925070273
# Same classification label.
# Both graphs have label -1.
#
# Graphs 35 and 38 are isomorphic.
#   Graph 35 has 38 nodes and 40 edges.
#   Graph 38 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 35 and Graph 38: 0.022902243925070273
# Same classification label.
# Both graphs have label -1.
#
# Graphs 35 and 50 are isomorphic.
#   Graph 35 has 38 nodes and 40 edges.
#   Graph 50 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 35 and Graph 50: 0.022902243925070273
# Same classification label.
# Both graphs have label -1.
#
# Graphs 35 and 51 are isomorphic.
#   Graph 35 has 38 nodes and 40 edges.
#   Graph 51 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 35 and Graph 51: 0.022902243925070273
# Same classification label.
# Both graphs have label -1.
#
# Graphs 35 and 52 are isomorphic.
#   Graph 35 has 38 nodes and 40 edges.
#   Graph 52 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 35 and Graph 52: 0.022902243925070273
# Same classification label.
# Both graphs have label -1.
#
# Graphs 35 and 66 are isomorphic.
#   Graph 35 has 38 nodes and 40 edges.
#   Graph 66 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 35 and Graph 66: 0.022902243925070273
# Same classification label.
# Both graphs have label -1.
#
# Graphs 35 and 67 are isomorphic.
#   Graph 35 has 38 nodes and 40 edges.
#   Graph 67 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 35 and Graph 67: 0.022902243925070273
# Same classification label.
# Both graphs have label -1.
#
# Graphs 35 and 85 are isomorphic.
#   Graph 35 has 38 nodes and 40 edges.
#   Graph 85 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 35 and Graph 85: 0.022902243925070273
# Same classification label.
# Both graphs have label -1.
#
# Graphs 35 and 91 are isomorphic.
#   Graph 35 has 38 nodes and 40 edges.
#   Graph 91 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 35 and Graph 91: 0.022902243925070273
# Same classification label.
# Both graphs have label -1.
#
# Graphs 35 and 112 are isomorphic.
#   Graph 35 has 38 nodes and 40 edges.
#   Graph 112 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 35 and Graph 112: 0.01983392504277875
# Same classification label.
# Both graphs have label -1.
#
# Graphs 35 and 113 are isomorphic.
#   Graph 35 has 38 nodes and 40 edges.
#   Graph 113 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 35 and Graph 113: 0.01983392504277875
# Same classification label.
# Both graphs have label -1.
#
# Graphs 36 and 37 are isomorphic.
#   Graph 36 has 38 nodes and 40 edges.
#   Graph 37 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 36 and Graph 37: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 36 and 38 are isomorphic.
#   Graph 36 has 38 nodes and 40 edges.
#   Graph 38 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 36 and Graph 38: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 36 and 50 are isomorphic.
#   Graph 36 has 38 nodes and 40 edges.
#   Graph 50 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 36 and Graph 50: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 36 and 51 are isomorphic.
#   Graph 36 has 38 nodes and 40 edges.
#   Graph 51 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 36 and Graph 51: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 36 and 52 are isomorphic.
#   Graph 36 has 38 nodes and 40 edges.
#   Graph 52 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 36 and Graph 52: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 36 and 66 are isomorphic.
#   Graph 36 has 38 nodes and 40 edges.
#   Graph 66 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 36 and Graph 66: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 36 and 67 are isomorphic.
#   Graph 36 has 38 nodes and 40 edges.
#   Graph 67 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 36 and Graph 67: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 36 and 85 are isomorphic.
#   Graph 36 has 38 nodes and 40 edges.
#   Graph 85 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 36 and Graph 85: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 36 and 91 are isomorphic.
#   Graph 36 has 38 nodes and 40 edges.
#   Graph 91 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 36 and Graph 91: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 36 and 112 are isomorphic.
#   Graph 36 has 38 nodes and 40 edges.
#   Graph 112 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 36 and Graph 112: 0.019833925042778863
# Same classification label.
# Both graphs have label -1.
#
# Graphs 36 and 113 are isomorphic.
#   Graph 36 has 38 nodes and 40 edges.
#   Graph 113 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 36 and Graph 113: 0.019833925042778863
# Same classification label.
# Both graphs have label -1.
#
# Graphs 37 and 38 are isomorphic.
#   Graph 37 has 38 nodes and 40 edges.
#   Graph 38 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 37 and Graph 38: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 37 and 50 are isomorphic.
#   Graph 37 has 38 nodes and 40 edges.
#   Graph 50 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 37 and Graph 50: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 37 and 51 are isomorphic.
#   Graph 37 has 38 nodes and 40 edges.
#   Graph 51 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 37 and Graph 51: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 37 and 52 are isomorphic.
#   Graph 37 has 38 nodes and 40 edges.
#   Graph 52 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 37 and Graph 52: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 37 and 66 are isomorphic.
#   Graph 37 has 38 nodes and 40 edges.
#   Graph 66 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 37 and Graph 66: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 37 and 67 are isomorphic.
#   Graph 37 has 38 nodes and 40 edges.
#   Graph 67 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 37 and Graph 67: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 37 and 85 are isomorphic.
#   Graph 37 has 38 nodes and 40 edges.
#   Graph 85 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 37 and Graph 85: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 37 and 91 are isomorphic.
#   Graph 37 has 38 nodes and 40 edges.
#   Graph 91 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 37 and Graph 91: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 37 and 112 are isomorphic.
#   Graph 37 has 38 nodes and 40 edges.
#   Graph 112 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 37 and Graph 112: 0.019833925042778863
# Same classification label.
# Both graphs have label -1.
#
# Graphs 37 and 113 are isomorphic.
#   Graph 37 has 38 nodes and 40 edges.
#   Graph 113 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 37 and Graph 113: 0.019833925042778863
# Same classification label.
# Both graphs have label -1.
#
# Graphs 38 and 50 are isomorphic.
#   Graph 38 has 38 nodes and 40 edges.
#   Graph 50 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 38 and Graph 50: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 38 and 51 are isomorphic.
#   Graph 38 has 38 nodes and 40 edges.
#   Graph 51 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 38 and Graph 51: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 38 and 52 are isomorphic.
#   Graph 38 has 38 nodes and 40 edges.
#   Graph 52 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 38 and Graph 52: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 38 and 66 are isomorphic.
#   Graph 38 has 38 nodes and 40 edges.
#   Graph 66 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 38 and Graph 66: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 38 and 67 are isomorphic.
#   Graph 38 has 38 nodes and 40 edges.
#   Graph 67 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 38 and Graph 67: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 38 and 85 are isomorphic.
#   Graph 38 has 38 nodes and 40 edges.
#   Graph 85 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 38 and Graph 85: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 38 and 91 are isomorphic.
#   Graph 38 has 38 nodes and 40 edges.
#   Graph 91 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 38 and Graph 91: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 38 and 112 are isomorphic.
#   Graph 38 has 38 nodes and 40 edges.
#   Graph 112 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 38 and Graph 112: 0.019833925042778863
# Same classification label.
# Both graphs have label -1.
#
# Graphs 38 and 113 are isomorphic.
#   Graph 38 has 38 nodes and 40 edges.
#   Graph 113 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 38 and Graph 113: 0.019833925042778863
# Same classification label.
# Both graphs have label -1.
#
# Graphs 39 and 78 are isomorphic.
#   Graph 39 has 41 nodes and 43 edges.
#   Graph 78 has 41 nodes and 43 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 39 and Graph 78: 0.024140080941726285
# Same classification label.
# Both graphs have label -1.
#
# Graphs 39 and 79 are isomorphic.
#   Graph 39 has 41 nodes and 43 edges.
#   Graph 79 has 41 nodes and 43 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 39 and Graph 79: 0.024140080941726285
# Same classification label.
# Both graphs have label -1.
#
# Graphs 40 and 43 are isomorphic.
#   Graph 40 has 42 nodes and 44 edges.
#   Graph 43 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 40 and Graph 43: 0.015552315827195714
# Same classification label.
# Both graphs have label -1.
#
# Graphs 40 and 72 are isomorphic.
#   Graph 40 has 42 nodes and 44 edges.
#   Graph 72 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 40 and Graph 72: 0.015552315827195714
# Same classification label.
# Both graphs have label -1.
#
# Graphs 40 and 73 are isomorphic.
#   Graph 40 has 42 nodes and 44 edges.
#   Graph 73 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 40 and Graph 73: 0.015552315827195714
# Same classification label.
# Both graphs have label -1.
#
# Graphs 40 and 74 are isomorphic.
#   Graph 40 has 42 nodes and 44 edges.
#   Graph 74 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 40 and Graph 74: 0.015552315827195714
# Same classification label.
# Both graphs have label -1.
#
# Graphs 40 and 104 are isomorphic.
#   Graph 40 has 42 nodes and 44 edges.
#   Graph 104 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 40 and Graph 104: 0.015552315827195714
# Same classification label.
# Both graphs have label -1.
#
# Graphs 40 and 105 are isomorphic.
#   Graph 40 has 42 nodes and 44 edges.
#   Graph 105 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 40 and Graph 105: 0.015552315827195714
# Same classification label.
# Both graphs have label -1.
#
# Graphs 40 and 106 are isomorphic.
#   Graph 40 has 42 nodes and 44 edges.
#   Graph 106 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 40 and Graph 106: 0.015552315827195714
# Same classification label.
# Both graphs have label -1.
#
# Graphs 41 and 44 are isomorphic.
#   Graph 41 has 43 nodes and 45 edges.
#   Graph 44 has 43 nodes and 45 edges.
#   Classification labels: -1 vs 1
#   GW Distance between Graph 41 and Graph 44: 0.021482800714032187
#
# Graphs 41 and 77 are isomorphic.
#   Graph 41 has 43 nodes and 45 edges.
#   Graph 77 has 43 nodes and 45 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 41 and Graph 77: 2.08250058582033e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 42 and 75 are isomorphic.
#   Graph 42 has 46 nodes and 48 edges.
#   Graph 75 has 46 nodes and 48 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 42 and Graph 75: 0.02008174849355361
# Same classification label.
# Both graphs have label -1.
#
# Graphs 42 and 76 are isomorphic.
#   Graph 42 has 46 nodes and 48 edges.
#   Graph 76 has 46 nodes and 48 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 42 and Graph 76: 0.02008174849355361
# Same classification label.
# Both graphs have label -1.
#
# Graphs 42 and 109 are isomorphic.
#   Graph 42 has 46 nodes and 48 edges.
#   Graph 109 has 46 nodes and 48 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 42 and Graph 109: 0.02008174849355361
# Same classification label.
# Both graphs have label -1.
#
# Graphs 43 and 72 are isomorphic.
#   Graph 43 has 42 nodes and 44 edges.
#   Graph 72 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 43 and Graph 72: 0.015552315827195714
# Same classification label.
# Both graphs have label -1.
#
# Graphs 43 and 73 are isomorphic.
#   Graph 43 has 42 nodes and 44 edges.
#   Graph 73 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 43 and Graph 73: 0.015552315827195714
# Same classification label.
# Both graphs have label -1.
#
# Graphs 43 and 74 are isomorphic.
#   Graph 43 has 42 nodes and 44 edges.
#   Graph 74 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 43 and Graph 74: 0.015552315827195714
# Same classification label.
# Both graphs have label -1.
#
# Graphs 43 and 104 are isomorphic.
#   Graph 43 has 42 nodes and 44 edges.
#   Graph 104 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 43 and Graph 104: 0.015552315827195714
# Same classification label.
# Both graphs have label -1.
#
# Graphs 43 and 105 are isomorphic.
#   Graph 43 has 42 nodes and 44 edges.
#   Graph 105 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 43 and Graph 105: 0.015552315827195714
# Same classification label.
# Both graphs have label -1.
#
# Graphs 43 and 106 are isomorphic.
#   Graph 43 has 42 nodes and 44 edges.
#   Graph 106 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 43 and Graph 106: 0.015552315827195714
# Same classification label.
# Both graphs have label -1.
#
# Graphs 44 and 77 are isomorphic.
#   Graph 44 has 43 nodes and 45 edges.
#   Graph 77 has 43 nodes and 45 edges.
#   Classification labels: 1 vs -1
#   GW Distance between Graph 44 and Graph 77: 0.01754063333175833
#
# Graphs 46 and 47 are isomorphic.
#   Graph 46 has 37 nodes and 39 edges.
#   Graph 47 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 46 and Graph 47: 0.031115653944065225
# Same classification label.
# Both graphs have label -1.
#
# Graphs 46 and 48 are isomorphic.
#   Graph 46 has 37 nodes and 39 edges.
#   Graph 48 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 46 and Graph 48: 0.031115653944065225
# Same classification label.
# Both graphs have label -1.
#
# Graphs 46 and 62 are isomorphic.
#   Graph 46 has 37 nodes and 39 edges.
#   Graph 62 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 46 and Graph 62: 0.031115653944065225
# Same classification label.
# Both graphs have label -1.
#
# Graphs 46 and 63 are isomorphic.
#   Graph 46 has 37 nodes and 39 edges.
#   Graph 63 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 46 and Graph 63: 0.031115653944065225
# Same classification label.
# Both graphs have label -1.
#
# Graphs 46 and 64 are isomorphic.
#   Graph 46 has 37 nodes and 39 edges.
#   Graph 64 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 46 and Graph 64: 0.031115653944065225
# Same classification label.
# Both graphs have label -1.
#
# Graphs 46 and 70 are isomorphic.
#   Graph 46 has 37 nodes and 39 edges.
#   Graph 70 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 46 and Graph 70: 0.031115653944065225
# Same classification label.
# Both graphs have label -1.
#
# Graphs 46 and 100 are isomorphic.
#   Graph 46 has 37 nodes and 39 edges.
#   Graph 100 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 46 and Graph 100: 0.031115653944065225
# Same classification label.
# Both graphs have label -1.
#
# Graphs 46 and 347 are isomorphic.
#   Graph 46 has 37 nodes and 39 edges.
#   Graph 347 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 46 and Graph 347: 7.33324128576723e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 47 and 48 are isomorphic.
#   Graph 47 has 37 nodes and 39 edges.
#   Graph 48 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 47 and Graph 48: 0.031115653944065225
# Same classification label.
# Both graphs have label -1.
#
# Graphs 47 and 62 are isomorphic.
#   Graph 47 has 37 nodes and 39 edges.
#   Graph 62 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 47 and Graph 62: 0.031115653944065225
# Same classification label.
# Both graphs have label -1.
#
# Graphs 47 and 63 are isomorphic.
#   Graph 47 has 37 nodes and 39 edges.
#   Graph 63 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 47 and Graph 63: 0.031115653944065225
# Same classification label.
# Both graphs have label -1.
#
# Graphs 47 and 64 are isomorphic.
#   Graph 47 has 37 nodes and 39 edges.
#   Graph 64 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 47 and Graph 64: 0.031115653944065225
# Same classification label.
# Both graphs have label -1.
#
# Graphs 47 and 70 are isomorphic.
#   Graph 47 has 37 nodes and 39 edges.
#   Graph 70 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 47 and Graph 70: 0.031115653944065225
# Same classification label.
# Both graphs have label -1.
#
# Graphs 47 and 100 are isomorphic.
#   Graph 47 has 37 nodes and 39 edges.
#   Graph 100 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 47 and Graph 100: 0.031115653944065225
# Same classification label.
# Both graphs have label -1.
#
# Graphs 47 and 347 are isomorphic.
#   Graph 47 has 37 nodes and 39 edges.
#   Graph 347 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 47 and Graph 347: 7.33324128576723e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 48 and 62 are isomorphic.
#   Graph 48 has 37 nodes and 39 edges.
#   Graph 62 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 48 and Graph 62: 0.031115653944065225
# Same classification label.
# Both graphs have label -1.
#
# Graphs 48 and 63 are isomorphic.
#   Graph 48 has 37 nodes and 39 edges.
#   Graph 63 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 48 and Graph 63: 0.031115653944065225
# Same classification label.
# Both graphs have label -1.
#
# Graphs 48 and 64 are isomorphic.
#   Graph 48 has 37 nodes and 39 edges.
#   Graph 64 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 48 and Graph 64: 0.031115653944065225
# Same classification label.
# Both graphs have label -1.
#
# Graphs 48 and 70 are isomorphic.
#   Graph 48 has 37 nodes and 39 edges.
#   Graph 70 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 48 and Graph 70: 0.031115653944065225
# Same classification label.
# Both graphs have label -1.
#
# Graphs 48 and 100 are isomorphic.
#   Graph 48 has 37 nodes and 39 edges.
#   Graph 100 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 48 and Graph 100: 0.031115653944065225
# Same classification label.
# Both graphs have label -1.
#
# Graphs 48 and 347 are isomorphic.
#   Graph 48 has 37 nodes and 39 edges.
#   Graph 347 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 48 and Graph 347: 7.33324128576723e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 49 and 98 are isomorphic.
#   Graph 49 has 40 nodes and 42 edges.
#   Graph 98 has 40 nodes and 42 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 49 and Graph 98: 0.017496355305595828
# Same classification label.
# Both graphs have label -1.
#
# Graphs 50 and 51 are isomorphic.
#   Graph 50 has 38 nodes and 40 edges.
#   Graph 51 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 50 and Graph 51: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 50 and 52 are isomorphic.
#   Graph 50 has 38 nodes and 40 edges.
#   Graph 52 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 50 and Graph 52: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 50 and 66 are isomorphic.
#   Graph 50 has 38 nodes and 40 edges.
#   Graph 66 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 50 and Graph 66: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 50 and 67 are isomorphic.
#   Graph 50 has 38 nodes and 40 edges.
#   Graph 67 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 50 and Graph 67: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 50 and 85 are isomorphic.
#   Graph 50 has 38 nodes and 40 edges.
#   Graph 85 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 50 and Graph 85: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 50 and 91 are isomorphic.
#   Graph 50 has 38 nodes and 40 edges.
#   Graph 91 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 50 and Graph 91: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 50 and 112 are isomorphic.
#   Graph 50 has 38 nodes and 40 edges.
#   Graph 112 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 50 and Graph 112: 0.019833925042778863
# Same classification label.
# Both graphs have label -1.
#
# Graphs 50 and 113 are isomorphic.
#   Graph 50 has 38 nodes and 40 edges.
#   Graph 113 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 50 and Graph 113: 0.019833925042778863
# Same classification label.
# Both graphs have label -1.
#
# Graphs 51 and 52 are isomorphic.
#   Graph 51 has 38 nodes and 40 edges.
#   Graph 52 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 51 and Graph 52: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 51 and 66 are isomorphic.
#   Graph 51 has 38 nodes and 40 edges.
#   Graph 66 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 51 and Graph 66: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 51 and 67 are isomorphic.
#   Graph 51 has 38 nodes and 40 edges.
#   Graph 67 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 51 and Graph 67: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 51 and 85 are isomorphic.
#   Graph 51 has 38 nodes and 40 edges.
#   Graph 85 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 51 and Graph 85: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 51 and 91 are isomorphic.
#   Graph 51 has 38 nodes and 40 edges.
#   Graph 91 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 51 and Graph 91: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 51 and 112 are isomorphic.
#   Graph 51 has 38 nodes and 40 edges.
#   Graph 112 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 51 and Graph 112: 0.019833925042778863
# Same classification label.
# Both graphs have label -1.
#
# Graphs 51 and 113 are isomorphic.
#   Graph 51 has 38 nodes and 40 edges.
#   Graph 113 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 51 and Graph 113: 0.019833925042778863
# Same classification label.
# Both graphs have label -1.
#
# Graphs 52 and 66 are isomorphic.
#   Graph 52 has 38 nodes and 40 edges.
#   Graph 66 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 52 and Graph 66: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 52 and 67 are isomorphic.
#   Graph 52 has 38 nodes and 40 edges.
#   Graph 67 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 52 and Graph 67: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 52 and 85 are isomorphic.
#   Graph 52 has 38 nodes and 40 edges.
#   Graph 85 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 52 and Graph 85: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 52 and 91 are isomorphic.
#   Graph 52 has 38 nodes and 40 edges.
#   Graph 91 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 52 and Graph 91: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 52 and 112 are isomorphic.
#   Graph 52 has 38 nodes and 40 edges.
#   Graph 112 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 52 and Graph 112: 0.019833925042778863
# Same classification label.
# Both graphs have label -1.
#
# Graphs 52 and 113 are isomorphic.
#   Graph 52 has 38 nodes and 40 edges.
#   Graph 113 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 52 and Graph 113: 0.019833925042778863
# Same classification label.
# Both graphs have label -1.
#
# Graphs 53 and 54 are isomorphic.
#   Graph 53 has 41 nodes and 43 edges.
#   Graph 54 has 41 nodes and 43 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 53 and Graph 54: 1.2214181058671326e-08
# Same classification label.
# Both graphs have label -1.
#
# Graphs 53 and 80 are isomorphic.
#   Graph 53 has 41 nodes and 43 edges.
#   Graph 80 has 41 nodes and 43 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 53 and Graph 80: 1.2214181058671326e-08
# Same classification label.
# Both graphs have label -1.
#
# Graphs 53 and 81 are isomorphic.
#   Graph 53 has 41 nodes and 43 edges.
#   Graph 81 has 41 nodes and 43 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 53 and Graph 81: 1.2214181058671326e-08
# Same classification label.
# Both graphs have label -1.
#
# Graphs 53 and 87 are isomorphic.
#   Graph 53 has 41 nodes and 43 edges.
#   Graph 87 has 41 nodes and 43 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 53 and Graph 87: 1.2214181058671326e-08
# Same classification label.
# Both graphs have label -1.
#
# Graphs 53 and 88 are isomorphic.
#   Graph 53 has 41 nodes and 43 edges.
#   Graph 88 has 41 nodes and 43 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 53 and Graph 88: 1.2214181058671326e-08
# Same classification label.
# Both graphs have label -1.
#
# Graphs 53 and 90 are isomorphic.
#   Graph 53 has 41 nodes and 43 edges.
#   Graph 90 has 41 nodes and 43 edges.
#   Classification labels: -1 vs 1
#   GW Distance between Graph 53 and Graph 90: 1.2214181058671326e-08
#
# Graphs 54 and 80 are isomorphic.
#   Graph 54 has 41 nodes and 43 edges.
#   Graph 80 has 41 nodes and 43 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 54 and Graph 80: 1.2214181058671326e-08
# Same classification label.
# Both graphs have label -1.
#
# Graphs 54 and 81 are isomorphic.
#   Graph 54 has 41 nodes and 43 edges.
#   Graph 81 has 41 nodes and 43 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 54 and Graph 81: 1.2214181058671326e-08
# Same classification label.
# Both graphs have label -1.
#
# Graphs 54 and 87 are isomorphic.
#   Graph 54 has 41 nodes and 43 edges.
#   Graph 87 has 41 nodes and 43 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 54 and Graph 87: 1.2214181058671326e-08
# Same classification label.
# Both graphs have label -1.
#
# Graphs 54 and 88 are isomorphic.
#   Graph 54 has 41 nodes and 43 edges.
#   Graph 88 has 41 nodes and 43 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 54 and Graph 88: 1.2214181058671326e-08
# Same classification label.
# Both graphs have label -1.
#
# Graphs 54 and 90 are isomorphic.
#   Graph 54 has 41 nodes and 43 edges.
#   Graph 90 has 41 nodes and 43 edges.
#   Classification labels: -1 vs 1
#   GW Distance between Graph 54 and Graph 90: 1.2214181058671326e-08
#
# Graphs 55 and 56 are isomorphic.
#   Graph 55 has 42 nodes and 44 edges.
#   Graph 56 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 55 and Graph 56: 0.016663195529135505
# Same classification label.
# Both graphs have label -1.
#
# Graphs 55 and 82 are isomorphic.
#   Graph 55 has 42 nodes and 44 edges.
#   Graph 82 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 55 and Graph 82: 0.016663195529135505
# Same classification label.
# Both graphs have label -1.
#
# Graphs 55 and 89 are isomorphic.
#   Graph 55 has 42 nodes and 44 edges.
#   Graph 89 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 55 and Graph 89: 0.016663195529135505
# Same classification label.
# Both graphs have label -1.
#
# Graphs 56 and 82 are isomorphic.
#   Graph 56 has 42 nodes and 44 edges.
#   Graph 82 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 56 and Graph 82: 0.016663195529135505
# Same classification label.
# Both graphs have label -1.
#
# Graphs 56 and 89 are isomorphic.
#   Graph 56 has 42 nodes and 44 edges.
#   Graph 89 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 56 and Graph 89: 0.016663195529135505
# Same classification label.
# Both graphs have label -1.
#
# Graphs 58 and 83 are isomorphic.
#   Graph 58 has 46 nodes and 48 edges.
#   Graph 83 has 46 nodes and 48 edges.
#   Classification labels: 1 vs -1
#   GW Distance between Graph 58 and Graph 83: 0.021516159100236326
#
# Graphs 60 and 61 are isomorphic.
#   Graph 60 has 40 nodes and 42 edges.
#   Graph 61 has 40 nodes and 42 edges.
#   Classification labels: 1 vs -1
#   GW Distance between Graph 60 and Graph 61: 8.736580162911545e-09
#
# Graphs 62 and 63 are isomorphic.
#   Graph 62 has 37 nodes and 39 edges.
#   Graph 63 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 62 and Graph 63: 0.031115653944065225
# Same classification label.
# Both graphs have label -1.
#
# Graphs 62 and 64 are isomorphic.
#   Graph 62 has 37 nodes and 39 edges.
#   Graph 64 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 62 and Graph 64: 0.031115653944065225
# Same classification label.
# Both graphs have label -1.
#
# Graphs 62 and 70 are isomorphic.
#   Graph 62 has 37 nodes and 39 edges.
#   Graph 70 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 62 and Graph 70: 0.031115653944065225
# Same classification label.
# Both graphs have label -1.
#
# Graphs 62 and 100 are isomorphic.
#   Graph 62 has 37 nodes and 39 edges.
#   Graph 100 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 62 and Graph 100: 0.031115653944065225
# Same classification label.
# Both graphs have label -1.
#
# Graphs 62 and 347 are isomorphic.
#   Graph 62 has 37 nodes and 39 edges.
#   Graph 347 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 62 and Graph 347: 7.33324128576723e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 63 and 64 are isomorphic.
#   Graph 63 has 37 nodes and 39 edges.
#   Graph 64 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 63 and Graph 64: 0.031115653944065225
# Same classification label.
# Both graphs have label -1.
#
# Graphs 63 and 70 are isomorphic.
#   Graph 63 has 37 nodes and 39 edges.
#   Graph 70 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 63 and Graph 70: 0.031115653944065225
# Same classification label.
# Both graphs have label -1.
#
# Graphs 63 and 100 are isomorphic.
#   Graph 63 has 37 nodes and 39 edges.
#   Graph 100 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 63 and Graph 100: 0.031115653944065225
# Same classification label.
# Both graphs have label -1.
#
# Graphs 63 and 347 are isomorphic.
#   Graph 63 has 37 nodes and 39 edges.
#   Graph 347 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 63 and Graph 347: 7.33324128576723e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 64 and 70 are isomorphic.
#   Graph 64 has 37 nodes and 39 edges.
#   Graph 70 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 64 and Graph 70: 0.031115653944065225
# Same classification label.
# Both graphs have label -1.
#
# Graphs 64 and 100 are isomorphic.
#   Graph 64 has 37 nodes and 39 edges.
#   Graph 100 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 64 and Graph 100: 0.031115653944065225
# Same classification label.
# Both graphs have label -1.
#
# Graphs 64 and 347 are isomorphic.
#   Graph 64 has 37 nodes and 39 edges.
#   Graph 347 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 64 and Graph 347: 7.33324128576723e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 65 and 101 are isomorphic.
#   Graph 65 has 40 nodes and 42 edges.
#   Graph 101 has 40 nodes and 42 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 65 and Graph 101: 7.830174509808531e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 65 and 102 are isomorphic.
#   Graph 65 has 40 nodes and 42 edges.
#   Graph 102 has 40 nodes and 42 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 65 and Graph 102: 7.830174509808531e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 66 and 67 are isomorphic.
#   Graph 66 has 38 nodes and 40 edges.
#   Graph 67 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 66 and Graph 67: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 66 and 85 are isomorphic.
#   Graph 66 has 38 nodes and 40 edges.
#   Graph 85 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 66 and Graph 85: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 66 and 91 are isomorphic.
#   Graph 66 has 38 nodes and 40 edges.
#   Graph 91 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 66 and Graph 91: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 66 and 112 are isomorphic.
#   Graph 66 has 38 nodes and 40 edges.
#   Graph 112 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 66 and Graph 112: 0.019833925042778863
# Same classification label.
# Both graphs have label -1.
#
# Graphs 66 and 113 are isomorphic.
#   Graph 66 has 38 nodes and 40 edges.
#   Graph 113 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 66 and Graph 113: 0.019833925042778863
# Same classification label.
# Both graphs have label -1.
#
# Graphs 67 and 85 are isomorphic.
#   Graph 67 has 38 nodes and 40 edges.
#   Graph 85 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 67 and Graph 85: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 67 and 91 are isomorphic.
#   Graph 67 has 38 nodes and 40 edges.
#   Graph 91 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 67 and Graph 91: 0.022902243925070325
# Same classification label.
# Both graphs have label -1.
#
# Graphs 67 and 112 are isomorphic.
#   Graph 67 has 38 nodes and 40 edges.
#   Graph 112 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 67 and Graph 112: 0.019833925042778863
# Same classification label.
# Both graphs have label -1.
#
# Graphs 67 and 113 are isomorphic.
#   Graph 67 has 38 nodes and 40 edges.
#   Graph 113 has 38 nodes and 40 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 67 and Graph 113: 0.019833925042778863
# Same classification label.
# Both graphs have label -1.
#
# Graphs 68 and 92 are isomorphic.
#   Graph 68 has 41 nodes and 43 edges.
#   Graph 92 has 41 nodes and 43 edges.
#   Classification labels: -1 vs 1
#   GW Distance between Graph 68 and Graph 92: 1.1444283395488288e-08
#
# Graphs 68 and 93 are isomorphic.
#   Graph 68 has 41 nodes and 43 edges.
#   Graph 93 has 41 nodes and 43 edges.
#   Classification labels: -1 vs 1
#   GW Distance between Graph 68 and Graph 93: 1.1444283395488288e-08
#
# Graphs 70 and 100 are isomorphic.
#   Graph 70 has 37 nodes and 39 edges.
#   Graph 100 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 70 and Graph 100: 0.031115653944065225
# Same classification label.
# Both graphs have label -1.
#
# Graphs 70 and 347 are isomorphic.
#   Graph 70 has 37 nodes and 39 edges.
#   Graph 347 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 70 and Graph 347: 7.33324128576723e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 72 and 73 are isomorphic.
#   Graph 72 has 42 nodes and 44 edges.
#   Graph 73 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 72 and Graph 73: 0.015552315827195714
# Same classification label.
# Both graphs have label -1.
#
# Graphs 72 and 74 are isomorphic.
#   Graph 72 has 42 nodes and 44 edges.
#   Graph 74 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 72 and Graph 74: 0.015552315827195714
# Same classification label.
# Both graphs have label -1.
#
# Graphs 72 and 104 are isomorphic.
#   Graph 72 has 42 nodes and 44 edges.
#   Graph 104 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 72 and Graph 104: 0.015552315827195714
# Same classification label.
# Both graphs have label -1.
#
# Graphs 72 and 105 are isomorphic.
#   Graph 72 has 42 nodes and 44 edges.
#   Graph 105 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 72 and Graph 105: 0.015552315827195714
# Same classification label.
# Both graphs have label -1.
#
# Graphs 72 and 106 are isomorphic.
#   Graph 72 has 42 nodes and 44 edges.
#   Graph 106 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 72 and Graph 106: 0.015552315827195714
# Same classification label.
# Both graphs have label -1.
#
# Graphs 73 and 74 are isomorphic.
#   Graph 73 has 42 nodes and 44 edges.
#   Graph 74 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 73 and Graph 74: 0.015552315827195714
# Same classification label.
# Both graphs have label -1.
#
# Graphs 73 and 104 are isomorphic.
#   Graph 73 has 42 nodes and 44 edges.
#   Graph 104 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 73 and Graph 104: 0.015552315827195714
# Same classification label.
# Both graphs have label -1.
#
# Graphs 73 and 105 are isomorphic.
#   Graph 73 has 42 nodes and 44 edges.
#   Graph 105 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 73 and Graph 105: 0.015552315827195714
# Same classification label.
# Both graphs have label -1.
#
# Graphs 73 and 106 are isomorphic.
#   Graph 73 has 42 nodes and 44 edges.
#   Graph 106 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 73 and Graph 106: 0.015552315827195714
# Same classification label.
# Both graphs have label -1.
#
# Graphs 74 and 104 are isomorphic.
#   Graph 74 has 42 nodes and 44 edges.
#   Graph 104 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 74 and Graph 104: 0.015552315827195714
# Same classification label.
# Both graphs have label -1.
#
# Graphs 74 and 105 are isomorphic.
#   Graph 74 has 42 nodes and 44 edges.
#   Graph 105 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 74 and Graph 105: 0.015552315827195714
# Same classification label.
# Both graphs have label -1.
#
# Graphs 74 and 106 are isomorphic.
#   Graph 74 has 42 nodes and 44 edges.
#   Graph 106 has 42 nodes and 44 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 74 and Graph 106: 0.015552315827195714
# Same classification label.
# Both graphs have label -1.
#
# Graphs 75 and 76 are isomorphic.
#   Graph 75 has 46 nodes and 48 edges.
#   Graph 76 has 46 nodes and 48 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 75 and Graph 76: 0.02008174849355361
# Same classification label.
# Both graphs have label -1.
#
# Graphs 75 and 109 are isomorphic.
#   Graph 75 has 46 nodes and 48 edges.
# ...
# Same classification label.
# Both graphs have label -1.
#
# Graphs 394 and 398 are isomorphic.
#   Graph 394 has 43 nodes and 46 edges.
#   Graph 398 has 43 nodes and 46 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 394 and Graph 398: 0.024787846977728983
# Same classification label.
# Both graphs have label -1.
#
# Graphs 394 and 399 are isomorphic.
#   Graph 394 has 43 nodes and 46 edges.
#   Graph 399 has 43 nodes and 46 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 394 and Graph 399: 0.024787846977728983
# Same classification label.
# Both graphs have label -1.
#
# Graphs 395 and 397 are isomorphic.
#   Graph 395 has 42 nodes and 45 edges.
#   Graph 397 has 42 nodes and 45 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 395 and Graph 397: 0.00732600732600924
# Same classification label.
# Both graphs have label -1.
#
# Graphs 396 and 398 are isomorphic.
#   Graph 396 has 43 nodes and 46 edges.
#   Graph 398 has 43 nodes and 46 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 396 and Graph 398: 0.024787846977728983
# Same classification label.
# Both graphs have label -1.
#
# Graphs 396 and 399 are isomorphic.
#   Graph 396 has 43 nodes and 46 edges.
#   Graph 399 has 43 nodes and 46 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 396 and Graph 399: 0.024787846977728983
# Same classification label.
# Both graphs have label -1.
#
# Graphs 398 and 399 are isomorphic.
#   Graph 398 has 43 nodes and 46 edges.
#   Graph 399 has 43 nodes and 46 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 398 and Graph 399: 0.024787846977728983
# Same classification label.
# Both graphs have label -1.
#
# Graphs 410 and 411 are isomorphic.
#   Graph 410 has 37 nodes and 39 edges.
#   Graph 411 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 410 and Graph 411: 5.319556062480371e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 410 and 413 are isomorphic.
#   Graph 410 has 37 nodes and 39 edges.
#   Graph 413 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 410 and Graph 413: 0.031115653944065506
# Same classification label.
# Both graphs have label -1.
#
# Graphs 410 and 414 are isomorphic.
#   Graph 410 has 37 nodes and 39 edges.
#   Graph 414 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 410 and Graph 414: 0.031115653944065506
# Same classification label.
# Both graphs have label -1.
#
# Graphs 411 and 413 are isomorphic.
#   Graph 411 has 37 nodes and 39 edges.
#   Graph 413 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 411 and Graph 413: 0.02036997707096034
# Same classification label.
# Both graphs have label -1.
#
# Graphs 411 and 414 are isomorphic.
#   Graph 411 has 37 nodes and 39 edges.
#   Graph 414 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 411 and Graph 414: 0.02036997707096034
# Same classification label.
# Both graphs have label -1.
#
# Graphs 412 and 415 are isomorphic.
#   Graph 412 has 44 nodes and 47 edges.
#   Graph 415 has 44 nodes and 47 edges.
#   Classification labels: -1 vs 1
#   GW Distance between Graph 412 and Graph 415: 0.015905777550537587
#
# Graphs 412 and 424 are isomorphic.
#   Graph 412 has 44 nodes and 47 edges.
#   Graph 424 has 44 nodes and 47 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 412 and Graph 424: 0.015905777550537587
# Same classification label.
# Both graphs have label -1.
#
# Graphs 412 and 425 are isomorphic.
#   Graph 412 has 44 nodes and 47 edges.
#   Graph 425 has 44 nodes and 47 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 412 and Graph 425: 0.015905777550537587
# Same classification label.
# Both graphs have label -1.
#
# Graphs 412 and 431 are isomorphic.
#   Graph 412 has 44 nodes and 47 edges.
#   Graph 431 has 44 nodes and 47 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 412 and Graph 431: 0.015905777550537587
# Same classification label.
# Both graphs have label -1.
#
# Graphs 412 and 432 are isomorphic.
#   Graph 412 has 44 nodes and 47 edges.
#   Graph 432 has 44 nodes and 47 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 412 and Graph 432: 0.015905777550537587
# Same classification label.
# Both graphs have label -1.
#
# Graphs 412 and 433 are isomorphic.
#   Graph 412 has 44 nodes and 47 edges.
#   Graph 433 has 44 nodes and 47 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 412 and Graph 433: 0.015905777550537587
# Same classification label.
# Both graphs have label -1.
#
# Graphs 412 and 434 are isomorphic.
#   Graph 412 has 44 nodes and 47 edges.
#   Graph 434 has 44 nodes and 47 edges.
#   Classification labels: -1 vs 1
#   GW Distance between Graph 412 and Graph 434: 0.015905777550537587
#
# Graphs 412 and 435 are isomorphic.
#   Graph 412 has 44 nodes and 47 edges.
#   Graph 435 has 44 nodes and 47 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 412 and Graph 435: 0.015905777550537587
# Same classification label.
# Both graphs have label -1.
#
# Graphs 413 and 414 are isomorphic.
#   Graph 413 has 37 nodes and 39 edges.
#   Graph 414 has 37 nodes and 39 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 413 and Graph 414: 0.02036997707096129
# Same classification label.
# Both graphs have label -1.
#
# Graphs 415 and 424 are isomorphic.
#   Graph 415 has 44 nodes and 47 edges.
#   Graph 424 has 44 nodes and 47 edges.
#   Classification labels: 1 vs -1
#   GW Distance between Graph 415 and Graph 424: 0.015905777550537244
#
# Graphs 415 and 425 are isomorphic.
#   Graph 415 has 44 nodes and 47 edges.
#   Graph 425 has 44 nodes and 47 edges.
#   Classification labels: 1 vs -1
#   GW Distance between Graph 415 and Graph 425: 0.015905777550537244
#
# Graphs 415 and 431 are isomorphic.
#   Graph 415 has 44 nodes and 47 edges.
#   Graph 431 has 44 nodes and 47 edges.
#   Classification labels: 1 vs -1
#   GW Distance between Graph 415 and Graph 431: 0.015905777550537244
#
# Graphs 415 and 432 are isomorphic.
#   Graph 415 has 44 nodes and 47 edges.
#   Graph 432 has 44 nodes and 47 edges.
#   Classification labels: 1 vs -1
#   GW Distance between Graph 415 and Graph 432: 0.015905777550537244
#
# Graphs 415 and 433 are isomorphic.
#   Graph 415 has 44 nodes and 47 edges.
#   Graph 433 has 44 nodes and 47 edges.
#   Classification labels: 1 vs -1
#   GW Distance between Graph 415 and Graph 433: 0.015905777550537244
#
# Graphs 415 and 434 are isomorphic.
#   Graph 415 has 44 nodes and 47 edges.
#   Graph 434 has 44 nodes and 47 edges.
#   Classification labels: 1 vs 1
#   GW Distance between Graph 415 and Graph 434: 0.015905777550537244
# Same classification label.
# Both graphs have label 1.
#
# Graphs 415 and 435 are isomorphic.
#   Graph 415 has 44 nodes and 47 edges.
#   Graph 435 has 44 nodes and 47 edges.
#   Classification labels: 1 vs -1
#   GW Distance between Graph 415 and Graph 435: 0.015905777550537244
#
# Graphs 422 and 423 are isomorphic.
#   Graph 422 has 53 nodes and 56 edges.
#   Graph 423 has 53 nodes and 56 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 422 and Graph 423: 6.7158625935464895e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 424 and 425 are isomorphic.
#   Graph 424 has 44 nodes and 47 edges.
#   Graph 425 has 44 nodes and 47 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 424 and Graph 425: 0.015905777550537244
# Same classification label.
# Both graphs have label -1.
#
# Graphs 424 and 431 are isomorphic.
#   Graph 424 has 44 nodes and 47 edges.
#   Graph 431 has 44 nodes and 47 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 424 and Graph 431: 0.015905777550537244
# Same classification label.
# Both graphs have label -1.
#
# Graphs 424 and 432 are isomorphic.
#   Graph 424 has 44 nodes and 47 edges.
#   Graph 432 has 44 nodes and 47 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 424 and Graph 432: 0.015905777550537244
# Same classification label.
# Both graphs have label -1.
#
# Graphs 424 and 433 are isomorphic.
#   Graph 424 has 44 nodes and 47 edges.
#   Graph 433 has 44 nodes and 47 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 424 and Graph 433: 0.015905777550537244
# Same classification label.
# Both graphs have label -1.
#
# Graphs 424 and 434 are isomorphic.
#   Graph 424 has 44 nodes and 47 edges.
#   Graph 434 has 44 nodes and 47 edges.
#   Classification labels: -1 vs 1
#   GW Distance between Graph 424 and Graph 434: 0.015905777550537244
#
# Graphs 424 and 435 are isomorphic.
#   Graph 424 has 44 nodes and 47 edges.
#   Graph 435 has 44 nodes and 47 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 424 and Graph 435: 0.015905777550537244
# Same classification label.
# Both graphs have label -1.
#
# Graphs 425 and 431 are isomorphic.
#   Graph 425 has 44 nodes and 47 edges.
#   Graph 431 has 44 nodes and 47 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 425 and Graph 431: 0.015905777550537244
# Same classification label.
# Both graphs have label -1.
#
# Graphs 425 and 432 are isomorphic.
#   Graph 425 has 44 nodes and 47 edges.
#   Graph 432 has 44 nodes and 47 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 425 and Graph 432: 0.015905777550537244
# Same classification label.
# Both graphs have label -1.
#
# Graphs 425 and 433 are isomorphic.
#   Graph 425 has 44 nodes and 47 edges.
#   Graph 433 has 44 nodes and 47 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 425 and Graph 433: 0.015905777550537244
# Same classification label.
# Both graphs have label -1.
#
# Graphs 425 and 434 are isomorphic.
#   Graph 425 has 44 nodes and 47 edges.
#   Graph 434 has 44 nodes and 47 edges.
#   Classification labels: -1 vs 1
#   GW Distance between Graph 425 and Graph 434: 0.015905777550537244
#
# Graphs 425 and 435 are isomorphic.
#   Graph 425 has 44 nodes and 47 edges.
#   Graph 435 has 44 nodes and 47 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 425 and Graph 435: 0.015905777550537244
# Same classification label.
# Both graphs have label -1.
#
# Graphs 431 and 432 are isomorphic.
#   Graph 431 has 44 nodes and 47 edges.
#   Graph 432 has 44 nodes and 47 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 431 and Graph 432: 0.015905777550537244
# Same classification label.
# Both graphs have label -1.
#
# Graphs 431 and 433 are isomorphic.
#   Graph 431 has 44 nodes and 47 edges.
#   Graph 433 has 44 nodes and 47 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 431 and Graph 433: 0.015905777550537244
# Same classification label.
# Both graphs have label -1.
#
# Graphs 431 and 434 are isomorphic.
#   Graph 431 has 44 nodes and 47 edges.
#   Graph 434 has 44 nodes and 47 edges.
#   Classification labels: -1 vs 1
#   GW Distance between Graph 431 and Graph 434: 0.015905777550537244
#
# Graphs 431 and 435 are isomorphic.
#   Graph 431 has 44 nodes and 47 edges.
#   Graph 435 has 44 nodes and 47 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 431 and Graph 435: 0.015905777550537244
# Same classification label.
# Both graphs have label -1.
#
# Graphs 432 and 433 are isomorphic.
#   Graph 432 has 44 nodes and 47 edges.
#   Graph 433 has 44 nodes and 47 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 432 and Graph 433: 0.015905777550537244
# Same classification label.
# Both graphs have label -1.
#
# Graphs 432 and 434 are isomorphic.
#   Graph 432 has 44 nodes and 47 edges.
#   Graph 434 has 44 nodes and 47 edges.
#   Classification labels: -1 vs 1
#   GW Distance between Graph 432 and Graph 434: 0.015905777550537244
#
# Graphs 432 and 435 are isomorphic.
#   Graph 432 has 44 nodes and 47 edges.
#   Graph 435 has 44 nodes and 47 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 432 and Graph 435: 0.015905777550537244
# Same classification label.
# Both graphs have label -1.
#
# Graphs 433 and 434 are isomorphic.
#   Graph 433 has 44 nodes and 47 edges.
#   Graph 434 has 44 nodes and 47 edges.
#   Classification labels: -1 vs 1
#   GW Distance between Graph 433 and Graph 434: 0.015905777550537244
#
# Graphs 433 and 435 are isomorphic.
#   Graph 433 has 44 nodes and 47 edges.
#   Graph 435 has 44 nodes and 47 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 433 and Graph 435: 0.015905777550537244
# Same classification label.
# Both graphs have label -1.
#
# Graphs 434 and 435 are isomorphic.
#   Graph 434 has 44 nodes and 47 edges.
#   Graph 435 has 44 nodes and 47 edges.
#   Classification labels: 1 vs -1
#   GW Distance between Graph 434 and Graph 435: 0.015905777550537244
#
# Graphs 438 and 439 are isomorphic.
#   Graph 438 has 36 nodes and 38 edges.
#   Graph 439 has 36 nodes and 38 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 438 and Graph 439: 0.02093580976737817
# Same classification label.
# Both graphs have label -1.
#
# Graphs 438 and 440 are isomorphic.
#   Graph 438 has 36 nodes and 38 edges.
#   Graph 440 has 36 nodes and 38 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 438 and Graph 440: 0.02093580976737765
# Same classification label.
# Both graphs have label -1.
#
# Graphs 438 and 441 are isomorphic.
#   Graph 438 has 36 nodes and 38 edges.
#   Graph 441 has 36 nodes and 38 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 438 and Graph 441: 0.02093580976737765
# Same classification label.
# Both graphs have label -1.
#
# Graphs 438 and 442 are isomorphic.
#   Graph 438 has 36 nodes and 38 edges.
#   Graph 442 has 36 nodes and 38 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 438 and Graph 442: 0.02093580976737765
# Same classification label.
# Both graphs have label -1.
#
# Graphs 439 and 440 are isomorphic.
#   Graph 439 has 36 nodes and 38 edges.
#   Graph 440 has 36 nodes and 38 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 439 and Graph 440: 0.02093580976737765
# Same classification label.
# Both graphs have label -1.
#
# Graphs 439 and 441 are isomorphic.
#   Graph 439 has 36 nodes and 38 edges.
#   Graph 441 has 36 nodes and 38 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 439 and Graph 441: 0.02093580976737765
# Same classification label.
# Both graphs have label -1.
#
# Graphs 439 and 442 are isomorphic.
#   Graph 439 has 36 nodes and 38 edges.
#   Graph 442 has 36 nodes and 38 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 439 and Graph 442: 0.02093580976737765
# Same classification label.
# Both graphs have label -1.
#
# Graphs 440 and 441 are isomorphic.
#   Graph 440 has 36 nodes and 38 edges.
#   Graph 441 has 36 nodes and 38 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 440 and Graph 441: 0.020935809767378213
# Same classification label.
# Both graphs have label -1.
#
# Graphs 440 and 442 are isomorphic.
#   Graph 440 has 36 nodes and 38 edges.
#   Graph 442 has 36 nodes and 38 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 440 and Graph 442: 0.020935809767378213
# Same classification label.
# Both graphs have label -1.
#
# Graphs 441 and 442 are isomorphic.
#   Graph 441 has 36 nodes and 38 edges.
#   Graph 442 has 36 nodes and 38 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 441 and Graph 442: 0.020935809767378213
# Same classification label.
# Both graphs have label -1.
#
# Graphs 462 and 464 are isomorphic.
#   Graph 462 has 45 nodes and 48 edges.
#   Graph 464 has 45 nodes and 48 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 462 and Graph 464: 3.3091451980992908e-09
# Same classification label.
# Both graphs have label -1.
#
# Graphs 463 and 465 are isomorphic.
#   Graph 463 has 44 nodes and 47 edges.
#   Graph 465 has 44 nodes and 47 edges.
#   Classification labels: -1 vs -1
#   GW Distance between Graph 463 and Graph 465: 0.02099455524325759
# Same classification label.
# Both graphs have label -1.
#
# Total number of graph pairs: 108811.0
# Total isomorphic pairs found: 655
# Pairs with same classification label: 547
# Pairs with both graphs having label 1: 14
# Pairs with both graphs having label -1: 533

# %%
# Create scatterplot of GW distances by class
plt.figure(figsize=(10, 8))

# Convert labels to numpy array for easier indexing
labels_array = np.array(labels_list)

# Get indices for each class
class_1_indices = np.where(labels_array == 1)[0]  # Active class
class_minus1_indices = np.where(labels_array == -1)[0]  # Inactive class

# Extract GW distances for different class combinations
# Within class 1 (active vs active)
within_class1_distances = []
for i in range(len(class_1_indices)):
    for j in range(i+1, len(class_1_indices)):
        idx_i, idx_j = class_1_indices[i], class_1_indices[j]
        within_class1_distances.append(gw[idx_i, idx_j])

# Within class -1 (inactive vs inactive)
within_class_minus1_distances = []
for i in range(len(class_minus1_indices)):
    for j in range(i+1, len(class_minus1_indices)):
        idx_i, idx_j = class_minus1_indices[i], class_minus1_indices[j]
        within_class_minus1_distances.append(gw[idx_i, idx_j])

# Between classes (active vs inactive)
between_classes_distances = []
for i in class_1_indices:
    for j in class_minus1_indices:
        between_classes_distances.append(gw[i, j])

# Create scatter plot
x_positions = []
distances = []
colors = []
labels_plot = []

# Add within class 1 distances
x_positions.extend([0] * len(within_class1_distances))
distances.extend(within_class1_distances)
colors.extend(['blue'] * len(within_class1_distances))
labels_plot.extend(['Active vs Active'] * len(within_class1_distances))

# Add within class -1 distances
x_positions.extend([1] * len(within_class_minus1_distances))
distances.extend(within_class_minus1_distances)
colors.extend(['orange'] * len(within_class_minus1_distances))
labels_plot.extend(['Inactive vs Inactive'] * len(within_class_minus1_distances))

# Add between classes distances
x_positions.extend([2] * len(between_classes_distances))
distances.extend(between_classes_distances)
colors.extend(['gray'] * len(between_classes_distances))
labels_plot.extend(['Active vs Inactive'] * len(between_classes_distances))

# Create the scatter plot
scatter = plt.scatter(x_positions, distances, c=colors, alpha=0.6, s=30)
# Customize the plot
plt.xlabel('Class Comparison')
plt.ylabel('Gromov-Wasserstein Distance')
plt.title('Gromov-Wasserstein Distances Between Graph Classes')
plt.xticks([0, 1, 2], ['Active vs Active\n(Class 1)', 'Inactive vs Inactive\n(Class -1)', 'Active vs Inactive\n(Cross-class)'])
legend_elements = [Patch(facecolor='blue', label='Active vs Active'),
                   Patch(facecolor='orange', label='Inactive vs Inactive'),
                   Patch(facecolor='gray', label='Active vs Inactive')]
plt.legend(handles=legend_elements)

# Add some statistics
print(f"Within Active class - Mean: {np.mean(within_class1_distances):.4f}, Std: {np.std(within_class1_distances):.4f}")
print(f"Within Inactive class - Mean: {np.mean(within_class_minus1_distances):.4f}, Std: {np.std(within_class_minus1_distances):.4f}")
print(f"Between classes - Mean: {np.mean(between_classes_distances):.4f}, Std: {np.std(between_classes_distances):.4f}")

plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Within Active class - Mean: 0.0995, Std: 0.0305
# Within Inactive class - Mean: 0.0891, Std: 0.0287
# Between classes - Mean: 0.0949, Std: 0.0293

# %%
# Perform statistical test
active_vs_inactive_mean = np.mean(between_classes_distances)
within_active_mean = np.mean(within_class1_distances)
within_inactive_mean = np.mean(within_class_minus1_distances)

print(f"\nStatistical Summary:")
print(f"Number of Active graphs: {len(class_1_indices)}")
print(f"Number of Inactive graphs: {len(class_minus1_indices)}")
print(f"Number of within-Active comparisons: {len(within_class1_distances)}")
print(f"Number of within-Inactive comparisons: {len(within_class_minus1_distances)}")
print(f"Number of cross-class comparisons: {len(between_classes_distances)}")

# Test if between-class distances are significantly different from within-class distances
all_within_class = within_class1_distances + within_class_minus1_distances
t_stat, p_value = ttest_ind(between_classes_distances, all_within_class)
print(f"\nT-test (Between-class vs Within-class distances):")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")
print(f"Significant difference: {'Yes' if p_value < 0.05 else 'No'}")
# Out:
# Statistical Summary:
# Number of Active graphs: 102
# Number of Inactive graphs: 365
# Number of within-Active comparisons: 5151
# Number of within-Inactive comparisons: 66430
# Number of cross-class comparisons: 37230
#
# T-test (Between-class vs Within-class distances):
# T-statistic: 27.4023
# P-value: 0.0000
# Significant difference: Yes

# %%
# gLGW Distances Scatterplots #

# %%
k_bary = 41  # use average
idx_bary = []
classes = [-1,1]

for i in classes:
    # Find the indices of instances with label i
    labels_list = np.asarray(labels_list) 
    indices = np.where(labels_list == i)[0]
    if indices.size > 0:
        idx_bary.extend(np.random.choice(indices, size=min(5, len(indices)), replace=False))

# Initialize reference matrix with k_bary size
M_ref = np.zeros((k_bary, k_bary))
selected_Ms = [Ms[i] for i in idx_bary]
selected_heights = [heights[i] for i in idx_bary]
lambdas = ot.unif(len(idx_bary))

M_ref = ot.gromov.gromov_barycenters(k_bary,
                                     Cs=selected_Ms,
                                     ps=selected_heights,
                                     p=ot.unif(k_bary),
                                     lambdas=lambdas,
                                     loss_fun='square_loss',
                                     max_iter=200,
                                     tol=1e-12,
                                     random_state=42)

height_ref = ot.unif(k_bary)
lgw_matrix, lgw_time = lgw_procedure(M_ref,
                                     height_ref,
                                     None,
                                     Ms,
                                     heights,
                                     mode="graph")

# %%
print(f"\ngLGW computation summary:")
print(f"gLGW computation time: {lgw_time:.4f} seconds")
print(f"Min gLGW value: {np.min(lgw_matrix[lgw_matrix != 0])}")
print(f"Max gLGW value: {np.max(lgw_matrix)}")
print(f"Number of NaN values: {np.sum(np.isnan(lgw_matrix))}")

negative_lgw_count = np.sum(lgw_matrix < 0)
if negative_lgw_count > 0:
    print(f"Warning: {negative_lgw_count} negative gLGW values found!")
# Out:
# gLGW computation summary:
# gLGW computation time: 3.1673 seconds
# Min gLGW value: 0.014543531560974241
# Max gLGW value: 0.2606030229397205
# Number of NaN values: 0

# %%
# Create scatterplot of gLGW distances by class
plt.figure(figsize=(10, 8))

# Convert labels to numpy array for easier indexing
labels_array = np.array(labels_list)

# Get indices for each class
class_1_indices = np.where(labels_array == 1)[0]  # Active class
class_minus1_indices = np.where(labels_array == -1)[0]  # Inactive class

# Extract gLGW distances for different class combinations
# Within class 1 (active vs active)
within_class1_lgw_distances = []
for i in range(len(class_1_indices)):
    for j in range(i+1, len(class_1_indices)):
        idx_i, idx_j = class_1_indices[i], class_1_indices[j]
        within_class1_lgw_distances.append(lgw_matrix[idx_i, idx_j])

# Within class -1 (inactive vs inactive)
within_class_minus1_lgw_distances = []
for i in range(len(class_minus1_indices)):
    for j in range(i+1, len(class_minus1_indices)):
        idx_i, idx_j = class_minus1_indices[i], class_minus1_indices[j]
        within_class_minus1_lgw_distances.append(lgw_matrix[idx_i, idx_j])

# Between classes (active vs inactive)
between_classes_lgw_distances = []
for i in class_1_indices:
    for j in class_minus1_indices:
        between_classes_lgw_distances.append(lgw_matrix[i, j])

# Create scatter plot
x_positions_lgw = []
distances_lgw = []
colors_lgw = []
labels_plot_lgw = []

# Add within class 1 distances
x_positions_lgw.extend([0] * len(within_class1_lgw_distances))
distances_lgw.extend(within_class1_lgw_distances)
colors_lgw.extend(['blue'] * len(within_class1_lgw_distances))
labels_plot_lgw.extend(['Active vs Active'] * len(within_class1_lgw_distances))

# Add within class -1 distances
x_positions_lgw.extend([1] * len(within_class_minus1_lgw_distances))
distances_lgw.extend(within_class_minus1_lgw_distances)
colors_lgw.extend(['orange'] * len(within_class_minus1_lgw_distances))
labels_plot_lgw.extend(['Inactive vs Inactive'] * len(within_class_minus1_lgw_distances))

# Add between classes distances
x_positions_lgw.extend([2] * len(between_classes_lgw_distances))
distances_lgw.extend(between_classes_lgw_distances)
colors_lgw.extend(['gray'] * len(between_classes_lgw_distances))
labels_plot_lgw.extend(['Active vs Inactive'] * len(between_classes_lgw_distances))

# Create the scatter plot
scatter_lgw = plt.scatter(x_positions_lgw, distances_lgw, c=colors_lgw, alpha=0.6, s=30)

# Customize the plot
plt.xlabel('Class Comparison')
plt.ylabel('Generalized Linear Gromov-Wasserstein Distance')
plt.title('Generalized Linear Gromov-Wasserstein Distances Between Graph Classes')
plt.xticks([0, 1, 2], ['Active vs Active\n(Class 1)', 'Inactive vs Inactive\n(Class -1)', 'Active vs Inactive\n(Cross-class)'])

# Add legend
from matplotlib.patches import Patch
legend_elements_lgw = [Patch(facecolor='blue', label='Active vs Active'),
                       Patch(facecolor='orange', label='Inactive vs Inactive'),
                       Patch(facecolor='gray', label='Active vs Inactive')]
plt.legend(handles=legend_elements_lgw)

# Add some statistics
print(f"\ngLGW Distance Statistics:")
print(f"Within Active class - Mean: {np.mean(within_class1_lgw_distances):.4f}, Std: {np.std(within_class1_lgw_distances):.4f}")
print(f"Within Inactive class - Mean: {np.mean(within_class_minus1_lgw_distances):.4f}, Std: {np.std(within_class_minus1_lgw_distances):.4f}")
print(f"Between classes - Mean: {np.mean(between_classes_lgw_distances):.4f}, Std: {np.std(between_classes_lgw_distances):.4f}")

plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# gLGW Distance Statistics:
# Within Active class - Mean: 0.1256, Std: 0.0366
# Within Inactive class - Mean: 0.1136, Std: 0.0346
# Between classes - Mean: 0.1200, Std: 0.0353

# %%
# Perform statistical test for gLGW
active_vs_inactive_lgw_mean = np.mean(between_classes_lgw_distances)
within_active_lgw_mean = np.mean(within_class1_lgw_distances)
within_inactive_lgw_mean = np.mean(within_class_minus1_lgw_distances)

print(f"\ngLGW Statistical Summary:")
print(f"Number of Active graphs: {len(class_1_indices)}")
print(f"Number of Inactive graphs: {len(class_minus1_indices)}")
print(f"Number of within-Active comparisons: {len(within_class1_lgw_distances)}")
print(f"Number of within-Inactive comparisons: {len(within_class_minus1_lgw_distances)}")
print(f"Number of cross-class comparisons: {len(between_classes_lgw_distances)}")

# Test if between-class gLGW distances are significantly different from within-class distances
all_within_class_lgw = within_class1_lgw_distances + within_class_minus1_lgw_distances
t_stat_lgw, p_value_lgw = ttest_ind(between_classes_lgw_distances, all_within_class_lgw)
print(f"\nT-test for LGW (Between-class vs Within-class distances):")
print(f"T-statistic: {t_stat_lgw:.4f}")
print(f"P-value: {p_value_lgw:.4f}")
print(f"Significant difference: {'Yes' if p_value_lgw < 0.05 else 'No'}")

# Additional comparison between GW and LGW results
print(f"gLGW between-class mean: {active_vs_inactive_lgw_mean:.4f}")
print(f"gLGW within-active mean: {within_active_lgw_mean:.4f}")
print(f"gLGW within-inactive mean: {within_inactive_lgw_mean:.4f}")
# Out:
# gLGW Statistical Summary:
# Number of Active graphs: 102
# Number of Inactive graphs: 365
# Number of within-Active comparisons: 5151
# Number of within-Inactive comparisons: 66430
# Number of cross-class comparisons: 37230
#
# T-test for LGW (Between-class vs Within-class distances):
# T-statistic: 24.9560
# P-value: 0.0000
# Significant difference: Yes
# gLGW between-class mean: 0.1200
# gLGW within-active mean: 0.1256
# gLGW within-inactive mean: 0.1136

# %%
## 2D GW vs. gLGW comparison ##
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))
labels_array = np.array(labels_list)

def create_within_class_gw_vs_lgw_scatterplot(gw_matrix, lgw_matrix, labels_array, ax, title, class_label):
    """Create a 2D scatterplot comparing within-class GW vs gLGW distances for a specific class"""

    # Get indices for the specific class
    if class_label == 1:
        class_indices = np.where(labels_array == 1)[0]  # ER class
        class_name = "Active"
        color = 'blue'
    else:
        class_indices = np.where(labels_array == -1)[0]  # SBM class
        class_name = "Inactive"
        color = 'orange'

    # Extract within-class distances only
    gw_within_class = []
    lgw_within_class = []

    for i in range(len(class_indices)):
        for j in range(i + 1, len(class_indices)):
            idx_i, idx_j = class_indices[i], class_indices[j]
            gw_within_class.append(gw_matrix[idx_i, idx_j])
            lgw_within_class.append(lgw_matrix[idx_i, idx_j])

    # Create scatter plot
    ax.scatter(gw_within_class, lgw_within_class, alpha=0.6, s=30, color=color, 
               edgecolors='black', linewidth=0.5)

    # Add diagonal line for comparison
    if len(gw_within_class) > 0:
        min_val = min(min(gw_within_class), min(lgw_within_class))
        max_val = max(max(gw_within_class), max(lgw_within_class))
        ax.plot([min_val, max_val], [min_val, max_val], 'k--', alpha=0.7, linewidth=2, label='y=x diagonal')

    # Customize the plot
    ax.set_xlabel('GW Distance (Within-class)')
    ax.set_ylabel('gLGW Distance (Within-class)')
    ax.set_title(f'{title} - {class_name} Class')
    ax.grid(True, alpha=0.3)
    ax.legend()

    # Calculate correlation coefficient if there are enough points
    if len(gw_within_class) > 1:
        correlation = np.corrcoef(gw_within_class, lgw_within_class)[0, 1]
        ax.text(0.05, 0.95, f'Correlation: {correlation:.4f}', transform=ax.transAxes, 
                bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
    else:
        correlation = np.nan
        ax.text(0.05, 0.95, 'Insufficient data', transform=ax.transAxes, 
                bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

    return gw_within_class, lgw_within_class, correlation

# Create scatterplots for both datasets and both classes
gw_within_active_1, lgw_within_active_1, corr_active_1 = create_within_class_gw_vs_lgw_scatterplot(
    gw, lgw_matrix, labels_array, ax1, 'COX-2', 1
)

gw_within_inactive_1, lgw_within_inactive_1, corr_inactive_1 = create_within_class_gw_vs_lgw_scatterplot(
    gw, lgw_matrix, labels_array, ax2, 'COX-2', -1
)
plt.tight_layout()

# %%
# fGW Distances Scatterplots #

# Initialize fGW distance matrix
fgw_matrix = np.zeros((N, N))

# Track negative values during computation
negative_fgw_count = 0
negative_fgw_pairs = []

# Compute fused Gromov-Wasserstein distances
for i in range(N):
    for j in range(i + 1, N):
        # Get features for both graphs
        graph_i = graphs_list[i]
        graph_j = graphs_list[j]

        # Extract node features
        features_i = np.array(
            [graph_i.nodes[n]['attributes'] for n in graph_i.nodes()])
        features_j = np.array(
            [graph_j.nodes[n]['attributes'] for n in graph_j.nodes()])

        # Compute metric cost matrix between features
        M = ot.dist(features_i, features_j, metric='euclidean')

        # Compute fGW distance
        try:
            fgw_result = ot.gromov.fused_gromov_wasserstein2(
                M,
                Ms[i],
                Ms[j],
                heights[i],
                heights[j],
                loss_fun='square_loss',
                alpha=0.0,
                log=True)
            fgw_value = fgw_result[0]
            fgw_matrix[i, j] = fgw_value

            # Check for negative values
            if fgw_value < 0:
                negative_fgw_count += 1
                negative_fgw_pairs.append((i, j, fgw_value))

            # Check for NaN values
            if np.isnan(fgw_value):
                print(f"NaN fGW distance found: graphs {i} and {j}")

        except Exception as e:
            print(
                f"Error computing fGW distance between graphs {i} and {j}: {e}"
            )
            fgw_matrix[i, j] = np.nan

# Make matrix symmetric
fgw_matrix += fgw_matrix.T

print(f"\nfGW computation summary:")
print(f"Total negative values found: {negative_fgw_count}")
print(f"Min fGW value: {np.min(fgw_matrix[fgw_matrix != 0])}")
print(f"Max fGW value: {np.max(fgw_matrix)}")
print(f"Number of NaN values: {np.sum(np.isnan(fgw_matrix))}")

# Print first few negative pairs if any
if negative_fgw_pairs:
    print(f"\nFirst 5 negative fGW pairs:")
    for i, (idx_i, idx_j, val) in enumerate(negative_fgw_pairs[:5]):
        print(f"  Pair {i+1}: graphs {idx_i} and {idx_j}, value: {val}")

# Handle negative values by taking absolute value if needed
if negative_fgw_count > 0:
    print("Taking absolute values of negative fGW distances...")
    fgw_matrix = np.abs(fgw_matrix)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ot/gromov/_gw.py:623: RuntimeWarning: divide by zero encountered in scalar divide
#   gw_term = log_fgw['quad_loss'] / alpha
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ot/gromov/_gw.py:623: RuntimeWarning: invalid value encountered in scalar divide
#   gw_term = log_fgw['quad_loss'] / alpha
# fGW computation summary:
# Total negative values found: 0
# Min fGW value: 0.002576707835121539
# Max fGW value: 3.656493407960493
# Number of NaN values: 0

# %%
# Create scatterplot of fGW distances by class
plt.figure(figsize=(10, 8))

# Convert labels to numpy array for easier indexing
labels_array = np.array(labels_list)

# Get indices for each class
class_1_indices = np.where(labels_array == 1)[0]  # Active class
class_minus1_indices = np.where(labels_array == -1)[0]  # Inactive class

# Extract fGW distances for different class combinations
# Within class 1 (active vs active)
within_class1_fgw_distances = []
for i in range(len(class_1_indices)):
    for j in range(i + 1, len(class_1_indices)):
        idx_i, idx_j = class_1_indices[i], class_1_indices[j]
        within_class1_fgw_distances.append(fgw_matrix[idx_i, idx_j])

# Within class -1 (inactive vs inactive)
within_class_minus1_fgw_distances = []
for i in range(len(class_minus1_indices)):
    for j in range(i + 1, len(class_minus1_indices)):
        idx_i, idx_j = class_minus1_indices[i], class_minus1_indices[j]
        within_class_minus1_fgw_distances.append(fgw_matrix[idx_i, idx_j])

# Between classes (active vs inactive)
between_classes_fgw_distances = []
for i in class_1_indices:
    for j in class_minus1_indices:
        between_classes_fgw_distances.append(fgw_matrix[i, j])

# Create scatter plot
x_positions_fgw = []
distances_fgw = []
colors_fgw = []
labels_plot_fgw = []

# Add within class 1 distances
x_positions_fgw.extend([0] * len(within_class1_fgw_distances))
distances_fgw.extend(within_class1_fgw_distances)
colors_fgw.extend(['blue'] * len(within_class1_fgw_distances))
labels_plot_fgw.extend(['Active vs Active'] * len(within_class1_fgw_distances))

# Add within class -1 distances
x_positions_fgw.extend([1] * len(within_class_minus1_fgw_distances))
distances_fgw.extend(within_class_minus1_fgw_distances)
colors_fgw.extend(['orange'] * len(within_class_minus1_fgw_distances))
labels_plot_fgw.extend(['Inactive vs Inactive'] *
                       len(within_class_minus1_fgw_distances))

# Add between classes distances
x_positions_fgw.extend([2] * len(between_classes_fgw_distances))
distances_fgw.extend(between_classes_fgw_distances)
colors_fgw.extend(['gray'] * len(between_classes_fgw_distances))
labels_plot_fgw.extend(['Active vs Inactive'] *
                       len(between_classes_fgw_distances))

# Create the scatter plot
scatter_fgw = plt.scatter(x_positions_fgw,
                          distances_fgw,
                          c=colors_fgw,
                          alpha=0.6,
                          s=30)

# Customize the plot
plt.xlabel('Class Comparison')
plt.ylabel('Fused Gromov-Wasserstein Distance')
plt.title('Fused Gromov-Wasserstein Distances Between Graph Classes')
plt.xticks([0, 1, 2], [
    'Active vs Active\n(Class 1)', 'Inactive vs Inactive\n(Class -1)',
    'Active vs Inactive\n(Cross-class)'
])

# Add legend
legend_elements_fgw = [
    Patch(facecolor='blue', label='Active vs Active'),
    Patch(facecolor='orange', label='Inactive vs Inactive'),
    Patch(facecolor='gray', label='Active vs Inactive')
]
plt.legend(handles=legend_elements_fgw)

# Add some statistics
print(f"\nfGW Distance Statistics:")
print(
    f"Within Active class - Mean: {np.mean(within_class1_fgw_distances):.4f}, Std: {np.std(within_class1_fgw_distances):.4f}"
)
print(
    f"Within Inactive class - Mean: {np.mean(within_class_minus1_fgw_distances):.4f}, Std: {np.std(within_class_minus1_fgw_distances):.4f}"
)
print(
    f"Between classes - Mean: {np.mean(between_classes_fgw_distances):.4f}, Std: {np.std(between_classes_fgw_distances):.4f}"
)

plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# fGW Distance Statistics:
# Within Active class - Mean: 1.2551, Std: 0.4664
# Within Inactive class - Mean: 1.1704, Std: 0.4444
# Between classes - Mean: 1.2231, Std: 0.4484

# %%
# Perform statistical test for fGW
active_vs_inactive_fgw_mean = np.mean(between_classes_fgw_distances)
within_active_fgw_mean = np.mean(within_class1_fgw_distances)
within_inactive_fgw_mean = np.mean(within_class_minus1_fgw_distances)

print(f"\nfGW Statistical Summary:")
print(f"Number of Active graphs: {len(class_1_indices)}")
print(f"Number of Inactive graphs: {len(class_minus1_indices)}")
print(
    f"Number of within-Active comparisons: {len(within_class1_fgw_distances)}")
print(
    f"Number of within-Inactive comparisons: {len(within_class_minus1_fgw_distances)}"
)
print(
    f"Number of cross-class comparisons: {len(between_classes_fgw_distances)}")

# Test if between-class fGW distances are significantly different from within-class distances
all_within_class_fgw = within_class1_fgw_distances + within_class_minus1_fgw_distances
t_stat_fgw, p_value_fgw = ttest_ind(between_classes_fgw_distances,
                                    all_within_class_fgw)
print(f"\nT-test for fGW (Between-class vs Within-class distances):")
print(f"T-statistic: {t_stat_fgw:.4f}")
print(f"P-value: {p_value_fgw:.4f}")
print(f"Significant difference: {'Yes' if p_value_fgw < 0.05 else 'No'}")

# Final comparison between all three methods
print(f"fGW between-class mean: {active_vs_inactive_fgw_mean:.4f}")
print(f"fGW within-active mean: {within_active_fgw_mean:.4f}")
print(f"fGW within-inactive mean: {within_inactive_fgw_mean:.4f}")
# Out:
# fGW Statistical Summary:
# Number of Active graphs: 102
# Number of Inactive graphs: 365
# Number of within-Active comparisons: 5151
# Number of within-Inactive comparisons: 66430
# Number of cross-class comparisons: 37230
#
# T-test for fGW (Between-class vs Within-class distances):
# T-statistic: 16.3064
# P-value: 0.0000
# Significant difference: Yes
# fGW between-class mean: 1.2231
# fGW within-active mean: 1.2551
# fGW within-inactive mean: 1.1704

# %%
### Distances Scatterplots: Distances from GW & fGW Barycenters of Each Class ###
# Compute the GW barycenter for each category
num_nodes = 41
seed = 42
X_class1 = [
           distance_matrices[j] for j in range(len(distance_matrices)) if labels_list[j] == -1
        ]
X_class2 = [
            distance_matrices[j] for j in range(len(distance_matrices)) if labels_list[j] == 1
        ]

# %%
barycenter_matrix_class1 = ot.gromov.gromov_barycenters(
    N=num_nodes,
    Cs=X_class1,
    loss_fun='square_loss',
    random_state=seed)
print("GW barycenter for Class 1 graphs:",
          barycenter_matrix_class1)
print("GW barycenter for Class 1 graphs computed")
barycenter_matrix_class2 = ot.gromov.gromov_barycenters(
    N=num_nodes,
    Cs=X_class2,
    loss_fun='square_loss',
    random_state=seed)
print("GW barycenter for Class 2 graphs:",
          barycenter_matrix_class2)
print("GW barycenter for Class 2 graphs computed")
# Out:
# GW barycenter for Class 1 graphs: [[ 0.26453731  5.5528365   1.83905901 ...  4.29140673  8.11741931
#    1.71896325]
#  [ 5.5528365   0.1397666   7.1702114  ...  9.62436765 13.4332655
#    4.9943477 ]
#  [ 1.83905901  7.1702114   0.28079804 ...  2.60150324  6.49247499
#    2.30555584]
#  ...
#  [ 4.29140673  9.62436765  2.60150324 ...  0.49238476  5.18601715
#    4.75379557]
#  [ 8.11741931 13.4332655   6.49247499 ...  5.18601715  0.24771805
#    8.56966238]
#  [ 1.71896325  4.9943477   2.30555584 ...  4.75379557  8.56966238
#    0.39965236]]
# GW barycenter for Class 1 graphs computed
# GW barycenter for Class 2 graphs: [[ 0.54608108  7.30011072  1.65586806 ...  2.02887102  7.66335137
#    2.70931272]
#  [ 7.30011072  0.22930463  6.39489597 ...  7.34838726 12.81785127
#    4.82339355]
#  [ 1.65586806  6.39489597  0.27302201 ...  1.06402705  6.55843157
#    1.68042371]
#  ...
#  [ 2.02887102  7.34838726  1.06402705 ...  0.28798333  5.72272243
#    2.61913393]
#  [ 7.66335137 12.81785127  6.55843157 ...  5.72272243  0.24473273
#    8.09546068]
#  [ 2.70931272  4.82339355  1.68042371 ...  2.61913393  8.09546068
#    0.35107498]]
# GW barycenter for Class 2 graphs computed

# %%
def compute_gromov_wasserstein_distance(adj_matrix1, adj_matrix2):
    """
    Compute the Gromov-Wasserstein distance between two adjacency matrices.
    
    Args:
        adj_matrix1: First adjacency matrix
        adj_matrix2: Second adjacency matrix
    
    Returns:
        The Gromov-Wasserstein distance
    """
    n1, n2 = adj_matrix1.shape[0], adj_matrix2.shape[0]
    
    # Create uniform distributions
    p = np.ones(n1) / n1
    q = np.ones(n2) / n2
    
    # Compute Gromov-Wasserstein distance
    gw_dist = np.abs(ot.gromov.gromov_wasserstein2(adj_matrix1, adj_matrix2, p, q, 'square_loss'))
    
    return np.sqrt(gw_dist)

# %%
# Distances from each class to each barycenter
gw_distances_from_negone_to_negonebary = []
gw_distances_from_one_to_negonebary = []
gw_distances_from_negone_to_onebary = []
gw_distances_from_one_to_onebary = []

for j in range(len(distance_matrices)):
    if labels_list[j] == -1:
        dist_negone = compute_gromov_wasserstein_distance(distance_matrices[j], barycenter_matrix_class1)
        dist_one = compute_gromov_wasserstein_distance(distance_matrices[j], barycenter_matrix_class2)
        gw_distances_from_negone_to_negonebary.append(dist_negone)
        gw_distances_from_negone_to_onebary.append(dist_one)
    else:
        dist_negone = compute_gromov_wasserstein_distance(distance_matrices[j], barycenter_matrix_class1)
        dist_one = compute_gromov_wasserstein_distance(distance_matrices[j], barycenter_matrix_class2)
        gw_distances_from_one_to_negonebary.append(dist_negone)
        gw_distances_from_one_to_onebary.append(dist_one)

# %%
# Plot results
distances = (gw_distances_from_negone_to_negonebary + gw_distances_from_one_to_negonebary + 
            gw_distances_from_negone_to_onebary + gw_distances_from_one_to_onebary)
min_dist = min(distances)
max_dist = max(distances)
margin = (max_dist - min_dist) * 0.05  # Add 5% margin

axis_min = min_dist - margin
axis_max = max_dist + margin

plt.figure(figsize=(12, 5))
plt.scatter(gw_distances_from_negone_to_negonebary, gw_distances_from_negone_to_onebary, 
           alpha=0.6, label='Class -1 Graphs', color='blue')
plt.scatter(gw_distances_from_one_to_negonebary, gw_distances_from_one_to_onebary, 
           alpha=0.6, label='Class 1 Graphs', color='orange')
# Add diagonal line
plt.plot([axis_min, axis_max], [axis_min, axis_max],'k--', alpha=0.5, linewidth=1, label='y = x')
plt.xlabel('Distance to Class 1 (Active) Prototype')
plt.ylabel('Distance to Class -1 (Inactive) Prototype')
plt.title('COX-2: GW Distances to GW Barycenters')
plt.legend()
plt.grid(True, alpha=0.3)

# %%
## Repeat the same experiment with fGW distances and fGW barycenters ##
# Compute the fGW barycenter for each category
# Get node attributes for class 1
num_nodes_class1 = 41
num_nodes_class2 = 41
features_class1 = []
class1_indices = [
    j for j in range(len(distance_matrices)) if labels_list[j] == -1
]
for graph_idx in class1_indices:
    graph = graphs_list[graph_idx]
    graph_features = np.array(
        [graph.nodes[n]['attributes'] for n in graph.nodes()])
    features_class1.append(graph_features)

# Create uniform distributions for each graph
ps_class1 = [
    np.ones(len(features)) / len(features)
    for features in features_class1
]
lambdas_class1 = np.ones(len(features_class1)) / len(features_class1)

barycenter_features_class1, barycenter_matrix_class1, log_class1 = ot.gromov.fgw_barycenters(
    N=num_nodes_class1,
    Ys=features_class1,
    Cs=X_class1,
    ps=ps_class1,
    lambdas=lambdas_class1,
    alpha=0.2,
    loss_fun='square_loss',
    random_state=seed,
    log=True)

print("GW barycenter for Class 1 graphs:",
          barycenter_matrix_class1)
print("GW barycenter for Class 1 graphs computed")

# Get node attributes for class 2
features_class2 = []
class2_indices = [
    j for j in range(len(distance_matrices)) if labels_list[j] == 1
]
for graph_idx in class2_indices:
    graph = graphs_list[graph_idx]
    graph_features = np.array(
        [graph.nodes[n]['attributes'] for n in graph.nodes()])
    features_class2.append(graph_features)

# Create uniform distributions for each graph
ps_class2 = [
    np.ones(len(features)) / len(features)
    for features in features_class2
]
lambdas_class2 = np.ones(len(features_class2)) / len(features_class2)

barycenter_features_class2, barycenter_matrix_class2, log_class2 = ot.gromov.fgw_barycenters(
    N=num_nodes_class2,
    Ys=features_class2,
    Cs=X_class2,
    ps=ps_class2,
    lambdas=lambdas_class2,
    alpha=0.2,
    loss_fun='square_loss',
    random_state=seed,
    log=True)
print("GW barycenter for Class 2 graphs:",
          barycenter_matrix_class2)
print("GW barycenter for Class 2 graphs computed")
# Out:
# GW barycenter for Class 1 graphs: [[ 0.27986933 10.44091834  2.37623716 ...  3.86847845  8.36638584
#    6.40980692]
#  [10.44091834  0.16480853  8.38074524 ...  6.66902567 12.15233958
#    5.91016634]
#  [ 2.37623716  8.38074524  0.28466419 ...  1.81128994  7.08585255
#    4.33829095]
#  ...
#  [ 3.86847845  6.66902567  1.81128994 ...  0.247423    6.19048421
#    2.70111813]
#  [ 8.36638584 12.15233958  7.08585255 ...  6.19048421  0.22319348
#    8.49596837]
#  [ 6.40980692  5.91016634  4.33829095 ...  2.70111813  8.49596837
#    0.41663848]]
# GW barycenter for Class 1 graphs computed
# GW barycenter for Class 2 graphs: [[ 0.37954022  7.046643    2.00332277 ...  1.34317441  9.60847782
#    2.10288662]
#  [ 7.046643    0.12285261  8.01407088 ...  6.62094543 13.38939279
#    5.14500445]
#  [ 2.00332277  8.01407088  0.43043149 ...  1.62376321  9.27439243
#    3.19832784]
#  ...
#  [ 1.34317441  6.62094543  1.62376321 ...  0.4560794   8.56173069
#    1.79913083]
#  [ 9.60847782 13.38939279  9.27439243 ...  8.56173069  0.14908515
#    9.20708242]
#  [ 2.10288662  5.14500445  3.19832784 ...  1.79913083  9.20708242
#    0.30252731]]
# GW barycenter for Class 2 graphs computed

# %%
def compute_fused_gromov_wasserstein_distance(graph_obj, matrix1, matrix2, bary_features):
    for n in graph_obj.nodes():
        m1_features = [graph_obj.nodes[n]['attributes']]

    # Compute metric cost matrix for graph
    M = ot.dist(np.array(m1_features), bary_features)

    fgw, log_fgw = ot.gromov.fused_gromov_wasserstein(
        M,
        matrix1,
        matrix2,
        loss_fun='square_loss',
        alpha=0.5,
        log=True)

    return log_fgw['fgw_dist']

# %%
# Distances from each class to each barycenter
fgw_distances_from_negone_to_negonebary = []
fgw_distances_from_one_to_negonebary = []
fgw_distances_from_negone_to_onebary = []
fgw_distances_from_one_to_onebary = []

for j in range(len(distance_matrices)):
    if labels_list[j] == -1:
        
        dist_negone = compute_fused_gromov_wasserstein_distance(graphs_list[j], distance_matrices[j], barycenter_matrix_class1, barycenter_features_class1)
        dist_one = compute_fused_gromov_wasserstein_distance(graphs_list[j], distance_matrices[j], barycenter_matrix_class2, barycenter_features_class2)
        fgw_distances_from_negone_to_negonebary.append(dist_negone)
        fgw_distances_from_negone_to_onebary.append(dist_one) 
    else:
        dist_negone = compute_fused_gromov_wasserstein_distance(graphs_list[j], distance_matrices[j], barycenter_matrix_class1, barycenter_features_class1)
        dist_one = compute_fused_gromov_wasserstein_distance(graphs_list[j], distance_matrices[j], barycenter_matrix_class2, barycenter_features_class2)
        fgw_distances_from_one_to_negonebary.append(dist_negone)
        fgw_distances_from_one_to_onebary.append(dist_one)

# %%
# Plot results
distances_fgw = (fgw_distances_from_negone_to_negonebary + fgw_distances_from_one_to_negonebary + 
            fgw_distances_from_negone_to_onebary + fgw_distances_from_one_to_onebary)
min_dist = min(distances_fgw)
max_dist = max(distances_fgw)
margin = (max_dist - min_dist) * 0.03  # Add 5% margin

axis_min = min_dist - margin
axis_max = max_dist + margin

plt.figure(figsize=(12, 5))
plt.scatter(fgw_distances_from_negone_to_negonebary, fgw_distances_from_negone_to_onebary, 
           alpha=0.6, label='Class -1 Graphs', color='blue')
plt.scatter(fgw_distances_from_one_to_negonebary, fgw_distances_from_one_to_onebary, 
           alpha=0.6, label='Class 1 Graphs', color='orange')
# Add diagonal line
plt.plot([axis_min, axis_max], [axis_min, axis_max],'k--', alpha=0.5, linewidth=1, label='y = x')
plt.xlabel('Distance to Class 1 (Active) Barycenter')
plt.ylabel('Distance to Class -1 (Inactive) Barycenter')
plt.title('COX-2: fGW Distances to fGW Barycenters')
plt.legend()
plt.grid(True, alpha=0.3)
