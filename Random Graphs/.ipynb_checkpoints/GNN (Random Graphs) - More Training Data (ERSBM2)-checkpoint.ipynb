# %%
### CITATIONS ###
# I read through and utilized the following references to help me understand and set up the neural network. #
# https://medium.com/@a.r.amouzad.m/how-to-get-state-of-the-art-result-on-graph-classification-with-gnn-73afadff5d49
# https://colab.research.google.com/drive/1I8a0DfQ3fI7Njc62__mVXUlcAleUclnb
# https://blog.dataiku.com/graph-neural-networks-part-three

# %%
# !pip install torch
# !pip install torch_geometric
# Out:
# Collecting torch
#   Obtaining dependency information for torch from https://files.pythonhosted.org/packages/13/85/6c1092d4b06c3db1ed23d4106488750917156af0b24ab0a2d9951830b0e9/torch-2.7.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading torch-2.7.0-cp311-cp311-win_amd64.whl.metadata (29 kB)
# Requirement already satisfied: filelock in c:\users\kaitlyn\anaconda3\lib\site-packages (from torch) (3.9.0)
# Collecting typing-extensions>=4.10.0 (from torch)
#   Obtaining dependency information for typing-extensions>=4.10.0 from https://files.pythonhosted.org/packages/8b/54/b1ae86c0973cc6f0210b53d508ca3641fb6d0c56823f288d108bc7ab3cc8/typing_extensions-4.13.2-py3-none-any.whl.metadata
#   Downloading typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting sympy>=1.13.3 (from torch)
#   Obtaining dependency information for sympy>=1.13.3 from https://files.pythonhosted.org/packages/a2/09/77d55d46fd61b4a135c444fc97158ef34a095e5681d0a6c10b75bf356191/sympy-1.14.0-py3-none-any.whl.metadata
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in c:\users\kaitlyn\anaconda3\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\kaitlyn\anaconda3\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\kaitlyn\anaconda3\lib\site-packages (from torch) (2023.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\kaitlyn\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kaitlyn\anaconda3\lib\site-packages (from jinja2->torch) (2.1.1)
# Downloading torch-2.7.0-cp311-cp311-win_amd64.whl (212.5 MB)
#    ---------------------------------------- 0.0/212.5 MB ? eta -:--:--
#    ---------------------------------------- 0.2/212.5 MB 4.6 MB/s eta 0:00:47
#    ---------------------------------------- 0.9/212.5 MB 9.7 MB/s eta 0:00:22
#     --------------------------------------- 2.8/212.5 MB 19.6 MB/s eta 0:00:11
#     --------------------------------------- 4.9/212.5 MB 26.3 MB/s eta 0:00:08
#    - -------------------------------------- 6.8/212.5 MB 29.1 MB/s eta 0:00:08
#    - -------------------------------------- 8.3/212.5 MB 31.1 MB/s eta 0:00:07
#    - -------------------------------------- 9.7/212.5 MB 29.4 MB/s eta 0:00:07
#    -- ------------------------------------- 10.8/212.5 MB 36.4 MB/s eta 0:00:06
#    -- ------------------------------------- 12.3/212.5 MB 34.4 MB/s eta 0:00:06
#    -- ------------------------------------- 15.3/212.5 MB 38.5 MB/s eta 0:00:06
#    --- ------------------------------------ 17.1/212.5 MB 38.5 MB/s eta 0:00:06
#    --- ------------------------------------ 18.5/212.5 MB 38.5 MB/s eta 0:00:06
#    --- ------------------------------------ 20.6/212.5 MB 43.5 MB/s eta 0:00:05
#    --- ------------------------------------ 21.0/212.5 MB 40.9 MB/s eta 0:00:05
#    --- ------------------------------------ 21.0/212.5 MB 40.9 MB/s eta 0:00:05
#    --- ------------------------------------ 21.0/212.5 MB 40.9 MB/s eta 0:00:05
#    --- ------------------------------------ 21.0/212.5 MB 40.9 MB/s eta 0:00:05
#    --- ------------------------------------ 21.0/212.5 MB 40.9 MB/s eta 0:00:05
#    --- ------------------------------------ 21.0/212.5 MB 40.9 MB/s eta 0:00:05
#    --- ------------------------------------ 21.0/212.5 MB 40.9 MB/s eta 0:00:05
#    --- ------------------------------------ 21.0/212.5 MB 40.9 MB/s eta 0:00:05
#    ---- ----------------------------------- 22.0/212.5 MB 16.4 MB/s eta 0:00:12
#    ---- ----------------------------------- 23.8/212.5 MB 16.4 MB/s eta 0:00:12
#    ---- ----------------------------------- 26.1/212.5 MB 16.0 MB/s eta 0:00:12
#    ----- ---------------------------------- 28.2/212.5 MB 16.8 MB/s eta 0:00:11
#    ----- ---------------------------------- 30.1/212.5 MB 17.3 MB/s eta 0:00:11
#    ----- ---------------------------------- 30.1/212.5 MB 15.6 MB/s eta 0:00:12
#    ------ --------------------------------- 34.0/212.5 MB 43.5 MB/s eta 0:00:05
#    ------ --------------------------------- 35.6/212.5 MB 43.7 MB/s eta 0:00:05
#    ------ --------------------------------- 37.1/212.5 MB 40.9 MB/s eta 0:00:05
#    ------- -------------------------------- 39.5/212.5 MB 38.6 MB/s eta 0:00:05
#    ------- -------------------------------- 41.8/212.5 MB 46.7 MB/s eta 0:00:04
#    -------- ------------------------------- 43.9/212.5 MB 40.9 MB/s eta 0:00:05
#    -------- ------------------------------- 46.0/212.5 MB 46.7 MB/s eta 0:00:04
#    --------- ------------------------------ 48.0/212.5 MB 46.7 MB/s eta 0:00:04
#    --------- ------------------------------ 49.8/212.5 MB 46.7 MB/s eta 0:00:04
#    --------- ------------------------------ 51.7/212.5 MB 43.7 MB/s eta 0:00:04
#    ---------- ----------------------------- 54.1/212.5 MB 40.9 MB/s eta 0:00:04
#    ---------- ----------------------------- 55.6/212.5 MB 43.5 MB/s eta 0:00:04
#    ---------- ----------------------------- 55.6/212.5 MB 43.5 MB/s eta 0:00:04
#    ---------- ----------------------------- 55.6/212.5 MB 43.5 MB/s eta 0:00:04
#    ---------- ----------------------------- 55.6/212.5 MB 43.5 MB/s eta 0:00:04
#    ---------- ----------------------------- 55.6/212.5 MB 43.5 MB/s eta 0:00:04
#    ---------- ----------------------------- 55.6/212.5 MB 43.5 MB/s eta 0:00:04
#    ---------- ----------------------------- 55.6/212.5 MB 43.5 MB/s eta 0:00:04
#    ---------- ----------------------------- 56.0/212.5 MB 18.2 MB/s eta 0:00:09
#    ---------- ----------------------------- 56.9/212.5 MB 16.8 MB/s eta 0:00:10
#    ----------- ---------------------------- 58.9/212.5 MB 16.8 MB/s eta 0:00:10
#    ----------- ---------------------------- 61.4/212.5 MB 17.7 MB/s eta 0:00:09
#    ----------- ---------------------------- 63.3/212.5 MB 17.2 MB/s eta 0:00:09
#    ------------ --------------------------- 65.8/212.5 MB 36.4 MB/s eta 0:00:05
#    ------------ --------------------------- 68.0/212.5 MB 46.7 MB/s eta 0:00:04
#    ------------- -------------------------- 70.1/212.5 MB 50.4 MB/s eta 0:00:03
#    ------------- -------------------------- 72.2/212.5 MB 46.7 MB/s eta 0:00:04
#    ------------- -------------------------- 74.3/212.5 MB 46.7 MB/s eta 0:00:03
#    -------------- ------------------------- 76.8/212.5 MB 50.1 MB/s eta 0:00:03
#    -------------- ------------------------- 78.1/212.5 MB 43.7 MB/s eta 0:00:04
#    --------------- ------------------------ 80.2/212.5 MB 43.7 MB/s eta 0:00:04
#    --------------- ------------------------ 82.3/212.5 MB 43.7 MB/s eta 0:00:03
#    --------------- ------------------------ 84.6/212.5 MB 46.7 MB/s eta 0:00:03
#    ---------------- ----------------------- 86.8/212.5 MB 43.7 MB/s eta 0:00:03
#    ---------------- ----------------------- 88.8/212.5 MB 46.7 MB/s eta 0:00:03
#    ----------------- ---------------------- 91.1/212.5 MB 46.7 MB/s eta 0:00:03
#    ----------------- ---------------------- 93.2/212.5 MB 46.7 MB/s eta 0:00:03
#    ----------------- ---------------------- 93.6/212.5 MB 46.7 MB/s eta 0:00:03
#    ----------------- ---------------------- 95.3/212.5 MB 38.6 MB/s eta 0:00:04
#    ------------------ --------------------- 96.0/212.5 MB 38.5 MB/s eta 0:00:04
#    ------------------ --------------------- 97.4/212.5 MB 32.8 MB/s eta 0:00:04
#    ------------------ --------------------- 99.6/212.5 MB 32.7 MB/s eta 0:00:04
#    ------------------ -------------------- 101.7/212.5 MB 32.7 MB/s eta 0:00:04
#    ------------------- ------------------- 103.9/212.5 MB 38.5 MB/s eta 0:00:03
#    ------------------- ------------------- 105.0/212.5 MB 34.4 MB/s eta 0:00:04
#    ------------------- ------------------- 106.5/212.5 MB 40.9 MB/s eta 0:00:03
#    ------------------- ------------------- 107.4/212.5 MB 36.4 MB/s eta 0:00:03
#    -------------------- ------------------ 109.2/212.5 MB 34.4 MB/s eta 0:00:04
#    -------------------- ------------------ 110.0/212.5 MB 32.8 MB/s eta 0:00:04
#    -------------------- ------------------ 112.1/212.5 MB 31.2 MB/s eta 0:00:04
#    -------------------- ------------------ 112.8/212.5 MB 28.4 MB/s eta 0:00:04
#    -------------------- ------------------ 114.3/212.5 MB 27.3 MB/s eta 0:00:04
#    --------------------- ----------------- 116.3/212.5 MB 29.7 MB/s eta 0:00:04
#    --------------------- ----------------- 118.3/212.5 MB 34.4 MB/s eta 0:00:03
#    ---------------------- ---------------- 120.7/212.5 MB 36.4 MB/s eta 0:00:03
#    ---------------------- ---------------- 122.4/212.5 MB 38.6 MB/s eta 0:00:03
#    ---------------------- ---------------- 124.3/212.5 MB 38.5 MB/s eta 0:00:03
#    ----------------------- --------------- 126.3/212.5 MB 40.9 MB/s eta 0:00:03
#    ----------------------- --------------- 128.6/212.5 MB 43.5 MB/s eta 0:00:02
#    ------------------------ -------------- 130.8/212.5 MB 40.9 MB/s eta 0:00:02
#    ------------------------ -------------- 132.9/212.5 MB 46.7 MB/s eta 0:00:02
#    ------------------------ -------------- 134.8/212.5 MB 46.7 MB/s eta 0:00:02
#    ------------------------- ------------- 137.2/212.5 MB 50.4 MB/s eta 0:00:02
#    ------------------------- ------------- 139.5/212.5 MB 46.7 MB/s eta 0:00:02
#    -------------------------- ------------ 141.7/212.5 MB 50.4 MB/s eta 0:00:02
#    -------------------------- ------------ 143.7/212.5 MB 46.9 MB/s eta 0:00:02
#    -------------------------- ------------ 144.6/212.5 MB 50.4 MB/s eta 0:00:02
#    --------------------------- ----------- 147.5/212.5 MB 46.7 MB/s eta 0:00:02
#    --------------------------- ----------- 149.1/212.5 MB 43.7 MB/s eta 0:00:02
#    --------------------------- ----------- 151.0/212.5 MB 40.9 MB/s eta 0:00:02
#    ---------------------------- ---------- 152.9/212.5 MB 40.9 MB/s eta 0:00:02
#    ---------------------------- ---------- 155.0/212.5 MB 46.7 MB/s eta 0:00:02
#    ---------------------------- ---------- 156.5/212.5 MB 43.7 MB/s eta 0:00:02
#    ---------------------------- ---------- 157.4/212.5 MB 40.9 MB/s eta 0:00:02
#    ----------------------------- --------- 158.4/212.5 MB 32.8 MB/s eta 0:00:02
#    ----------------------------- --------- 160.1/212.5 MB 34.4 MB/s eta 0:00:02
#    ----------------------------- --------- 161.1/212.5 MB 34.4 MB/s eta 0:00:02
#    ----------------------------- --------- 161.5/212.5 MB 28.4 MB/s eta 0:00:02
#    ------------------------------ -------- 163.9/212.5 MB 28.4 MB/s eta 0:00:02
#    ------------------------------ -------- 164.9/212.5 MB 29.8 MB/s eta 0:00:02
#    ------------------------------ -------- 165.3/212.5 MB 24.3 MB/s eta 0:00:02
#    ------------------------------ -------- 167.6/212.5 MB 29.8 MB/s eta 0:00:02
#    ------------------------------- ------- 169.7/212.5 MB 29.7 MB/s eta 0:00:02
#    ------------------------------- ------- 170.8/212.5 MB 29.8 MB/s eta 0:00:02
#    ------------------------------- ------- 171.1/212.5 MB 25.2 MB/s eta 0:00:02
#    ------------------------------- ------- 172.7/212.5 MB 28.4 MB/s eta 0:00:02
#    ------------------------------- ------- 173.8/212.5 MB 29.8 MB/s eta 0:00:02
#    -------------------------------- ------ 174.7/212.5 MB 25.1 MB/s eta 0:00:02
#    -------------------------------- ------ 176.2/212.5 MB 28.5 MB/s eta 0:00:02
#    -------------------------------- ------ 177.4/212.5 MB 28.5 MB/s eta 0:00:02
#    -------------------------------- ------ 178.2/212.5 MB 25.1 MB/s eta 0:00:02
#    -------------------------------- ------ 179.8/212.5 MB 25.2 MB/s eta 0:00:02
#    --------------------------------- ----- 181.3/212.5 MB 28.5 MB/s eta 0:00:02
#    --------------------------------- ----- 182.6/212.5 MB 27.3 MB/s eta 0:00:02
#    --------------------------------- ----- 184.3/212.5 MB 31.2 MB/s eta 0:00:01
#    ---------------------------------- ---- 186.6/212.5 MB 32.7 MB/s eta 0:00:01
#    ---------------------------------- ---- 187.0/212.5 MB 28.4 MB/s eta 0:00:01
#    ---------------------------------- ---- 188.8/212.5 MB 32.7 MB/s eta 0:00:01
#    ---------------------------------- ---- 190.3/212.5 MB 32.7 MB/s eta 0:00:01
#    ---------------------------------- ---- 190.6/212.5 MB 29.8 MB/s eta 0:00:01
#    ---------------------------------- ---- 190.6/212.5 MB 29.8 MB/s eta 0:00:01
#    ----------------------------------- --- 192.6/212.5 MB 27.3 MB/s eta 0:00:01
#    ----------------------------------- --- 194.8/212.5 MB 28.5 MB/s eta 0:00:01
#    ------------------------------------ -- 196.9/212.5 MB 27.3 MB/s eta 0:00:01
#    ------------------------------------ -- 198.8/212.5 MB 31.2 MB/s eta 0:00:01
#    ------------------------------------ -- 200.8/212.5 MB 36.3 MB/s eta 0:00:01
#    ------------------------------------- - 203.0/212.5 MB 46.7 MB/s eta 0:00:01
#    ------------------------------------- - 205.2/212.5 MB 46.9 MB/s eta 0:00:01
#    ------------------------------------- - 207.0/212.5 MB 43.7 MB/s eta 0:00:01
#    --------------------------------------  209.4/212.5 MB 46.7 MB/s eta 0:00:01
#    --------------------------------------  211.6/212.5 MB 46.7 MB/s eta 0:00:01
#    --------------------------------------  212.5/212.5 MB 46.7 MB/s eta 0:00:01
#    --------------------------------------  212.5/212.5 MB 46.7 MB/s eta 0:00:01
#    --------------------------------------  212.5/212.5 MB 46.7 MB/s eta 0:00:01
#    --------------------------------------  212.5/212.5 MB 46.7 MB/s eta 0:00:01
#    --------------------------------------  212.5/212.5 MB 46.7 MB/s eta 0:00:01
#    --------------------------------------  212.5/212.5 MB 46.7 MB/s eta 0:00:01
#    --------------------------------------  212.5/212.5 MB 46.7 MB/s eta 0:00:01
#    --------------------------------------- 212.5/212.5 MB 14.2 MB/s eta 0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------- ----------------------- 2.5/6.3 MB 54.0 MB/s eta 0:00:01
#    -------------------------- ------------- 4.2/6.3 MB 44.1 MB/s eta 0:00:01
#    ------------------------------------ --- 5.7/6.3 MB 40.2 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 36.6 MB/s eta 0:00:00
# Downloading typing_extensions-4.13.2-py3-none-any.whl (45 kB)
#    ---------------------------------------- 0.0/45.8 kB ? eta -:--:--
#    ---------------------------------------- 45.8/45.8 kB ? eta 0:00:00
# Installing collected packages: typing-extensions, sympy, torch
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.7.1
#     Uninstalling typing_extensions-4.7.1:
#       Successfully uninstalled typing_extensions-4.7.1
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.11.1
#     Uninstalling sympy-1.11.1:
#       Successfully uninstalled sympy-1.11.1
# Successfully installed sympy-1.14.0 torch-2.7.0 typing-extensions-4.13.2
# Collecting torch_geometric
#   Obtaining dependency information for torch_geometric from https://files.pythonhosted.org/packages/03/9f/157e913626c1acfb3b19ce000b1a6e4e4fb177c0bc0ea0c67ca5bd714b5a/torch_geometric-2.6.1-py3-none-any.whl.metadata
#   Downloading torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
#      ---------------------------------------- 0.0/63.1 kB ? eta -:--:--
#      ---------------------------------------- 0.0/63.1 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/63.1 kB ? eta -:--:--
#      ------------------ ------------------- 30.7/63.1 kB 262.6 kB/s eta 0:00:01
#      ------------------------------ ------- 51.2/63.1 kB 327.7 kB/s eta 0:00:01
#      -------------------------------------- 63.1/63.1 kB 338.6 kB/s eta 0:00:00
# Requirement already satisfied: aiohttp in c:\users\kaitlyn\anaconda3\lib\site-packages (from torch_geometric) (3.8.5)
# Requirement already satisfied: fsspec in c:\users\kaitlyn\anaconda3\lib\site-packages (from torch_geometric) (2023.4.0)
# Requirement already satisfied: jinja2 in c:\users\kaitlyn\anaconda3\lib\site-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: numpy in c:\users\kaitlyn\anaconda3\lib\site-packages (from torch_geometric) (1.24.3)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\kaitlyn\anaconda3\lib\site-packages (from torch_geometric) (5.9.0)
# Requirement already satisfied: pyparsing in c:\users\kaitlyn\anaconda3\lib\site-packages (from torch_geometric) (3.0.9)
# Requirement already satisfied: requests in c:\users\kaitlyn\anaconda3\lib\site-packages (from torch_geometric) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\kaitlyn\anaconda3\lib\site-packages (from torch_geometric) (4.65.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\kaitlyn\anaconda3\lib\site-packages (from aiohttp->torch_geometric) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\kaitlyn\anaconda3\lib\site-packages (from aiohttp->torch_geometric) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\kaitlyn\anaconda3\lib\site-packages (from aiohttp->torch_geometric) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\kaitlyn\anaconda3\lib\site-packages (from aiohttp->torch_geometric) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\kaitlyn\anaconda3\lib\site-packages (from aiohttp->torch_geometric) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\kaitlyn\anaconda3\lib\site-packages (from aiohttp->torch_geometric) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\kaitlyn\anaconda3\lib\site-packages (from aiohttp->torch_geometric) (1.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kaitlyn\anaconda3\lib\site-packages (from jinja2->torch_geometric) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kaitlyn\anaconda3\lib\site-packages (from requests->torch_geometric) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kaitlyn\anaconda3\lib\site-packages (from requests->torch_geometric) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kaitlyn\anaconda3\lib\site-packages (from requests->torch_geometric) (2024.2.2)
# Requirement already satisfied: colorama in c:\users\kaitlyn\anaconda3\lib\site-packages (from tqdm->torch_geometric) (0.4.6)
# Downloading torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.1/1.1 MB 3.6 MB/s eta 0:00:01
#    -------------------- ------------------- 0.6/1.1 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 10.3 MB/s eta 0:00:00
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.6.1

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch_geometric.nn import GCNConv, global_mean_pool
from torch_geometric.data import Data, DataLoader
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, classification_report, f1_score
import numpy as np
import time
import random
import networkx as nx
import optuna
from optuna.samplers import TPESampler
from gwgraphs import *
from visualizations import GCNResultsVisualizer, get_model_probabilities

# %%
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

# %%
class GraphNeuralNetwork(nn.Module):

  def __init__(self, input_dim, hidden_dim, output_dim, num_layers=3):
    super(GraphNeuralNetwork, self).__init__()

    self.num_layers = num_layers
    self.convs = nn.ModuleList()

    # First layer
    self.convs.append(GCNConv(input_dim, hidden_dim))

    # Hidden layers
    for _ in range(num_layers - 2):
      self.convs.append(GCNConv(hidden_dim, hidden_dim))

    # Last layer
    self.convs.append(GCNConv(hidden_dim, hidden_dim))

    # Classifier
    self.classifier = nn.Linear(hidden_dim, output_dim)
    self.dropout = nn.Dropout(0.5)

  def forward(self, x, edge_index, batch, edge_attr=None):
    # Apply GCN layers
    for i, conv in enumerate(self.convs):
      x = conv(x, edge_index, edge_weight=edge_attr)
      if i < len(self.convs) - 1:
        x = F.relu(x)
        x = self.dropout(x)

    # Global pooling to get graph-level representation
    x = global_mean_pool(x, batch)

    # Final classification
    x = self.classifier(x)

    return x


def train_model(model, train_loader, optimizer, criterion, device):
  """Function to train the model for one epoch."""
  model.train()
  total_loss = 0

  for batch in train_loader:
    batch = batch.to(device)
    optimizer.zero_grad()

    # Forward pass
    out = model(batch.x, batch.edge_index, batch.batch, batch.edge_attr if hasattr(batch, 'edge_attr') else None)

    # Convert labels from {-1, 1} to {0,1} for cross-entropy loss
    labels = (batch.y + 1) // 2

    loss = criterion(out, labels.view(-1))
    loss.backward()
    optimizer.step()

    total_loss += loss.item()

  return total_loss / len(train_loader)


def evaluate_model(model, test_loader, device):
  """Function to evaluate the model."""
  model.eval()
  predictions = []
  true_labels = []

  with torch.no_grad():
    for batch in test_loader:
      batch = batch.to(device)
      out = model(batch.x, batch.edge_index, batch.batch, batch.edge_attr if hasattr(batch, 'edge_attr') else None)

      # Get predictions
      pred = torch.argmax(out, dim=1)
      # Convert back to {-1,1} labels
      pred = pred * 2 - 1

      predictions.extend(pred.cpu().numpy())
      true_labels.extend(batch.y.cpu().numpy())

    return np.array(predictions), np.array(true_labels)


def calculate_metrics(y_true, y_pred):
  """Calculate classification metrics"""
  # Overall accuracy
  overall_acc = accuracy_score(y_true, y_pred)

  # By-class accuracy
  class_1_mask = y_true == 1
  class_neg1_mask = y_true == -1

  class_1_acc = accuracy_score(
      y_true[class_1_mask],
      y_pred[class_1_mask]) if np.sum(class_1_mask) > 0 else 0
  class_neg1_acc = accuracy_score(
      y_true[class_neg1_mask],
      y_pred[class_neg1_mask]) if np.sum(class_neg1_mask) > 0 else 0

  # F1 score
  f1 = f1_score(y_true, y_pred, average='weighted')

  return overall_acc, class_1_acc, class_neg1_acc, f1


def networkx_to_pyg(nx_graph, label, num_features):
  """Convert NetworkX graph to PyTorch Geometric Data object with edge features"""
  num_nodes = len(nx_graph.nodes)

  if num_features == 0:
    raise ValueError(
        "num_features cannot be 0. Use num_features=1 for minimal features.")
  elif num_features == 1:
    # Use constant features (all ones) for graphs without meaningful node features
    x = torch.ones(num_nodes, 1)
  else:
    # Create random node features for synthetic examples
    x = torch.randn(num_nodes, num_features)

  # Convert edges to tensor format and create edge features
  edge_list = list(nx_graph.edges())
  if len(edge_list) == 0:
    # Handle graphs with no edges
    edge_index = torch.empty((2, 0), dtype=torch.long)
    edge_attr = torch.empty((0, 1), dtype=torch.float)
  else:
    edge_index = torch.tensor(edge_list, dtype=torch.long).t().contiguous()
    
    # Create edge features based on graph properties
    edge_features = []
    for u, v in edge_list:
      # Use degree difference as edge feature
      degree_diff = abs(nx_graph.degree[u] - nx_graph.degree[v])
      edge_features.append([degree_diff])
    
    edge_attr = torch.tensor(edge_features, dtype=torch.float)

  # Convert label to tensor
  y = torch.tensor([label], dtype=torch.long)

  return Data(x=x, edge_index=edge_index, edge_attr=edge_attr, y=y)


def objective(trial, full_graph_data, device, input_dim, hidden_dim, output_dim):
    """Objective function for Bayesian optimization"""
    # Suggest hyperparameters
    num_epochs = trial.suggest_int('num_epochs', 20, 100, step=10)
    learning_rate = trial.suggest_float('learning_rate', 1e-4, 1e-1, log=True)
    batch_size = trial.suggest_categorical('batch_size', [16, 32, 64])

    # 5-fold cross validation for this trial
    kfold = KFold(n_splits=5, shuffle=True, random_state=42)
    fold_scores = []

    for fold, (train_idx, test_idx) in enumerate(kfold.split(full_graph_data)):
        # Split data
        train_graphs = [full_graph_data[i] for i in train_idx]
        test_graphs = [full_graph_data[i] for i in test_idx]

        # Create data loaders
        train_loader = DataLoader(train_graphs, batch_size=batch_size, shuffle=True)
        test_loader = DataLoader(test_graphs, batch_size=batch_size, shuffle=False)

        # Initialize model
        model = GraphNeuralNetwork(input_dim, hidden_dim, output_dim).to(device)
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)
        criterion = nn.CrossEntropyLoss()

        # Training loop
        for epoch in range(num_epochs):
            train_loss = train_model(model, train_loader, optimizer, criterion, device)

        # Evaluation
        y_pred, y_true = evaluate_model(model, test_loader, device)
        overall_acc, _, _, _ = calculate_metrics(y_true, y_pred)
        fold_scores.append(overall_acc)

        # Report intermediate objective value for pruning
        trial.report(np.mean(fold_scores[:fold + 1]), fold)

        # Handle pruning based on the intermediate value
        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()

    return np.mean(fold_scores)

# %%
### ERSBM2 EXPERIMENT: MORE TRAINING DATA ###
# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Model parameters
input_dim = 1  # Number of node features; no meaningful features in this synthetic example, so set = 1
hidden_dim = 64  # defines the number of neurons in the GCN layers. Essentially, controls the width of the neural network
# larger hidden_dim means more capacity but more parameters
output_dim = 2  # Binary classification, so set to 2

# Generate and process data
print("Generating synthetic graph dataset...")
# Generate ERSBM2
prob_matrix5 = [
    [0.45, 0.05],  # Probabilities related to block 1 connections
    [0.05, 0.45]  # Probabilities related to block 2 connections
]

graphs_er5 = generate_erdos_renyi_graphs(500, 100, 0.25)
graphs_sbm5 = generate_sbm_graphs(500, [50, 50], prob_matrix5)

# Convert NetworkX graphs to PyTorch Geometric Data objects
full_graph_data5 = []
graphs_list5 = []
labels_list5 = []
for nx_graph, label in graphs_er5 + graphs_sbm5:
    pyg_data = networkx_to_pyg(nx_graph, label, input_dim)
    full_graph_data5.append(pyg_data)
    graphs_list5.append(nx_graph)
    labels_list5.append(label)

# Extract labels for reference
labels5 = [data.y.item() for data in full_graph_data5]
labels5 = np.array(labels5)
print("ERSBM2 created")

print("\nStarting Bayesian Optimization for Hyperparameter Tuning...")
start_time = time.time()

# Create Optuna study
study = optuna.create_study(direction='maximize',
                            sampler=TPESampler(seed=42),
                            pruner=optuna.pruners.MedianPruner(
                                n_startup_trials=5, n_warmup_steps=2))

# Optimize hyperparameters
study.optimize(
    lambda trial: objective(trial, full_graph_data5, device, input_dim,
                            hidden_dim, output_dim),
    n_trials=30
)

optimization_time = time.time() - start_time

# Print best hyperparameters
print("\n" + "=" * 60)
print("BAYESIAN OPTIMIZATION RESULTS")
print("=" * 60)
print(f"Best trial: {study.best_trial.number}")
print(f"Best accuracy: {study.best_trial.value:.4f}")
print("Best hyperparameters:")
for key, value in study.best_trial.params.items():
    print(f"  {key}: {value}")

print(f"\nOptimization time: {optimization_time:.2f} seconds")

# Train final model with best hyperparameters
print("\n" + "=" * 60)
print("TRAINING FINAL MODEL WITH BEST HYPERPARAMETERS")
print("=" * 60)

best_params = study.best_trial.params
final_num_epochs = best_params['num_epochs']
final_learning_rate = best_params['learning_rate']
final_batch_size = best_params['batch_size']

# 5-fold cross validation with best parameters
kfold = KFold(n_splits=5, shuffle=True, random_state=42)
all_results = []
fold_times = []

print("\nStarting 5-fold cross-validation with optimized parameters...")
total_start_time = time.time()

for fold, (train_idx, test_idx) in enumerate(kfold.split(full_graph_data5)):
  print(f"\n--- Final Training Fold {fold + 1}/5 ---")
  fold_start_time = time.time()

  # Split data
  train_graphs = [full_graph_data5[i] for i in train_idx]
  test_graphs = [full_graph_data5[i] for i in test_idx]

  # Create data loaders
  train_loader = DataLoader(train_graphs, batch_size=final_batch_size, shuffle=True)
  test_loader = DataLoader(test_graphs, batch_size=final_batch_size, shuffle=False)

  # Initialize model
  model = GraphNeuralNetwork(input_dim, hidden_dim, output_dim).to(device)
  optimizer = optim.Adam(model.parameters(), lr=final_learning_rate)
  criterion = nn.CrossEntropyLoss()

  # Training loop
  for epoch in range(final_num_epochs):
    train_loss = train_model(model, train_loader, optimizer, criterion, device)

    if (epoch + 1) % 10 == 0:
      print(f"Epoch {epoch + 1}/{final_num_epochs}, Loss: {train_loss:.4f}")

  # Final evaluation
  y_pred, y_true = evaluate_model(model, test_loader, device)
  overall_acc, class_1_acc, class_neg1_acc, f1 = calculate_metrics(y_true, y_pred)

  fold_time = time.time() - fold_start_time
  fold_times.append(fold_time)

  results = {
      'fold': fold + 1,
      'overall_accuracy': overall_acc,
      'class_1_accuracy': class_1_acc,
      'class_-1_accuracy': class_neg1_acc,
      'f1_score': f1,
      'fold_time': fold_time
  }

  all_results.append(results)

  print(f"Results for Fold {fold + 1}:")
  print(f"  Overall Accuracy: {overall_acc:.4f}")
  print(f"  Class +1 Accuracy: {class_1_acc:.4f}")
  print(f"  Class -1 Accuracy: {class_neg1_acc:.4f}")
  print(f"  F1 Score: {f1:.4f}")
  print(f"  Fold Time: {fold_time:.2f} seconds")

# Calculate final average metrics
avg_overall_acc = np.mean([r['overall_accuracy'] for r in all_results])
avg_class_1_acc = np.mean([r['class_1_accuracy'] for r in all_results])
avg_class_neg1_acc = np.mean([r['class_-1_accuracy'] for r in all_results])
avg_f1 = np.mean([r['f1_score'] for r in all_results])

std_overall_acc = np.std([r['overall_accuracy'] for r in all_results])
std_class_1_acc = np.std([r['class_1_accuracy'] for r in all_results])
std_class_neg1_acc = np.std([r['class_-1_accuracy'] for r in all_results])
std_f1 = np.std([r['f1_score'] for r in all_results])

total_time = time.time() - total_start_time

print("\n" + "=" * 60)
print("FINAL RESULTS WITH OPTIMIZED HYPERPARAMETERS")
print("=" * 60)
print(f"Best hyperparameters used:")
print(f"  Epochs: {final_num_epochs}")
print(f"  Learning Rate: {final_learning_rate:.6f}")
print(f"  Batch Size: {final_batch_size}")
print(f"\nFinal Cross-Validation Results:")
print(f"Average Overall Accuracy: {avg_overall_acc:.4f} ± {std_overall_acc:.4f}")
print(f"Average Class +1 Accuracy: {avg_class_1_acc:.4f} ± {std_class_1_acc:.4f}")
print(f"Average Class -1 Accuracy: {avg_class_neg1_acc:.4f} ± {std_class_neg1_acc:.4f}")
print(f"Average F1 Score: {avg_f1:.4f} ± {std_f1:.4f}")
print(f"\nTotal Time (Optimization + Final Training): {total_time:.2f} seconds")
print(f"Average Time per Fold: {np.mean(fold_times):.2f} seconds")
# Out:
# Using device: cpu
# Generating synthetic graph dataset...
# [I 2025-06-27 16:54:22,530] A new study created in memory with name: no-name-a109f991-4198-4ffb-b123-9e8fcffc5ec6
# ERSBM2 created
#
# Starting Bayesian Optimization for Hyperparameter Tuning...
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 16:57:30,244] Trial 0 finished with value: 0.5359999999999999 and parameters: {'num_epochs': 50, 'learning_rate': 0.0711447600934342, 'batch_size': 16}. Best is trial 0 with value: 0.5359999999999999.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 16:59:24,648] Trial 1 finished with value: 0.5 and parameters: {'num_epochs': 30, 'learning_rate': 0.00014936568554617635, 'batch_size': 16}. Best is trial 0 with value: 0.5359999999999999.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 17:00:47,966] Trial 2 finished with value: 0.607 and parameters: {'num_epochs': 20, 'learning_rate': 0.0812324508558869, 'batch_size': 16}. Best is trial 2 with value: 0.607.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 17:03:04,738] Trial 3 finished with value: 0.5 and parameters: {'num_epochs': 30, 'learning_rate': 0.0008179499475211679, 'batch_size': 16}. Best is trial 2 with value: 0.607.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 17:06:37,757] Trial 4 finished with value: 0.5 and parameters: {'num_epochs': 70, 'learning_rate': 0.00026210878782654407, 'batch_size': 64}. Best is trial 2 with value: 0.607.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 17:11:53,289] Trial 5 finished with value: 0.5 and parameters: {'num_epochs': 90, 'learning_rate': 0.0003972110727381916, 'batch_size': 32}. Best is trial 2 with value: 0.607.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 17:15:24,362] Trial 6 finished with value: 0.5 and parameters: {'num_epochs': 70, 'learning_rate': 0.00032476735706274504, 'batch_size': 64}. Best is trial 2 with value: 0.607.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 17:20:10,874] Trial 7 finished with value: 0.5 and parameters: {'num_epochs': 90, 'learning_rate': 0.0008200518402245837, 'batch_size': 32}. Best is trial 2 with value: 0.607.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 17:21:44,164] Trial 8 finished with value: 0.5109999999999999 and parameters: {'num_epochs': 30, 'learning_rate': 0.0030586566669785274, 'batch_size': 32}. Best is trial 2 with value: 0.607.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 17:25:21,111] Trial 9 finished with value: 0.5 and parameters: {'num_epochs': 70, 'learning_rate': 0.0008612579192594886, 'batch_size': 32}. Best is trial 2 with value: 0.607.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 17:26:36,640] Trial 10 finished with value: 0.48600000000000004 and parameters: {'num_epochs': 20, 'learning_rate': 0.0628269316540743, 'batch_size': 16}. Best is trial 2 with value: 0.607.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 17:29:44,633] Trial 11 finished with value: 0.618 and parameters: {'num_epochs': 50, 'learning_rate': 0.08946888125457012, 'batch_size': 16}. Best is trial 11 with value: 0.618.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 17:33:11,047] Trial 12 finished with value: 0.6439999999999999 and parameters: {'num_epochs': 50, 'learning_rate': 0.02130319595170936, 'batch_size': 16}. Best is trial 12 with value: 0.6439999999999999.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 17:36:19,219] Trial 13 finished with value: 0.6 and parameters: {'num_epochs': 50, 'learning_rate': 0.018550110269395355, 'batch_size': 16}. Best is trial 12 with value: 0.6439999999999999.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 17:39:35,837] Trial 14 finished with value: 0.557 and parameters: {'num_epochs': 50, 'learning_rate': 0.016979256531282263, 'batch_size': 16}. Best is trial 12 with value: 0.6439999999999999.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 17:43:49,948] Trial 15 finished with value: 0.657 and parameters: {'num_epochs': 60, 'learning_rate': 0.01945342335510126, 'batch_size': 16}. Best is trial 15 with value: 0.657.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 17:47:04,705] Trial 16 finished with value: 0.5279999999999999 and parameters: {'num_epochs': 60, 'learning_rate': 0.010535135349343278, 'batch_size': 64}. Best is trial 15 with value: 0.657.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 17:54:53,724] Trial 17 finished with value: 0.5 and parameters: {'num_epochs': 100, 'learning_rate': 0.0046378823123481554, 'batch_size': 16}. Best is trial 15 with value: 0.657.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 17:57:43,453] Trial 18 finished with value: 0.634 and parameters: {'num_epochs': 40, 'learning_rate': 0.03549557251724621, 'batch_size': 16}. Best is trial 15 with value: 0.657.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 18:01:39,412] Trial 19 finished with value: 0.509 and parameters: {'num_epochs': 80, 'learning_rate': 0.005861554819300929, 'batch_size': 64}. Best is trial 15 with value: 0.657.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 18:07:19,299] Trial 20 finished with value: 0.554 and parameters: {'num_epochs': 80, 'learning_rate': 0.028744976785542203, 'batch_size': 16}. Best is trial 15 with value: 0.657.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 18:10:19,535] Trial 21 finished with value: 0.695 and parameters: {'num_epochs': 40, 'learning_rate': 0.03403614029566116, 'batch_size': 16}. Best is trial 21 with value: 0.695.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 18:12:05,115] Trial 22 finished with value: 0.518 and parameters: {'num_epochs': 40, 'learning_rate': 0.010477328483671474, 'batch_size': 16}. Best is trial 21 with value: 0.695.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 18:14:43,308] Trial 23 finished with value: 0.555 and parameters: {'num_epochs': 60, 'learning_rate': 0.03481759989033465, 'batch_size': 16}. Best is trial 21 with value: 0.695.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 18:16:28,871] Trial 24 pruned.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 18:19:07,031] Trial 25 pruned.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 18:20:52,763] Trial 26 finished with value: 0.591 and parameters: {'num_epochs': 40, 'learning_rate': 0.01993159917275784, 'batch_size': 16}. Best is trial 21 with value: 0.695.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 18:22:52,448] Trial 27 finished with value: 0.503 and parameters: {'num_epochs': 50, 'learning_rate': 0.04651528340145965, 'batch_size': 64}. Best is trial 21 with value: 0.695.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 18:25:18,746] Trial 28 pruned.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [I 2025-06-27 18:27:04,323] Trial 29 finished with value: 0.625 and parameters: {'num_epochs': 40, 'learning_rate': 0.02316499337376987, 'batch_size': 16}. Best is trial 21 with value: 0.695.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# ============================================================
# BAYESIAN OPTIMIZATION RESULTS
# ============================================================
# Best trial: 21
# Best accuracy: 0.6950
# Best hyperparameters:
#   num_epochs: 40
#   learning_rate: 0.03403614029566116
#   batch_size: 16
#
# Optimization time: 5561.79 seconds
#
# ============================================================
# TRAINING FINAL MODEL WITH BEST HYPERPARAMETERS
# ============================================================
#
# Starting 5-fold cross-validation with optimized parameters...
#
# --- Final Training Fold 1/5 ---
# Epoch 10/40, Loss: 0.5526
# Epoch 20/40, Loss: 0.4739
# Epoch 30/40, Loss: 0.4803
# Epoch 40/40, Loss: 0.4299
# Results for Fold 1:
#   Overall Accuracy: 0.5200
#   Class +1 Accuracy: 0.0000
#   Class -1 Accuracy: 1.0000
#   F1 Score: 0.3558
#   Fold Time: 21.14 seconds
#
# --- Final Training Fold 2/5 ---
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Epoch 10/40, Loss: 0.4572
# Epoch 20/40, Loss: 0.4717
# Epoch 30/40, Loss: 0.5052
# Epoch 40/40, Loss: 0.4764
# Results for Fold 2:
#   Overall Accuracy: 0.4400
#   Class +1 Accuracy: 0.0000
#   Class -1 Accuracy: 1.0000
#   F1 Score: 0.2689
#   Fold Time: 21.12 seconds
#
# --- Final Training Fold 3/5 ---
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Epoch 10/40, Loss: 0.6949
# Epoch 20/40, Loss: 0.7026
# Epoch 30/40, Loss: 0.6939
# Epoch 40/40, Loss: 0.7039
# Results for Fold 3:
#   Overall Accuracy: 0.5300
#   Class +1 Accuracy: 1.0000
#   Class -1 Accuracy: 0.0000
#   F1 Score: 0.3672
#   Fold Time: 21.12 seconds
#
# --- Final Training Fold 4/5 ---
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Epoch 10/40, Loss: 0.5857
# Epoch 20/40, Loss: 0.5540
# Epoch 30/40, Loss: 0.5529
# Epoch 40/40, Loss: 0.5493
# Results for Fold 4:
#   Overall Accuracy: 0.8150
#   Class +1 Accuracy: 0.9647
#   Class -1 Accuracy: 0.7043
#   F1 Score: 0.8149
#   Fold Time: 21.12 seconds
#
# --- Final Training Fold 5/5 ---
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Epoch 10/40, Loss: 0.5136
# Epoch 20/40, Loss: 0.4522
# Epoch 30/40, Loss: 0.4818
# Epoch 40/40, Loss: 0.5088
# Results for Fold 5:
#   Overall Accuracy: 0.5100
#   Class +1 Accuracy: 0.0297
#   Class -1 Accuracy: 1.0000
#   F1 Score: 0.3602
#   Fold Time: 21.12 seconds
#
# ============================================================
# FINAL RESULTS WITH OPTIMIZED HYPERPARAMETERS
# ============================================================
# Best hyperparameters used:
#   Epochs: 40
#   Learning Rate: 0.034036
#   Batch Size: 16
#
# Final Cross-Validation Results:
# Average Overall Accuracy: 0.5630 ± 0.1299
# Average Class +1 Accuracy: 0.3989 ± 0.4767
# Average Class -1 Accuracy: 0.7409 ± 0.3877
# Average F1 Score: 0.4334 ± 0.1941
#
# Total Time (Optimization + Final Training): 105.61 seconds
# Average Time per Fold: 21.12 seconds

# %%
# Create visualizer with optimization results
visualizer = GCNResultsVisualizer(
    study=study, 
    all_results=all_results, 
    best_params=study.best_trial.params
)

# Generate core optimization visualizations
visualizer.plot_optimization_history()
visualizer.plot_hyperparameter_relationships()
visualizer.plot_cross_validation_results()

# For the final model evaluation with the best parameters
print("\nTraining final model for detailed evaluation...")

# Use the entire dataset for final model evaluation
final_train_loader = DataLoader(full_graph_data5, batch_size=final_batch_size, shuffle=True)
final_model = GraphNeuralNetwork(input_dim, hidden_dim, output_dim).to(device)
final_optimizer = optim.Adam(final_model.parameters(), lr=final_learning_rate)
final_criterion = nn.CrossEntropyLoss()

# Train the final model
for epoch in range(final_num_epochs):
    train_loss = train_model(final_model, final_train_loader, final_optimizer, final_criterion, device)

# Get predictions and probabilities for visualization
final_y_true, final_y_scores = get_model_probabilities(final_model, final_train_loader, device)
final_y_pred = np.argmax(final_y_scores, axis=1) * 2 - 1  # Convert back to {-1, 1}

# Generate performance visualizations
visualizer.plot_confusion_matrix(final_y_true, final_y_pred)
visualizer.plot_roc_curve(final_y_true, final_y_scores)

# Visualize sample graphs
visualizer.plot_sample_graphs(graphs_list5, labels_list5)

print("All visualizations have been generated and saved!")
# Out:
# Training final model for detailed evaluation...
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# All visualizations have been generated and saved!
